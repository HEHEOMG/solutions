# %% [markdown]
# ## ML-第七版本-类别特征编码-时间序列特征-交叉累计特征-embeding特征-验证版

# %% [markdown]
# ## 导包

# %%
import os
import re
import numpy as np
import pandas as pd
import datetime
import pickle as pkl

import matplotlib.pyplot as plt
import seaborn as sns

import scorpyo as sp
from null_importance import get_null_importance
from time_sequence_feats import get_time_base, get_sequence_statis, get_sequence_groupby_statis
import category_encoders as ce

from gensim.models import word2vec

import time
from sklearn.metrics import roc_auc_score as auc
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold, KFold

import warnings
warnings.filterwarnings("ignore")

pd.set_option('max_rows', 320, 'max_columns',100)

# %%
path_project = r'/Users/liliangshan/workspace/python/01_datasets/ccf_system_access_risk_identification'

# path dir
path_row_data = os.path.join(path_project, 'row_data')
path_new_data = os.path.join(path_project, 'new_data')
path_results  = os.path.join(path_project, 'results')
path_results_version  = os.path.join(path_results, 'version_2')

# path row_data
path_train = os.path.join(path_row_data, 'train.csv')
path_test  = os.path.join(path_row_data, 'evaluation_public.csv')
path_sample_submission = os.path.join(path_row_data, 'submit_example.csv')

## results
path_output_report = os.path.join(path_results, '01_原始数据探察_20221014.xlsx')

y_label = "is_risk"


# new_train_data
path_new_train_cate = os.path.join(path_new_data, 'train_cate.pkl')
path_new_test_cate  = os.path.join(path_new_data, 'test_cate.pkl')

path_new_train_time_sequence = os.path.join(path_new_data, 'train_time_sequence.pkl')
path_new_test_time_sequence  = os.path.join(path_new_data, 'test_time_sequence.pkl')

path_new_train_time_sequence_woe = os.path.join(path_new_data, 'train_time_sequence_woe.pkl')
path_new_test_time_sequence_woe  = os.path.join(path_new_data, 'test_time_sequence_woe.pkl')

path_new_train_cumsum = os.path.join(path_new_data, 'train_cumsum.pkl')
path_new_test_cumsum = os.path.join(path_new_data, 'test_cumsum.pkl')

path_new_train_cumsum_woe = os.path.join(path_new_data, 'train_cumsum_woe.pkl')
path_new_test_cumsum_woe = os.path.join(path_new_data, 'test_cumsum_woe.pkl')

path_new_train_embeding = os.path.join(path_new_data, 'train_embeding.pkl')
path_new_test_embeding = os.path.join(path_new_data, 'test_embeding.pkl')

path_new_train_time_sequence_sp_woe = os.path.join(path_new_data, 'train_time_sequence_sp_woe.pkl')
path_new_test_time_sequence_sp_woe  = os.path.join(path_new_data, 'test_time_sequence_sp_woe.pkl')

path_new_train_cumsum_sp_woe = os.path.join(path_new_data, 'train_cumsum_sp_woe.pkl')
path_new_test_cumsum_sp_woe = os.path.join(path_new_data, 'test_cumsum_sp_woe.pkl')


path_new_train_sp_cate = os.path.join(path_new_data, 'train_sp_cate.pkl')
path_new_test_sp_cate  = os.path.join(path_new_data, 'test_sp_cate.pkl')

# %%
df_row_train = pd.read_csv(path_train)
df_row_val  = pd.read_csv(path_test)

# %% [markdown]
# ## 工具函数

# %%
def save_pkl(data, path_data):
    """将数据保存为pkl"""
    with open(path_data, 'wb') as f:
        pkl.dump(data, f)
        
def read_pkl(path_data):
    """读取pkl格式数据"""
    with open(path_data, 'rb') as f:
        data = pkl.load(f)
    return data

# %% [markdown]
# ## 类别特征+时间序列特征+累计交叉特征+embeding特征

# %%
df_train_cate = read_pkl(path_new_train_sp_cate)
df_val_cate = read_pkl(path_new_test_sp_cate)

df_train_time_sequence = read_pkl(path_new_train_time_sequence)
df_val_time_sequence = read_pkl(path_new_test_time_sequence)

df_train_cumsum = read_pkl(path_new_train_cumsum)
df_val_cumsum = read_pkl(path_new_test_cumsum)

df_train_embeding = read_pkl(path_new_train_embeding)
df_val_embeding = read_pkl(path_new_test_embeding)

df_raw_train = pd.read_csv(path_train)
df_raw_val  = pd.read_csv(path_test)

# %% [markdown]
# ## 类别特征+embeding特征

# %% [markdown]
# ### 数据集构造

# %%
df_row_train = pd.merge(left=df_train_cate, right=df_train_embeding, on='id')
df_row_val = pd.merge(left=df_val_cate, right=df_val_embeding, on='id')

df_row_train = pd.merge(left=df_row_train, right=df_raw_train[['id', y_label]], on='id')
df_row_val = pd.merge(left=df_row_val, right=df_raw_val[['id']], on='id')

# %%
feats = df_row_train.columns
feats = feats.drop(['id',y_label])

df_train = df_row_train
df_test = df_row_val

# %% [markdown]
# ### lightgbm

# %%
params = {
    'learning_rate': 0.05,
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'num_leaves': 31,
    'verbose': -1,
    'seed': 2222,
    'n_jobs': -1,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.9,
    'bagging_freq': 4,
    # 'min_child_weight': 10,
}

res_sort_col = 'id'

# %%
fold_num = 5
seeds = [2022]
oof = np.zeros(len(df_train))
importance = 0
pred_y = pd.DataFrame()
score = []


for seed in seeds:
    kf = StratifiedKFold(n_splits=fold_num, shuffle=True, random_state=seed)
    for fold, (train_idx, val_idx) in enumerate(kf.split(df_train[feats], df_train[y_label])):
        print('-----------', fold)
        # 数据集构造
        train = lgb.Dataset(df_train.loc[train_idx, feats],
                            df_train.loc[train_idx, y_label]
                           )
        val = lgb.Dataset(df_train.loc[val_idx, feats],
                          df_train.loc[val_idx, y_label]
                         )
        # 模型训练
        model = lgb.train(params, train, valid_sets=[train, val], 
                          num_boost_round=20000, early_stopping_rounds=100, verbose_eval=10)
        
        # 结果及得分获取
        oof[val_idx] += model.predict(df_train.loc[val_idx, feats]) / len(seeds)
        pred_y['fold_%d_seed_%d' % (fold, seed)] = model.predict(df_test[feats])
        importance += model.feature_importance(importance_type='gain') / fold_num
        score.append(auc(df_train.loc[val_idx, y_label], model.predict(df_train.loc[val_idx, feats])))

# 特征重要性获取
feats_importance = pd.DataFrame()
feats_importance['name'] = feats
feats_importance['importance'] = importance
display(feats_importance.sort_values('importance', ascending=False)[:30])

# 训练集得分效果
df_train['oof'] = oof
print('训练集AUC均值：{}, 训练集合AUC方差: {}'.format(np.mean(score), np.std(score)))

# 测试集合结果输出
score = np.mean(score)
df_test[y_label] = pred_y.mean(axis=1).values
df_test = df_test.sort_values(res_sort_col).reset_index(drop=True)

if not os.path.exists(path_results_version):
    os.makedirs(path_results_version)

# 结果保存
sub = pd.read_csv(path_sample_submission)
sub[y_label] = df_test[y_label].values
sub.to_csv(os.path.join(path_results_version,time.strftime('lgb_%Y%m%d%H%M_')+'%.5f.csv'%score), index=False)
# Out:
# ----------- 0
# Training until validation scores don't improve for 100 rounds
# [10]	training's auc: 0.758452	valid_1's auc: 0.738763
# [20]	training's auc: 0.762684	valid_1's auc: 0.741984
# [30]	training's auc: 0.770427	valid_1's auc: 0.74137
# [40]	training's auc: 0.773129	valid_1's auc: 0.741892
# [50]	training's auc: 0.77483	valid_1's auc: 0.740863
# [60]	training's auc: 0.776735	valid_1's auc: 0.740952
# [70]	training's auc: 0.780556	valid_1's auc: 0.740324
# [80]	training's auc: 0.783058	valid_1's auc: 0.739869
# [90]	training's auc: 0.785157	valid_1's auc: 0.739258
# [100]	training's auc: 0.787264	valid_1's auc: 0.738601
# [110]	training's auc: 0.789324	valid_1's auc: 0.739396
# Early stopping, best iteration is:
# [17]	training's auc: 0.761452	valid_1's auc: 0.743331
# ----------- 1
# Training until validation scores don't improve for 100 rounds
# [10]	training's auc: 0.759899	valid_1's auc: 0.731119
# [20]	training's auc: 0.764807	valid_1's auc: 0.730202
# [30]	training's auc: 0.771191	valid_1's auc: 0.731434
# [40]	training's auc: 0.773333	valid_1's auc: 0.731953
# [50]	training's auc: 0.775677	valid_1's auc: 0.730926
# [60]	training's auc: 0.776963	valid_1's auc: 0.730334
# [70]	training's auc: 0.781232	valid_1's auc: 0.72973
# [80]	training's auc: 0.785184	valid_1's auc: 0.729704
# [90]	training's auc: 0.787027	valid_1's auc: 0.72941
# [100]	training's auc: 0.789374	valid_1's auc: 0.728886
# [110]	training's auc: 0.791897	valid_1's auc: 0.729202
# [120]	training's auc: 0.794137	valid_1's auc: 0.728684
# [130]	training's auc: 0.796679	valid_1's auc: 0.727461
# Early stopping, best iteration is:
# [39]	training's auc: 0.77316	valid_1's auc: 0.73214
# ----------- 2
# Training until validation scores don't improve for 100 rounds
# [10]	training's auc: 0.75902	valid_1's auc: 0.739621
# [20]	training's auc: 0.766251	valid_1's auc: 0.736001
# [30]	training's auc: 0.770534	valid_1's auc: 0.735335
# [40]	training's auc: 0.773765	valid_1's auc: 0.73638
# [50]	training's auc: 0.776024	valid_1's auc: 0.736671
# [60]	training's auc: 0.779003	valid_1's auc: 0.736954
# [70]	training's auc: 0.781843	valid_1's auc: 0.736579
# [80]	training's auc: 0.783515	valid_1's auc: 0.736374
# [90]	training's auc: 0.785506	valid_1's auc: 0.735815
# [100]	training's auc: 0.787424	valid_1's auc: 0.736151
# Early stopping, best iteration is:
# [4]	training's auc: 0.748892	valid_1's auc: 0.742378
# ----------- 3
# Training until validation scores don't improve for 100 rounds
# [10]	training's auc: 0.759991	valid_1's auc: 0.737383
# [20]	training's auc: 0.764912	valid_1's auc: 0.738374
# [30]	training's auc: 0.771013	valid_1's auc: 0.737649
# [40]	training's auc: 0.774829	valid_1's auc: 0.737376
# [50]	training's auc: 0.776748	valid_1's auc: 0.736797
# [60]	training's auc: 0.778468	valid_1's auc: 0.736615
# [70]	training's auc: 0.780946	valid_1's auc: 0.736683
# [80]	training's auc: 0.785654	valid_1's auc: 0.735669
# [90]	training's auc: 0.787163	valid_1's auc: 0.735082
# [100]	training's auc: 0.789733	valid_1's auc: 0.733378
# Early stopping, best iteration is:
# [4]	training's auc: 0.749992	valid_1's auc: 0.738679
# ----------- 4
# Training until validation scores don't improve for 100 rounds
# [10]	training's auc: 0.755717	valid_1's auc: 0.741033
# [20]	training's auc: 0.760376	valid_1's auc: 0.738877
# [30]	training's auc: 0.768269	valid_1's auc: 0.735652
# [40]	training's auc: 0.773606	valid_1's auc: 0.733648
# [50]	training's auc: 0.776431	valid_1's auc: 0.734724
# [60]	training's auc: 0.779378	valid_1's auc: 0.734924
# [70]	training's auc: 0.781595	valid_1's auc: 0.733476
# [80]	training's auc: 0.78545	valid_1's auc: 0.735051
# [90]	training's auc: 0.788074	valid_1's auc: 0.734594
# [100]	training's auc: 0.792308	valid_1's auc: 0.733801
# [110]	training's auc: 0.794554	valid_1's auc: 0.733328
# Early stopping, best iteration is:
# [10]	training's auc: 0.755717	valid_1's auc: 0.741033
#                         name    importance
# 8       http_status_code_woe  25445.669012
# 13            ip_transform_4   4914.077605
# 56        http_status_code_2   3013.790613
# 11            ip_transform_2   2345.830805
# 12            ip_transform_3   1881.423259
# 14            ip_transform_5   1838.462713
# 23    device_num_transform_4   1758.107997
# 15               user_name_1   1573.386370
# 2             department_woe   1271.117599
# 18               user_name_4    994.710086
# 5                    url_woe    957.457386
# 19               user_name_5    633.477960
# 10            ip_transform_1    525.947653
# 21    device_num_transform_2    518.896543
# 22    device_num_transform_3    467.818114
# 17               user_name_3    369.123757
# 16               user_name_2    300.752607
# 24    device_num_transform_5    260.785620
# 20    device_num_transform_1    218.119811
# 1             os_version_woe    186.302678
# 34         browser_version_5    135.125962
# 4   log_system_transform_woe    117.146538
# 30         browser_version_1    115.217253
# 58        http_status_code_4     94.334003
# 60                 op_city_1     84.077160
# 32         browser_version_3     63.788633
# 33         browser_version_4     63.600256
# 64                 op_city_5     56.444600
# 31         browser_version_2     53.457366
# 29              department_5     50.808128
# 训练集AUC均值：0.7395121660004447, 训练集合AUC方差: 0.0040036818046200245

# %% [markdown]
# ## 类别特征+embeding特征+累计交叉特征

# %% [markdown]
# ### 数据集构造

# %%
df_row_train = pd.merge(left=df_train_cate, right=df_train_embeding, on='id')
df_row_val = pd.merge(left=df_val_cate, right=df_val_embeding, on='id')

df_row_train = pd.merge(left=df_row_train, right=df_raw_train[['id', y_label]], on='id')
df_row_val = pd.merge(left=df_row_val, right=df_raw_val[['id']], on='id')


df_row_train = pd.merge(left=df_row_train, right=df_train_cumsum, on='id')
df_row_val = pd.merge(left=df_row_val, right=df_val_cumsum, on='id')

# %%
feats = df_row_train.columns
feats = feats.drop(['id',y_label])

df_train = df_row_train
df_test = df_row_val

# %% [markdown]
# ### lightgbm

# %%
params = {
    'learning_rate': 0.05,
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'num_leaves': 31,
    'verbose': -1,
    'seed': 2222,
    'n_jobs': -1,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.9,
    'bagging_freq': 4,
    # 'min_child_weight': 10,
}

res_sort_col = 'id'

# %%
fold_num = 5
seeds = [2022]
oof = np.zeros(len(df_train))
importance = 0
pred_y = pd.DataFrame()
score = []


for seed in seeds:
    kf = StratifiedKFold(n_splits=fold_num, shuffle=True, random_state=seed)
    for fold, (train_idx, val_idx) in enumerate(kf.split(df_train[feats], df_train[y_label])):
        print('-----------', fold)
        # 数据集构造
        train = lgb.Dataset(df_train.loc[train_idx, feats],
                            df_train.loc[train_idx, y_label]
                           )
        val = lgb.Dataset(df_train.loc[val_idx, feats],
                          df_train.loc[val_idx, y_label]
                         )
        # 模型训练
        model = lgb.train(params, train, valid_sets=[train, val], 
                          num_boost_round=20000, early_stopping_rounds=100, verbose_eval=10)
        
        # 结果及得分获取
        oof[val_idx] += model.predict(df_train.loc[val_idx, feats]) / len(seeds)
        pred_y['fold_%d_seed_%d' % (fold, seed)] = model.predict(df_test[feats])
        importance += model.feature_importance(importance_type='gain') / fold_num
        score.append(auc(df_train.loc[val_idx, y_label], model.predict(df_train.loc[val_idx, feats])))

# 特征重要性获取
feats_importance = pd.DataFrame()
feats_importance['name'] = feats
feats_importance['importance'] = importance
display(feats_importance.sort_values('importance', ascending=False)[:30])

# 训练集得分效果
df_train['oof'] = oof
print('训练集AUC均值：{}, 训练集合AUC方差: {}'.format(np.mean(score), np.std(score)))

# 测试集合结果输出
score = np.mean(score)
df_test[y_label] = pred_y.mean(axis=1).values
df_test = df_test.sort_values(res_sort_col).reset_index(drop=True)

if not os.path.exists(path_results_version):
    os.makedirs(path_results_version)

# 结果保存
sub = pd.read_csv(path_sample_submission)
sub[y_label] = df_test[y_label].values
sub.to_csv(os.path.join(path_results_version,time.strftime('lgb_%Y%m%d%H%M_')+'%.5f.csv'%score), index=False)
# Out:
# ----------- 0
# Training until validation scores don't improve for 100 rounds
# [10]	training's auc: 0.936057	valid_1's auc: 0.930122
# [20]	training's auc: 0.941683	valid_1's auc: 0.934562
# [30]	training's auc: 0.944986	valid_1's auc: 0.937224
# [40]	training's auc: 0.950212	valid_1's auc: 0.936045
# [50]	training's auc: 0.955722	valid_1's auc: 0.935931
# [60]	training's auc: 0.959873	valid_1's auc: 0.936244
# [70]	training's auc: 0.965136	valid_1's auc: 0.936832
# [80]	training's auc: 0.969845	valid_1's auc: 0.938157
# [90]	training's auc: 0.973701	valid_1's auc: 0.937769
# [100]	training's auc: 0.976844	valid_1's auc: 0.937828
# [110]	training's auc: 0.979062	valid_1's auc: 0.937445
# [120]	training's auc: 0.980969	valid_1's auc: 0.936657
# [130]	training's auc: 0.983019	valid_1's auc: 0.936854
# [140]	training's auc: 0.984258	valid_1's auc: 0.937117
# [150]	training's auc: 0.985249	valid_1's auc: 0.937092
# [160]	training's auc: 0.986185	valid_1's auc: 0.936797
# [170]	training's auc: 0.987646	valid_1's auc: 0.937108
# [180]	training's auc: 0.988418	valid_1's auc: 0.937172
# Early stopping, best iteration is:
# [82]	training's auc: 0.971082	valid_1's auc: 0.938299
# ----------- 1
# Training until validation scores don't improve for 100 rounds
# [10]	training's auc: 0.934577	valid_1's auc: 0.931958
# [20]	training's auc: 0.943129	valid_1's auc: 0.9331
# [30]	training's auc: 0.946102	valid_1's auc: 0.933053
# [40]	training's auc: 0.948949	valid_1's auc: 0.934127
# [50]	training's auc: 0.952368	valid_1's auc: 0.933911
# [60]	training's auc: 0.957235	valid_1's auc: 0.935648
# [70]	training's auc: 0.965342	valid_1's auc: 0.934289
# [80]	training's auc: 0.969957	valid_1's auc: 0.935147
# [90]	training's auc: 0.974112	valid_1's auc: 0.935639
# [100]	training's auc: 0.975972	valid_1's auc: 0.934694
# [110]	training's auc: 0.97907	valid_1's auc: 0.933876
# [120]	training's auc: 0.981017	valid_1's auc: 0.934299
# [130]	training's auc: 0.982445	valid_1's auc: 0.933591
# [140]	training's auc: 0.98385	valid_1's auc: 0.933448
# [150]	training's auc: 0.984918	valid_1's auc: 0.933484
# [160]	training's auc: 0.98597	valid_1's auc: 0.933914
# [170]	training's auc: 0.987089	valid_1's auc: 0.933614
# [180]	training's auc: 0.988132	valid_1's auc: 0.934445
# Early stopping, best iteration is:
# [85]	training's auc: 0.972473	valid_1's auc: 0.936459
# ----------- 2
# Training until validation scores don't improve for 100 rounds
# [10]	training's auc: 0
# 1511  op_month_ip_transform_http_status_code_200_cumsum    3689.394664
# 289                    system_op_days_ip_type_内网_cumsum    3361.328172
# 136     system_system_op_times_groups_ip_type_内网_cumsum    1870.916585
# 746         op_times_groups_user_name_ip_type_内网_cumsum    1128.346021
# 122    system_system_op_times_groups_os_type_win_cumsum     842.668982
# 234                 system_op_days_department_rd_cumsum     641.184217
# 228                               system_op_days_cumsum     586.654118
# 229                    system_op_days_error_code_cumsum     572.552226
# 275                   system_op_days_os_type_win_cumsum     560.301470
# 75                 system_system_op_times_groups_cumsum     527.981235
# 81    system_system_op_times_groups_department_rd_cu...     458.006660
# 290         system_op_days_ip_type_内网_error_code_cumsum     426.850189
# 1202                op_days_user_name_ip_type_内网_cumsum     397.111599
# 334   system_op_days_log_system_transform_nHrKgKdJ1M...     346.715610
# 181   system_system_op_times_groups_log_system_trans...     317.193556
# 682   op_times_groups_ip_transform_url_wpsdoc.xxx.co...     291.345005
# 1294                op_days_device_num_transform_cumsum     284.467624
# 85    system_system_op_times_groups_department_sales...     249.302849
# 673   op_times_groups_ip_transform_url_xxx.com/login...     222.663129
# 280              system_op_days_os_version_win10_cumsum     205.879229
# 751   op_times_groups_user_name_http_status_code_200...     200.780998
# 534                 op_times_groups_ip_transform_cumsum     197.230133
# 1055   op_days_ip_transform_http_status_code_200_cumsum     196.702398
# 训练集AUC均值：0.9388582425174793, 训练集合AUC方差: 0.0018082451249107742

# %% [markdown]
# ## 类别特征+embeding特征+时间序列特征

# %% [markdown]
# ### 数据集构造

# %%
df_row_train = pd.merge(left=df_train_cate, right=df_train_embeding, on='id')
df_row_val = pd.merge(left=df_val_cate, right=df_val_embeding, on='id')

df_row_train = pd.merge(left=df_row_train, right=df_raw_train[['id', y_label]], on='id')
df_row_val = pd.merge(left=df_row_val, right=df_raw_val[['id']], on='id')


df_row_train = pd.merge(left=df_row_train, right=df_train_time_sequence, on='id')
df_row_val = pd.merge(left=df_row_val, right=df_val_time_sequence, on='id')

# %%
feats = df_row_train.columns
feats = feats.drop(['id',y_label])

df_train = df_row_train
df_test = df_row_val

# %% [markdown]
# ### lightgbm

# %%
params = {
    'learning_rate': 0.05,
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'num_leaves': 31,
    'verbose': -1,
    'seed': 2222,
    'n_jobs': -1,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.9,
    'bagging_freq': 4,
    # 'min_child_weight': 10,
}

res_sort_col = 'id'

# %%
fold_num = 5
seeds = [2022]
oof = np.zeros(len(df_train))
importance = 0
pred_y = pd.DataFrame()
score = []


for seed in seeds:
    kf = StratifiedKFold(n_splits=fold_num, shuffle=True, random_state=seed)
    for fold, (train_idx, val_idx) in enumerate(kf.split(df_train[feats], df_train[y_label])):
        print('-----------', fold)
        # 数据集构造
        train = lgb.Dataset(df_train.loc[train_idx, feats],
                            df_train.loc[train_idx, y_label]
                           )
        val = lgb.Dataset(df_train.loc[val_idx, feats],
                          df_train.loc[val_idx, y_label]
                         )
        # 模型训练
        model = lgb.train(params, train, valid_sets=[train, val], 
                          num_boost_round=20000, early_stopping_rounds=100, verbose_eval=10)
        
        # 结果及得分获取
        oof[val_idx] += model.predict(df_train.loc[val_idx, feats]) / len(seeds)
        pred_y['fold_%d_seed_%d' % (fold, seed)] = model.predict(df_test[feats])
        importance += model.feature_importance(importance_type='gain') / fold_num
        score.append(auc(df_train.loc[val_idx, y_label], model.predict(df_train.loc[val_idx, feats])))

# 特征重要性获取
feats_importance = pd.DataFrame()
feats_importance['name'] = feats
feats_importance['importance'] = importance
display(feats_importance.sort_values('importance', ascending=False)[:30])

# 训练集得分效果
df_train['oof'] = oof
print('训练集AUC均值：{}, 训练集合AUC方差: {}'.format(np.mean(score), np.std(score)))

# 测试集合结果输出
score = np.mean(score)
df_test[y_label] = pred_y.mean(axis=1).values
df_test = df_test.sort_values(res_sort_col).reset_index(drop=True)

if not os.path.exists(path_results_version):
    os.makedirs(path_results_version)

# 结果保存
sub = pd.read_csv(path_sample_submission)
sub[y_label] = df_test[y_label].values
sub.to_csv(os.path.join(path_results_version,time.strftime('lgb_%Y%m%d%H%M_')+'%.5f.csv'%score), index=False)
# Out:
# ----------- 0
# Training until validation scores don't improve for 100 rounds
# [10]	training's auc: 0.939067	valid_1's auc: 0.931964
# [20]	training's auc: 0.944139	valid_1's auc: 0.934712
# [30]	training's auc: 0.946098	valid_1's auc: 0.937564
# [40]	training's auc: 0.953647	valid_1's auc: 0.939686
# [50]	training's auc: 0.961524	valid_1's auc: 0.939035
# [60]	training's auc: 0.970067	valid_1's auc: 0.939733
# [70]	training's auc: 0.978666	valid_1's auc: 0.937832
# [80]	training's auc: 0.984348	valid_1's auc: 0.93724
# [90]	training's auc: 0.987898	valid_1's auc: 0.937215
# [100]	training's auc: 0.98971	valid_1's auc: 0.936611
# [110]	training's auc: 0.991844	valid_1's auc: 0.93518
# [120]	training's auc: 0.99309	valid_1's auc: 0.935398
# [130]	training's auc: 0.993901	valid_1's auc: 0.935262
# [140]	training's auc: 0.994607	valid_1's auc: 0.935005
# [150]	training's auc: 0.995188	valid_1's auc: 0.935716
# Early stopping, best iteration is:
# [58]	training's auc: 0.967159	valid_1's auc: 0.941727
# ----------- 1
# Training until validation scores don't improve for 100 rounds
# [10]	training's auc: 0
# [90]	training's auc: 0.987501	valid_1's auc: 0.944251
# [100]	training's auc: 0.990118	valid_1's auc: 0.94445
# [110]	training's auc: 0.991807	valid_1's auc: 0.944486
# [120]	training's auc: 0.992819	valid_1's auc: 0.944389
# [130]	training's auc: 0.993698	valid_1's auc: 0.943964
# [140]	training's auc: 0.994302	valid_1's auc: 0.944341
# [150]	training's auc: 0.994877	valid_1's auc: 0.944149
# [160]	training's auc: 0.995448	valid_1's auc: 0.944659
# [170]	training's auc: 0.995821	valid_1's auc: 0.945324
# [180]	training's auc: 0.996104	valid_1's auc: 0.945518
# [190]	training's auc: 0.996353	valid_1's auc: 0.945643
# [200]	training's auc: 0.996613	valid_1's auc: 0.945064
# [210]	training's auc: 0.996848	valid_1's auc: 0.944276
# [220]	training's auc: 0.997036	valid_1's auc: 0.944021
# [230]	training's auc: 0.997214	valid_1's auc: 0.943607
# [240]	training's auc: 0.997412	valid_1's auc: 0.943335
# [250]	training's auc: 0.997603	valid_1's auc: 0.943564
# [260]	training's auc: 0.997787	valid_1's auc: 0.943385
# [270]	training's auc: 0.997996	valid_1's auc: 0.94371
# [280]	training's auc: 0.998192	valid_1's auc: 0.943396
# Early stopping, best iteration is:
# [184]	training's auc: 0.996194	valid_1's auc: 0.945868
# ----------- 4
# Training until validation scores don't improve for 100 rounds
# [10]	training's auc: 0.939247	valid_1's auc: 0.933223
# [20]	training's auc: 0.943829	valid_1's auc: 0.93868
# [30]	training's auc: 0.945935	valid_1's auc: 0.939596
# [40]	training's auc: 0.953594	valid_1's auc: 0.939344
# [50]	training's auc: 0.967458	valid_1's auc: 0.940463
# [60]	training's auc: 0.975778	valid_1's auc: 0.938666
# [70]	training's auc: 0.98101	valid_1's auc: 0.937765
# [80]	training's auc: 0.984056	valid_1's auc: 0.937944
# [90]	training's auc: 0.98746	valid_1's auc: 0.938065
# [100]	training's auc: 0.989635	valid_1's auc: 0.939431
# [110]	training's auc: 0.991505	valid_1's auc: 0.938512
# [120]	training's auc: 0.992426	valid_1's auc: 0.939504
# [130]	training's auc: 0.993242	valid_1's auc: 0.94033
# [140]	training's auc: 0.994133	valid_1's auc: 0.940329
# Early stopping, best iteration is:
# [44]	training's auc: 0.961815	valid_1's auc: 0.941787
#                                               name    importance
# 417           avg_ip_type_system_op_diff_second1_3  58303.482373
# 146      max_ip_transform_system_op_diff_second1_6  48684.987602
# 148      std_ip_transform_system_op_diff_second1_6  26081.620739
# 452  avg_http_status_code_system_op_diff_second1_3  19733.158900
# 102                   avg_3_system_op_diff_second1   6223.500305
# 144      avg_ip_transform_system_op_diff_second1_6   5222.421159
# 95                            op_datetime_hour_cos   3251.305075
# 629      max_ip_transform_system_op_diff_second2_3   3170.298232
# 78                          system_op_diff_second2   3027.829036
# 627      avg_ip_transform_system_op_diff_second2_3   2372.934506
# 907           avg_ip_type_system_op_diff_second2_3   2095.497351
# 82                                op_datetime_hour   1776.690379
# 909           max_ip_type_system_op_diff_second2_3   1599.663673
# 83                              op_datetime_minute   1279.745205
# 424           avg_ip_type_system_op_diff_second1_6   1132.658668
# 634      avg_ip_transform_system_op_diff_second2_6   1065.526388
# 29                                    department_5   1036.649149
# 75                                 op_diff_second1    960.115099
# 426           max_ip_type_system_op_diff_second1_6    835.228909
# 96                             op_datetime_day_sin    716.665631
# 631      std_ip_transform_system_op_diff_second2_3    591.868220
# 80                               op_datetime_month    573.733929
# 347           avg_os_type_system_op_diff_second1_3    550.927517
# 25                                    department_1    484.318031
# 418        median_ip_type_system_op_diff_second1_3    426.910931
# 94                            op_datetime_hour_sin    415.508932
# 930          max_ip_type_system_op_diff_second2_12    375.328592
# 86                           op_datetime_dayofweek    362.227976
# 592                   avg_3_system_op_diff_second2    359.592955
# 921           avg_ip_type_system_op_diff_second2_9    354.716962
# 训练集AUC均值：0.9427731176619718, 训练集合AUC方差: 0.002268804124952653

# %% [markdown]
# ## 类别特征+时间序列特征+累计交叉特征+embeding特征

# %% [markdown]
# ### 数据集构造

# %%
df_row_train = pd.merge(left=df_train_cate, right=df_train_embeding, on='id')
df_row_val = pd.merge(left=df_val_cate, right=df_val_embeding, on='id')

df_row_train = pd.merge(left=df_row_train, right=df_raw_train[['id', y_label]], on='id')
df_row_val = pd.merge(left=df_row_val, right=df_raw_val[['id']], on='id')


df_row_train = pd.merge(left=df_row_train, right=df_train_cumsum, on='id')
df_row_val = pd.merge(left=df_row_val, right=df_val_cumsum, on='id')

df_row_train = pd.merge(left=df_row_train, right=df_train_time_sequence, on='id')
df_row_val = pd.merge(left=df_row_val, right=df_val_time_sequence, on='id')

# %%
feats = df_row_train.columns
feats = feats.drop(['id',y_label])

df_train = df_row_train
df_test = df_row_val

# %% [markdown]
# ### lightgbm

# %%
len(feats)
# Out:
# 2909

# %%
feats = feats_importance.sort_values('importance', ascending=False)[:50].name.values

# %%
params = {
    'learning_rate': 0.05,
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'num_leaves': 31,
    'verbose': -1,
    'seed': 2222,
    'n_jobs': -1,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.9,
    'bagging_freq': 4,
    # 'min_child_weight': 10,
}

res_sort_col = 'id'

# %%
fold_num = 5
seeds = [2022]
oof = np.zeros(len(df_train))
importance = 0
pred_y = pd.DataFrame()
score = []


for seed in seeds:
    kf = StratifiedKFold(n_splits=fold_num, shuffle=True, random_state=seed)
    for fold, (train_idx, val_idx) in enumerate(kf.split(df_train[feats], df_train[y_label])):
        print('-----------', fold)
        # 数据集构造
        train = lgb.Dataset(df_train.loc[train_idx, feats],
                            df_train.loc[train_idx, y_label]
                           )
        val = lgb.Dataset(df_train.loc[val_idx, feats],
                          df_train.loc[val_idx, y_label]
                         )
        # 模型训练
        model = lgb.train(params, train, valid_sets=[train, val], 
                          num_boost_round=20000, early_stopping_rounds=100, verbose_eval=10)
        
        # 结果及得分获取
        oof[val_idx] += model.predict(df_train.loc[val_idx, feats]) / len(seeds)
        pred_y['fold_%d_seed_%d' % (fold, seed)] = model.predict(df_test[feats])
        importance += model.feature_importance(importance_type='gain') / fold_num
        score.append(auc(df_train.loc[val_idx, y_label], model.predict(df_train.loc[val_idx, feats])))

# 特征重要性获取
feats_importance = pd.DataFrame()
feats_importance['name'] = feats
feats_importance['importance'] = importance
display(feats_importance.sort_values('importance', ascending=False)[:30])

# 训练集得分效果
df_train['oof'] = oof
print('训练集AUC均值：{}, 训练集合AUC方差: {}'.format(np.mean(score), np.std(score)))

# 测试集合结果输出
score = np.mean(score)
df_test[y_label] = pred_y.mean(axis=1).values
df_test = df_test.sort_values(res_sort_col).reset_index(drop=True)

if not os.path.exists(path_results_version):
    os.makedirs(path_results_version)

# 结果保存
sub = pd.read_csv(path_sample_submission)
sub[y_label] = df_test[y_label].values
sub.to_csv(os.path.join(path_results_version,time.strftime('lgb_%Y%m%d%H%M_')+'%.5f.csv'%score), index=False)
# Out:
# ----------- 0
# Training until validation scores don't improve for 100 rounds
# [10]	training's auc: 0.938898	valid_1's auc: 0.933799
# [20]	training's auc: 0.942262	valid_1's auc: 0.939543
# [30]	training's auc: 0.944804	valid_1's auc: 0.940196
# [40]	training's auc: 0.94926	valid_1's auc: 0.939784
# [50]	training's auc: 0.954651	valid_1's auc: 0.941137
# [60]	training's auc: 0.960817	valid_1's auc: 0.940484
# [70]	training's auc: 0.965999	valid_1's auc: 0.941259
# [80]	training's auc: 0.973617	valid_1's auc: 0.939543
# [90]	training's auc: 0.978158	valid_1's auc: 0.939301
# [100]	training's auc: 0.981251	valid_1's auc: 0.938984
# [110]	training's auc: 0.984196	valid_1's auc: 0.937027
# [120]	training's auc: 0.986269	valid_1's auc: 0.936354
# [130]	training's auc: 0.987831	valid_1's auc: 0.935874
# [140]	training's auc: 0.989002	valid_1's auc: 0.935463
# [150]	training's auc: 0.990306	valid_1's auc: 0.935659
# [160]	training's auc: 0.991065	valid_1's auc: 0.935485
# Early stopping, best iteration is:
# [66]	training's auc: 0.963313	valid_1's auc: 0.942432
# ----------- 1
# Training until validation scores don't improve for 100 rounds
# [10]	training's auc: 0
# Training until validation scores don't improve for 100 rounds
# [10]	training's auc: 0.939934	valid_1's auc: 0.932248
# [20]	training's auc: 0.943181	valid_1's auc: 0.940321
# [30]	training's auc: 0.944436	valid_1's auc: 0.941296
# [40]	training's auc: 0.950625	valid_1's auc: 0.940293
# [50]	training's auc: 0.956855	valid_1's auc: 0.940543
# [60]	training's auc: 0.961937	valid_1's auc: 0.94183
# [70]	training's auc: 0.96852	valid_1's auc: 0.942237
# [80]	training's auc: 0.974144	valid_1's auc: 0.940701
# [90]	training's auc: 0.977711	valid_1's auc: 0.941149
# [100]	training's auc: 0.981273	valid_1's auc: 0.93981
# [110]	training's auc: 0.983488	valid_1's auc: 0.938858
# [120]	training's auc: 0.98533	valid_1's auc: 0.939244
# [130]	training's auc: 0.986982	valid_1's auc: 0.939302
# [140]	training's auc: 0.988373	valid_1's auc: 0.939226
# [150]	training's auc: 0.990094	valid_1's auc: 0.93912
# [160]	training's auc: 0.990885	valid_1's auc: 0.938902
# Early stopping, best iteration is:
# [64]	training's auc: 0.962868	valid_1's auc: 0.943364
#                                                  name    importance
# 0   system_system_op_times_groups_http_status_code...  79031.528516
# 1           max_ip_transform_system_op_diff_second1_6  34901.579985
# 2          system_op_days_http_status_code_200_cumsum  29736.124171
# 4           std_ip_transform_system_op_diff_second1_6  13452.206757
# 3                avg_ip_type_system_op_diff_second1_3   8118.926219
# 5                                    op_datetime_hour   6763.023510
# 6              avg_user_name_system_op_diff_second1_6   6337.156825
# 7           avg_ip_transform_system_op_diff_second1_6   3384.679099
# 8   op_times_groups_ip_transform_url_wpsdoc.xxx.co...   3221.451782
# 9                                op_datetime_hour_cos   2861.514054
# 14      avg_http_status_code_system_op_diff_second1_3   2408.728906
# 21          std_ip_transform_system_op_diff_second2_3   2116.441064
# 10            kurt_user_name_system_op_diff_second1_9   1870.980501
# 24               avg_ip_type_system_op_diff_second1_6   1829.122485
# 16                                    op_diff_second1   1646.132049
# 12                                       department_5   1643.376271
# 15                                 op_datetime_minute   1343.888791
# 19          std_ip_transform_system_op_diff_second1_3   1153.129597
# 25               max_ip_type_system_op_diff_second2_6   1083.912875
# 11            kurt_user_name_system_op_diff_second2_6   1060.754272
# 27  op_month_ip_transform_http_status_code_200_cumsum   1059.623936
# 46               min_ip_type_system_op_diff_second2_3   1052.094868
# 20         skew_ip_transform_system_op_diff_second2_3    919.075259
# 18  avg_device_num_transform_system_op_diff_second1_9    884.362251
# 13                       avg_3_system_op_diff_second1    790.076582
# 26                             op_datetime_minute_sin    780.822953
# 32               min_ip_type_system_op_diff_second2_9    730.628292
# 34                             system_op_diff_second2    715.492867
# 39  kurt_log_system_transform_system_op_diff_secon...    629.914423
# 23        skew_ip_transform_system_op_diff_second2_15    624.157265
# 训练集AUC均值：0.9436649119573186, 训练集合AUC方差: 0.0022388350250016186
