# %%
import os
import re
import pickle as pkl
import numpy as np
import pandas as pd
import datetime

import matplotlib.pyplot as plt
import seaborn as sns

import scorpyo as sp

from null_importance import get_null_importance

from gensim.models import word2vec


pd.set_option('max_rows', 500, 'max_columns', 200)

# %%
path_project = r'/Users/liliangshan/workspace/python/01_datasets/ccf_system_access_risk_identification'

# path dir
path_row_data = os.path.join(path_project, 'row_data')
path_new_data = os.path.join(path_project, 'new_data')
path_results  = os.path.join(path_project, 'results')
path_results_jupyter  = os.path.join(path_results, 'jupyter')

# path row_data
path_train = os.path.join(path_row_data, 'train.csv')
path_test  = os.path.join(path_row_data, 'evaluation_public.csv')
path_sample_submission = os.path.join(path_row_data, 'submit_example.csv')


path_new_train = os.path.join(path_new_data, 'train_lightgbm_20221014.csv')
path_new_test  = os.path.join(path_new_data, 'test_lightgbm_20221014.csv')

## results
path_output_report = os.path.join(path_results, '01_原始数据探察_20221014.xlsx')

y_label = "is_risk"

# %%
df_row_train = sp.read_data(path_train)
df_row_val  = sp.read_data(path_test)

df_row_train['url_sit'] = df_row_train['url'].map(lambda x: x.split('/')[0])
df_row_train['url_page'] = df_row_train['url'].map(lambda x: x.split('/')[1])

df_row_val['url_sit'] = df_row_val['url'].map(lambda x: x.split('/')[0])
df_row_val['url_page'] = df_row_val['url'].map(lambda x: x.split('/')[1])



df_train_info = df_row_train.copy().sort_values(by='op_datetime')

# %%
df = pd.concat([df_row_train, df_row_val]).reset_index(drop=True)
df = df.sort_values(by='op_datetime')

# 认证日期时间
df['op_datetime'] = pd.to_datetime(df['op_datetime'])
# 将数据分为每一天
df['op_days'] = df['op_datetime'].map(lambda x: x.strftime('%Y-%m-%d'))

# 按客户进行统计这次认证和上次认证的时间差
df['op_second'] = df['op_datetime']
df['op_second1'] = df.groupby('device_num_transform')['op_second'].shift(1)
df['op_diff_second1'] = (df['op_second'] - df['op_second1']).map(lambda x: x.total_seconds())
df['op_diff_second1_log'] = df['op_diff_second1'].apply(np.log)
df['op_diff_second1_log_log'] = df['op_diff_second1'].apply(np.log).apply(np.log)

df['op_diff_second1_tmp'] = df['op_diff_second1']>10
# 客户第几次登录
df['op_times_groups'] = df.groupby('device_num_transform')['op_diff_second1_tmp'].apply(lambda x: x.cumsum())

# 系统层面的一段时间
df['system_op_second'] = df['op_datetime']
df['system_op_second1'] = df['system_op_second'].shift(1)
df['system_op_diff_second1'] = (df['system_op_second'] - df['system_op_second1']).map(lambda x: x.total_seconds())

df['system_op_diff_second1_log'] = df['system_op_diff_second1'].apply(np.log)
df['system_op_diff_second1_log_log'] = df['system_op_diff_second1'].apply(np.log).apply(np.log)
df['system_op_diff_second1_tmp'] = df['system_op_diff_second1']>400
# 客户第几次登录
df['system_op_times_groups'] = df['system_op_diff_second1_tmp'].cumsum()

df = df.drop(columns=['op_second','op_second1','op_diff_second1_tmp', 
                      'system_op_second', 'system_op_second1', 'system_op_diff_second1_tmp'])

# %% [markdown]
# ## 生成词向量

# %%
col = 'url'

# %%
df_cols = df.groupby(['device_num_transform', 'op_days'])[col].agg(lambda x: " ".join(list(x)))
df_cols.head()
# Out:
# device_num_transform  op_days
# 01GOhHDp463z          2022-01-07    xxx.com/mail xxx.com/loginAuth xxx.com/github ...
#                       2022-01-10                                       xxx.com/github
#                       2022-01-11                                       xxx.com/github
#                       2022-01-12                                         xxx.com/mail
#                       2022-01-13    xxx.com/github xxx.com/loginAuth xxx.com/githu...
# Name: url, dtype: object

# %%
df_cols = df_cols.unstack()

# %%
df_cols.head()
# Out:
# op_days                                                      2022-01-07  \
# device_num_transform
# 01GOhHDp463z          xxx.com/mail xxx.com/loginAuth xxx.com/github ...
# 04F4iKnBDqb6          xxx.com/mail wpsdoc.xxx.com/kdocs work.xxx.com...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days              2022-01-08 2022-01-09      2022-01-10  \
# device_num_transform
# 01GOhHDp463z                NaN        NaN  xxx.com/github
# 04F4iKnBDqb6                NaN        NaN             NaN
# 04MrZwVR5Dh4                NaN        NaN             NaN
# 05DiseR8wyyh                NaN        NaN             NaN
# 05SghMEzzxQQ                NaN        NaN             NaN
#
# op_days                                     2022-01-11  \
# device_num_transform
# 01GOhHDp463z                            xxx.com/github
# 04F4iKnBDqb6          xxx.com/loginAuth xxx.com/github
# 04MrZwVR5Dh4                                       NaN
# 05DiseR8wyyh                                       NaN
# 05SghMEzzxQQ                                       NaN
#
# op_days                                                      2022-01-12  \
# device_num_transform
# 01GOhHDp463z                                               xxx.com/mail
# 04F4iKnBDqb6          work.xxx.com/task xxx.com/github xxx.com/login...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-01-13  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/loginAuth xxx.com/githu...
# 04F4iKnBDqb6                        xxx.com/loginAuth work.xxx.com/task
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-01-14  \
# device_num_transform
# 01GOhHDp463z                                                 xxx.com/oa
# 04F4iKnBDqb6          xxx.com/github xxx.com/github xxx.com/github x...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                   2022-01-15                     2022-01-16  \
# device_num_transform
# 01GOhHDp463z                     NaN  xxx.com/github xxx.com/github
# 04F4iKnBDqb6          xxx.com/github           wpsdoc.xxx.com/kdocs
# 04MrZwVR5Dh4                     NaN                            NaN
# 05DiseR8wyyh                     NaN                            NaN
# 05SghMEzzxQQ                     NaN                            NaN
#
# op_days                                           2022-01-17  \
# device_num_transform
# 01GOhHDp463z                       xxx.com/github xxx.com/oa
# 04F4iKnBDqb6          xxx.com/loginAuth wpsdoc.xxx.com/kdocs
# 04MrZwVR5Dh4                                             NaN
# 05DiseR8wyyh                                             NaN
# 05SghMEzzxQQ                                             NaN
#
# op_days                                        2022-01-18  \
# device_num_transform
# 01GOhHDp463z            xxx.com/mail wpsdoc.xxx.com/kdocs
# 04F4iKnBDqb6          wpsdoc.xxx.com/kdocs xxx.com/github
# 04MrZwVR5Dh4                                          NaN
# 05DiseR8wyyh                                          NaN
# 05SghMEzzxQQ                                          NaN
#
# op_days                                                      2022-01-19  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/mail work.xxx.com/task ...
# 04F4iKnBDqb6          wpsdoc.xxx.com/kdocs wpsdoc.xxx.com/kdocs xxx....
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-01-20  \
# device_num_transform
# 01GOhHDp463z              xxx.com/mail work.xxx.com/task xxx.com/github
# 04F4iKnBDqb6          xxx.com/github xxx.com/github xxx.com/loginAut...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                    2022-01-21  \
# device_num_transform
# 01GOhHDp463z                                           xxx.com/github
# 04F4iKnBDqb6          xxx.com/loginAuth xxx.com/github xxx.com/github
# 04MrZwVR5Dh4                                     xxx.com/getLoginType
# 05DiseR8wyyh                                                      NaN
# 05SghMEzzxQQ                                                      NaN
#
# op_days              2022-01-22      2022-01-23  \
# device_num_transform
# 01GOhHDp463z                NaN  xxx.com/github
# 04F4iKnBDqb6                NaN             NaN
# 04MrZwVR5Dh4                NaN             NaN
# 05DiseR8wyyh                NaN             NaN
# 05SghMEzzxQQ                NaN             NaN
#
# op_days                                                      2022-01-24  \
# device_num_transform
# 01GOhHDp463z                           work.xxx.com/task xxx.com/github
# 04F4iKnBDqb6          wpsdoc.xxx.com/kdocs xxx.com/github xxx.com/oa...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                   2022-01-25 2022-01-26  \
# device_num_transform
# 01GOhHDp463z          xxx.com/mail work.xxx.com/task        NaN
# 04F4iKnBDqb6             xxx.com/github xxx.com/mail        NaN
# 04MrZwVR5Dh4                                     NaN        NaN
# 05DiseR8wyyh                                     NaN        NaN
# 05SghMEzzxQQ                                     NaN        NaN
#
# op_days                                                      2022-01-27  \
# device_num_transform
# 01GOhHDp463z          work.xxx.com/task xxx.com/github work.xxx.com/...
# 04F4iKnBDqb6          xxx.com/mail xxx.com/github xxx.com/github xxx...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                             2022-01-28  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/mail xxx.com/mail
# 04F4iKnBDqb6                                    xxx.com/github
# 04MrZwVR5Dh4                                               NaN
# 05DiseR8wyyh                                               NaN
# 05SghMEzzxQQ                                               NaN
#
# op_days                                                      2022-01-29  \
# device_num_transform
# 01GOhHDp463z          xxx.com/loginAuth xxx.com/mail xxx.com/loginAu...
# 04F4iKnBDqb6          xxx.com/github wpsdoc.xxx.com/kdocs wpsdoc.xxx...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-01-30  \
# device_num_transform
# 01GOhHDp463z                   xxx.com/github xxx.com/mail xxx.com/mail
# 04F4iKnBDqb6          xxx.com/github wpsdoc.xxx.com/kdocs wpsdoc.xxx...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days              2022-01-31    2022-02-01 2022-02-02 2022-02-03  \
# device_num_transform
# 01GOhHDp463z                NaN  xxx.com/mail        NaN        NaN
# 04F4iKnBDqb6                NaN           NaN        NaN        NaN
# 04MrZwVR5Dh4                NaN           NaN        NaN        NaN
# 05DiseR8wyyh                NaN           NaN        NaN        NaN
# 05SghMEzzxQQ                NaN           NaN        NaN        NaN
#
# op_days              2022-02-04 2022-02-05      2022-02-06  \
# device_num_transform
# 01GOhHDp463z                NaN        NaN  xxx.com/github
# 04F4iKnBDqb6                NaN        NaN             NaN
# 04MrZwVR5Dh4                NaN        NaN             NaN
# 05DiseR8wyyh                NaN        NaN             NaN
# 05SghMEzzxQQ                NaN        NaN             NaN
#
# op_days                         2022-02-07  \
# device_num_transform
# 01GOhHDp463z                           NaN
# 04F4iKnBDqb6          wpsdoc.xxx.com/kdocs
# 04MrZwVR5Dh4                           NaN
# 05DiseR8wyyh                           NaN
# 05SghMEzzxQQ                           NaN
#
# op_days                                                      2022-02-08  \
# device_num_transform
# 01GOhHDp463z                 xxx.com/mail xxx.com/github xxx.com/github
# 04F4iKnBDqb6          xxx.com/mail xxx.com/loginAuth work.xxx.com/ta...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-02-09  \
# device_num_transform
# 01GOhHDp463z          wpsdoc.xxx.com/kdocs wpsdoc.xxx.com/download w...
# 04F4iKnBDqb6                           xxx.com/github work.xxx.com/task
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-02-10  \
# device_num_transform
# 01GOhHDp463z          xxx.com/mail xxx.com/github xxx.com/github xxx...
# 04F4iKnBDqb6          xxx.com/github work.xxx.com/task xxx.com/mail ...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-02-11  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github wpsdoc.xxx.com/kdocs xxx.com/gi...
# 04F4iKnBDqb6                                                        NaN
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days              2022-02-12 2022-02-13  \
# device_num_transform
# 01GOhHDp463z                NaN        NaN
# 04F4iKnBDqb6                NaN        NaN
# 04MrZwVR5Dh4                NaN        NaN
# 05DiseR8wyyh                NaN        NaN
# 05SghMEzzxQQ                NaN        NaN
#
# op_days                                                      2022-02-14  \
# device_num_transform
# 01GOhHDp463z                                             xxx.com/github
# 04F4iKnBDqb6          xxx.com/github xxx.com/github xxx.com/mail xxx...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-02-15  \
# device_num_transform
# 01GOhHDp463z                                                        NaN
# 04F4iKnBDqb6          work.xxx.com/task xxx.com/github wpsdoc.xxx.co...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                        2022-02-16  \
# device_num_transform
# 01GOhHDp463z                                 xxx.com/mail
# 04F4iKnBDqb6          xxx.com/github wpsdoc.xxx.com/kdocs
# 04MrZwVR5Dh4                                          NaN
# 05DiseR8wyyh                                          NaN
# 05SghMEzzxQQ                                          NaN
#
# op_days                                                      2022-02-17  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github wpsdoc.xxx.com/kdocs wpsdoc.xxx...
# 04F4iKnBDqb6                                             xxx.com/github
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                      2022-02-18 2022-02-19            2022-02-20  \
# device_num_transform
# 01GOhHDp463z          work.xxx.com/task        NaN  wpsdoc.xxx.com/kdocs
# 04F4iKnBDqb6                        NaN        NaN                   NaN
# 04MrZwVR5Dh4                        NaN        NaN                   NaN
# 05DiseR8wyyh                        NaN        NaN                   NaN
# 05SghMEzzxQQ                        NaN        NaN                   NaN
#
# op_days                                                      2022-02-21  \
# device_num_transform
# 01GOhHDp463z          work.xxx.com/task xxx.com/github wpsdoc.xxx.co...
# 04F4iKnBDqb6          xxx.com/github xxx.com/mail wpsdoc.xxx.com/kdo...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                   2022-02-22  \
# device_num_transform
# 01GOhHDp463z          xxx.com/mail work.xxx.com/task
# 04F4iKnBDqb6               xxx.com/github xxx.com/oa
# 04MrZwVR5Dh4                                     NaN
# 05DiseR8wyyh                                     NaN
# 05SghMEzzxQQ                                     NaN
#
# op_days                                                      2022-02-23  \
# device_num_transform
# 01GOhHDp463z              work.xxx.com/task xxx.com/github xxx.com/mail
# 04F4iKnBDqb6          xxx.com/github xxx.com/mail xxx.com/github xxx...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                    2022-02-24  \
# device_num_transform
# 01GOhHDp463z                            xxx.com/github xxx.com/github
# 04F4iKnBDqb6          xxx.com/github xxx.com/loginAuth xxx.com/github
# 04MrZwVR5Dh4                                                      NaN
# 05DiseR8wyyh                                                      NaN
# 05SghMEzzxQQ                                                      NaN
#
# op_days              2022-02-25 2022-02-26 2022-02-27  \
# device_num_transform
# 01GOhHDp463z                NaN        NaN        NaN
# 04F4iKnBDqb6                NaN        NaN        NaN
# 04MrZwVR5Dh4                NaN        NaN        NaN
# 05DiseR8wyyh                NaN        NaN        NaN
# 05SghMEzzxQQ                NaN        NaN        NaN
#
# op_days                                                      2022-02-28  \
# device_num_transform
# 01GOhHDp463z          wpsdoc.xxx.com/kdocs wpsdoc.xxx.com/download w...
# 04F4iKnBDqb6          xxx.com/oa xxx.com/github work.xxx.com/task wo...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-03-01  \
# device_num_transform
# 01GOhHDp463z                                             xxx.com/github
# 04F4iKnBDqb6          xxx.com/github xxx.com/mail xxx.com/mail work....
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-03-02  \
# device_num_transform
# 01GOhHDp463z                                          work.xxx.com/task
# 04F4iKnBDqb6          xxx.com/mail xxx.com/loginAuth work.xxx.com/ta...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-03-03  \
# device_num_transform
# 01GOhHDp463z                           xxx.com/loginAuth xxx.com/github
# 04F4iKnBDqb6          xxx.com/oa xxx.com/oa xxx.com/github xxx.com/g...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-03-04  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/oa xxx.com/loginAuth xx...
# 04F4iKnBDqb6                                  xxx.com/mail xxx.com/mail
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                   2022-03-05 2022-03-06      2022-03-07  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github        NaN  xxx.com/github
# 04F4iKnBDqb6                     NaN        NaN             NaN
# 04MrZwVR5Dh4                     NaN        NaN             NaN
# 05DiseR8wyyh                     NaN        NaN             NaN
# 05SghMEzzxQQ                     NaN        NaN             NaN
#
# op_days                                        2022-03-08  \
# device_num_transform
# 01GOhHDp463z                                          NaN
# 04F4iKnBDqb6          wpsdoc.xxx.com/kdocs xxx.com/github
# 04MrZwVR5Dh4                                          NaN
# 05DiseR8wyyh                                          NaN
# 05SghMEzzxQQ                                          NaN
#
# op_days                                             2022-03-09  \
# device_num_transform
# 01GOhHDp463z                  xxx.com/loginAuth xxx.com/github
# 04F4iKnBDqb6          xxx.com/github xxx.com/mail xxx.com/mail
# 04MrZwVR5Dh4                                               NaN
# 05DiseR8wyyh                                               NaN
# 05SghMEzzxQQ                                               NaN
#
# op_days                                                      2022-03-10  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/mail xxx.com/github xxx...
# 04F4iKnBDqb6            xxx.com/github xxx.com/loginAuth xxx.com/github
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-03-11  \
# device_num_transform
# 01GOhHDp463z                                          work.xxx.com/task
# 04F4iKnBDqb6          wpsdoc.xxx.com/kdocs wpsdoc.xxx.com/download w...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days              2022-03-12 2022-03-13                   2022-03-14  \
# device_num_transform
# 01GOhHDp463z                NaN        NaN               xxx.com/github
# 04F4iKnBDqb6                NaN        NaN  xxx.com/mail xxx.com/github
# 04MrZwVR5Dh4                NaN        NaN                          NaN
# 05DiseR8wyyh                NaN        NaN                          NaN
# 05SghMEzzxQQ                NaN        NaN                          NaN
#
# op_days                                                      2022-03-15  \
# device_num_transform
# 01GOhHDp463z                                                        NaN
# 04F4iKnBDqb6          xxx.com/mail xxx.com/github xxx.com/github xxx...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                       xxx.com/getLoginType
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-03-16  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/mail xxx.com/loginAuth ...
# 04F4iKnBDqb6          work.xxx.com/task work.xxx.com/task xxx.com/oa...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-03-17  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github work.xxx.com/task work.xxx.com/...
# 04F4iKnBDqb6          xxx.com/github wpsdoc.xxx.com/kdocs xxx.com/gi...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-03-18  \
# device_num_transform
# 01GOhHDp463z          xxx.com/loginAuth xxx.com/mail xxx.com/oa work...
# 04F4iKnBDqb6                        xxx.com/loginAuth work.xxx.com/task
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                      2022-03-19 2022-03-20  \
# device_num_transform
# 01GOhHDp463z          work.xxx.com/task        NaN
# 04F4iKnBDqb6                        NaN        NaN
# 04MrZwVR5Dh4                        NaN        NaN
# 05DiseR8wyyh                        NaN        NaN
# 05SghMEzzxQQ                        NaN        NaN
#
# op_days                                                      2022-03-21  \
# device_num_transform
# 01GOhHDp463z          work.xxx.com/task work.xxx.com/task xxx.com/gi...
# 04F4iKnBDqb6                                             xxx.com/github
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-03-22  \
# device_num_transform
# 01GOhHDp463z                           xxx.com/loginAuth xxx.com/github
# 04F4iKnBDqb6          wpsdoc.xxx.com/kdocs xxx.com/mail wpsdoc.xxx.c...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-03-23  \
# device_num_transform
# 01GOhHDp463z                 xxx.com/github xxx.com/mail xxx.com/github
# 04F4iKnBDqb6          xxx.com/github xxx.com/github xxx.com/mail xxx...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-03-24  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github work.xxx.com/task work.xxx.com/...
# 04F4iKnBDqb6          xxx.com/mail xxx.com/mail xxx.com/github xxx.c...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                  2022-03-25 2022-03-26  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/github        NaN
# 04F4iKnBDqb6                         xxx.com/github        NaN
# 04MrZwVR5Dh4                                    NaN        NaN
# 05DiseR8wyyh                                    NaN        NaN
# 05SghMEzzxQQ                                    NaN        NaN
#
# op_days                   2022-03-27  \
# device_num_transform
# 01GOhHDp463z                     NaN
# 04F4iKnBDqb6          xxx.com/github
# 04MrZwVR5Dh4                     NaN
# 05DiseR8wyyh                     NaN
# 05SghMEzzxQQ                     NaN
#
# op_days                                                      2022-03-28  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/github work.xxx.com/tas...
# 04F4iKnBDqb6                           work.xxx.com/task xxx.com/github
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                        2022-03-29  \
# device_num_transform
# 01GOhHDp463z                               xxx.com/github
# 04F4iKnBDqb6          xxx.com/github wpsdoc.xxx.com/kdocs
# 04MrZwVR5Dh4                                          NaN
# 05DiseR8wyyh                                          NaN
# 05SghMEzzxQQ                                          NaN
#
# op_days                                                      2022-03-30  \
# device_num_transform
# 01GOhHDp463z                             xxx.com/mail work.xxx.com/task
# 04F4iKnBDqb6          xxx.com/loginAuth xxx.com/github xxx.com/githu...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                   2022-03-31  \
# device_num_transform
# 01GOhHDp463z                     NaN
# 04F4iKnBDqb6          xxx.com/github
# 04MrZwVR5Dh4                     NaN
# 05DiseR8wyyh                     NaN
# 05SghMEzzxQQ                     NaN
#
# op_days                                                      2022-04-01  \
# device_num_transform
# 01GOhHDp463z                                             xxx.com/github
# 04F4iKnBDqb6          wpsdoc.xxx.com/kdocs wpsdoc.xxx.com/download w...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                  2022-04-02  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github work.xxx.com/task xxx.com/mail
# 04F4iKnBDqb6               xxx.com/mail xxx.com/mail xxx.com/github
# 04MrZwVR5Dh4                                                    NaN
# 05DiseR8wyyh                                                    NaN
# 05SghMEzzxQQ                                                    NaN
#
# op_days               2022-04-03 2022-04-04 2022-04-05  \
# device_num_transform
# 01GOhHDp463z                 NaN        NaN        NaN
# 04F4iKnBDqb6          xxx.com/oa        NaN        NaN
# 04MrZwVR5Dh4                 NaN        NaN        NaN
# 05DiseR8wyyh                 NaN        NaN        NaN
# 05SghMEzzxQQ                 NaN        NaN        NaN
#
# op_days                                                      2022-04-06  \
# device_num_transform
# 01GOhHDp463z                  wpsdoc.xxx.com/kdocs wpsdoc.xxx.com/kdocs
# 04F4iKnBDqb6          wpsdoc.xxx.com/kdocs xxx.com/github work.xxx.c...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-04-07  \
# device_num_transform
# 01GOhHDp463z                           work.xxx.com/task xxx.com/github
# 04F4iKnBDqb6          xxx.com/oa xxx.com/loginAuth xxx.com/github xx...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-04-08  \
# device_num_transform
# 01GOhHDp463z          xxx.com/mail wpsdoc.xxx.com/kdocs wpsdoc.xxx.c...
# 04F4iKnBDqb6           wpsdoc.xxx.com/kdocs xxx.com/github xxx.com/mail
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days              2022-04-09 2022-04-10  \
# device_num_transform
# 01GOhHDp463z                NaN        NaN
# 04F4iKnBDqb6                NaN        NaN
# 04MrZwVR5Dh4                NaN        NaN
# 05DiseR8wyyh                NaN        NaN
# 05SghMEzzxQQ                NaN        NaN
#
# op_days                                             2022-04-11  \
# device_num_transform
# 01GOhHDp463z          xxx.com/oa xxx.com/github xxx.com/github
# 04F4iKnBDqb6                                    xxx.com/github
# 04MrZwVR5Dh4                                               NaN
# 05DiseR8wyyh                                               NaN
# 05SghMEzzxQQ                                               NaN
#
# op_days                                                      2022-04-12  \
# device_num_transform
# 01GOhHDp463z          wpsdoc.xxx.com/kdocs wpsdoc.xxx.com/download w...
# 04F4iKnBDqb6                               work.xxx.com/task xxx.com/oa
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-04-13  \
# device_num_transform
# 01GOhHDp463z          work.xxx.com/task xxx.com/mail xxx.com/github ...
# 04F4iKnBDqb6                                             xxx.com/github
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                 2022-04-14  \
# device_num_transform
# 01GOhHDp463z                           xxx.com/mail xxx.com/github
# 04F4iKnBDqb6          xxx.com/github xxx.com/github xxx.com/github
# 04MrZwVR5Dh4                                                   NaN
# 05DiseR8wyyh                                                   NaN
# 05SghMEzzxQQ                                                   NaN
#
# op_days                                                      2022-04-15  \
# device_num_transform
# 01GOhHDp463z          wpsdoc.xxx.com/kdocs wpsdoc.xxx.com/download w...
# 04F4iKnBDqb6                        xxx.com/loginAuth work.xxx.com/task
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days              2022-04-16      2022-04-17  \
# device_num_transform
# 01GOhHDp463z                NaN             NaN
# 04F4iKnBDqb6                NaN  xxx.com/github
# 04MrZwVR5Dh4                NaN             NaN
# 05DiseR8wyyh                NaN             NaN
# 05SghMEzzxQQ                NaN             NaN
#
# op_days                                                      2022-04-18  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github work.xxx.com/task xxx.com/githu...
# 04F4iKnBDqb6          xxx.com/loginAuth wpsdoc.xxx.com/kdocs xxx.com...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-04-19  \
# device_num_transform
# 01GOhHDp463z                                                 xxx.com/oa
# 04F4iKnBDqb6          wpsdoc.xxx.com/kdocs xxx.com/github xxx.com/ma...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-04-20  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/github xxx.com/github x...
# 04F4iKnBDqb6                                       wpsdoc.xxx.com/kdocs
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-04-21  \
# device_num_transform
# 01GOhHDp463z                                             xxx.com/github
# 04F4iKnBDqb6          wpsdoc.xxx.com/kdocs wpsdoc.xxx.com/download w...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-04-22  \
# device_num_transform
# 01GOhHDp463z          xxx.com/mail xxx.com/github xxx.com/github xxx...
# 04F4iKnBDqb6                              xxx.com/github xxx.com/github
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days              2022-04-23                                2022-04-24  \
# device_num_transform
# 01GOhHDp463z                NaN  xxx.com/github xxx.com/github xxx.com/oa
# 04F4iKnBDqb6                NaN                            xxx.com/github
# 04MrZwVR5Dh4                NaN                                       NaN
# 05DiseR8wyyh                NaN                                       NaN
# 05SghMEzzxQQ                NaN                     xxx.com/getVerifyCode
#
# op_days                                               2022-04-25  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/github xxx.com/mail
# 04F4iKnBDqb6                                                 NaN
# 04MrZwVR5Dh4                                                 NaN
# 05DiseR8wyyh                                                 NaN
# 05SghMEzzxQQ                                                 NaN
#
# op_days                                  2022-04-26  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/github
# 04F4iKnBDqb6          xxx.com/github xxx.com/github
# 04MrZwVR5Dh4                                    NaN
# 05DiseR8wyyh                                    NaN
# 05SghMEzzxQQ                                    NaN
#
# op_days                                                      2022-04-27  \
# device_num_transform
# 01GOhHDp463z          wpsdoc.xxx.com/kdocs wpsdoc.xxx.com/download w...
# 04F4iKnBDqb6                                xxx.com/mail xxx.com/github
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-04-28  \
# device_num_transform
# 01GOhHDp463z                                             xxx.com/github
# 04F4iKnBDqb6          xxx.com/mail work.xxx.com/task xxx.com/mail xx...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-04-29  \
# device_num_transform
# 01GOhHDp463z          xxx.com/oa xxx.com/github work.xxx.com/task xx...
# 04F4iKnBDqb6                                                        NaN
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days              2022-04-30  2022-05-01 2022-05-02            2022-05-03  \
# device_num_transform
# 01GOhHDp463z                NaN  xxx.com/oa        NaN  wpsdoc.xxx.com/kdocs
# 04F4iKnBDqb6                NaN         NaN        NaN                   NaN
# 04MrZwVR5Dh4                NaN         NaN        NaN                   NaN
# 05DiseR8wyyh                NaN         NaN        NaN                   NaN
# 05SghMEzzxQQ                NaN         NaN        NaN                   NaN
#
# op_days              2022-05-04      2022-05-05  \
# device_num_transform
# 01GOhHDp463z                NaN  xxx.com/github
# 04F4iKnBDqb6                NaN             NaN
# 04MrZwVR5Dh4                NaN             NaN
# 05DiseR8wyyh                NaN             NaN
# 05SghMEzzxQQ                NaN             NaN
#
# op_days                                                      2022-05-06  \
# device_num_transform
# 01GOhHDp463z                                               xxx.com/mail
# 04F4iKnBDqb6          xxx.com/mail xxx.com/github xxx.com/github xxx...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                2022-05-07 2022-05-08  \
# device_num_transform
# 01GOhHDp463z                                    work.xxx.com/task        NaN
# 04F4iKnBDqb6          xxx.com/github work.xxx.com/task xxx.com/oa        NaN
# 04MrZwVR5Dh4                                                  NaN        NaN
# 05DiseR8wyyh                                                  NaN        NaN
# 05SghMEzzxQQ                                                  NaN        NaN
#
# op_days                                  2022-05-09  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/github
# 04F4iKnBDqb6                         xxx.com/github
# 04MrZwVR5Dh4                                    NaN
# 05DiseR8wyyh                                    NaN
# 05SghMEzzxQQ                                    NaN
#
# op_days                                  2022-05-10  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/github
# 04F4iKnBDqb6          xxx.com/github xxx.com/github
# 04MrZwVR5Dh4                                    NaN
# 05DiseR8wyyh                                    NaN
# 05SghMEzzxQQ                                    NaN
#
# op_days                                                      2022-05-11  \
# device_num_transform
# 01GOhHDp463z          xxx.com/mail xxx.com/github xxx.com/github xxx...
# 04F4iKnBDqb6          wpsdoc.xxx.com/kdocs xxx.com/github work.xxx.c...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                    2022-05-12  \
# device_num_transform
# 01GOhHDp463z          work.xxx.com/task xxx.com/github xxx.com/github
# 04F4iKnBDqb6          xxx.com/loginAuth xxx.com/github xxx.com/github
# 04MrZwVR5Dh4                                                      NaN
# 05DiseR8wyyh                                                      NaN
# 05SghMEzzxQQ                                                      NaN
#
# op_days                                                      2022-05-13  \
# device_num_transform
# 01GOhHDp463z                                             xxx.com/github
# 04F4iKnBDqb6          work.xxx.com/task wpsdoc.xxx.com/kdocs wpsdoc....
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days              2022-05-14 2022-05-15  \
# device_num_transform
# 01GOhHDp463z                NaN        NaN
# 04F4iKnBDqb6                NaN        NaN
# 04MrZwVR5Dh4                NaN        NaN
# 05DiseR8wyyh                NaN        NaN
# 05SghMEzzxQQ                NaN        NaN
#
# op_days                                                      2022-05-16  \
# device_num_transform
# 01GOhHDp463z          xxx.com/mail xxx.com/github xxx.com/oa xxx.com...
# 04F4iKnBDqb6                                             xxx.com/github
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                    2022-05-17  \
# device_num_transform
# 01GOhHDp463z                 xxx.com/oa xxx.com/github xxx.com/github
# 04F4iKnBDqb6          xxx.com/loginAuth xxx.com/github xxx.com/github
# 04MrZwVR5Dh4                                                      NaN
# 05DiseR8wyyh                                                      NaN
# ...
# 04F4iKnBDqb6               xxx.com/github xxx.com/github xxx.com/github
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days              2022-05-21 2022-05-22  \
# device_num_transform
# 01GOhHDp463z                NaN        NaN
# 04F4iKnBDqb6                NaN        NaN
# 04MrZwVR5Dh4                NaN        NaN
# 05DiseR8wyyh                NaN        NaN
# 05SghMEzzxQQ                NaN        NaN
#
# op_days                                                      2022-05-23  \
# device_num_transform
# 01GOhHDp463z          xxx.com/mail xxx.com/mail xxx.com/github work....
# 04F4iKnBDqb6                                                        NaN
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-05-24  \
# device_num_transform
# 01GOhHDp463z                                xxx.com/github xxx.com/mail
# 04F4iKnBDqb6          xxx.com/github work.xxx.com/task xxx.com/githu...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-05-25  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/github xxx.com/github w...
# 04F4iKnBDqb6                                xxx.com/github xxx.com/mail
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-05-26  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/github xxx.com/loginAut...
# 04F4iKnBDqb6                              xxx.com/github xxx.com/github
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                     2022-05-27 2022-05-28 2022-05-29  \
# device_num_transform
# 01GOhHDp463z                 xxx.com/mail xxx.com/mail        NaN        NaN
# 04F4iKnBDqb6          work.xxx.com/task xxx.com/github        NaN        NaN
# 04MrZwVR5Dh4                                       NaN        NaN        NaN
# 05DiseR8wyyh                                       NaN        NaN        NaN
# 05SghMEzzxQQ                                       NaN        NaN        NaN
#
# op_days                                                      2022-05-30  \
# device_num_transform
# 01GOhHDp463z          xxx.com/mail xxx.com/github work.xxx.com/task ...
# 04F4iKnBDqb6                                                        NaN
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-05-31  \
# device_num_transform
# 01GOhHDp463z                                  xxx.com/github xxx.com/oa
# 04F4iKnBDqb6          xxx.com/github xxx.com/github xxx.com/github x...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                   2022-06-01  \
# device_num_transform
# 01GOhHDp463z          xxx.com/oa xxx.com/loginAuth work.xxx.com/task
# 04F4iKnBDqb6                               xxx.com/github xxx.com/oa
# 04MrZwVR5Dh4                                                     NaN
# 05DiseR8wyyh                                                     NaN
# 05SghMEzzxQQ                                                     NaN
#
# op_days                                               2022-06-02  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/mail xxx.com/github
# 04F4iKnBDqb6                    xxx.com/github work.xxx.com/task
# 04MrZwVR5Dh4                                                 NaN
# 05DiseR8wyyh                                                 NaN
# 05SghMEzzxQQ                                                 NaN
#
# op_days                   2022-06-03      2022-06-04 2022-06-05  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github  xxx.com/github        NaN
# 04F4iKnBDqb6                     NaN             NaN        NaN
# 04MrZwVR5Dh4                     NaN             NaN        NaN
# 05DiseR8wyyh                     NaN             NaN        NaN
# 05SghMEzzxQQ                     NaN             NaN        NaN
#
# op_days                                                    2022-06-06  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github work.xxx.com/task xxx.com/github
# 04F4iKnBDqb6                                           xxx.com/github
# 04MrZwVR5Dh4                                                      NaN
# 05DiseR8wyyh                                                      NaN
# 05SghMEzzxQQ                                                      NaN
#
# op_days                                                      2022-06-07  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/github work.xxx.com/tas...
# 04F4iKnBDqb6               xxx.com/github xxx.com/github xxx.com/github
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-06-08  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github wpsdoc.xxx.com/kdocs xxx.com/lo...
# 04F4iKnBDqb6              xxx.com/mail xxx.com/loginAuth xxx.com/github
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                     2022-06-09  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github work.xxx.com/task
# 04F4iKnBDqb6             xxx.com/github xxx.com/github
# 04MrZwVR5Dh4                                       NaN
# 05DiseR8wyyh                                       NaN
# 05SghMEzzxQQ                                       NaN
#
# op_days                                                      2022-06-10  \
# device_num_transform
# 01GOhHDp463z          work.xxx.com/task wpsdoc.xxx.com/kdocs wpsdoc....
# 04F4iKnBDqb6                                                        NaN
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days              2022-06-11 2022-06-12                   2022-06-13  \
# device_num_transform
# 01GOhHDp463z                NaN        NaN  xxx.com/mail xxx.com/github
# 04F4iKnBDqb6                NaN        NaN                          NaN
# 04MrZwVR5Dh4                NaN        NaN                          NaN
# 05DiseR8wyyh                NaN        NaN                          NaN
# 05SghMEzzxQQ                NaN        NaN                          NaN
#
# op_days                                               2022-06-14  \
# device_num_transform
# 01GOhHDp463z                       xxx.com/github xxx.com/github
# 04F4iKnBDqb6          xxx.com/github xxx.com/github xxx.com/mail
# 04MrZwVR5Dh4                                                 NaN
# 05DiseR8wyyh                                                 NaN
# 05SghMEzzxQQ                                                 NaN
#
# op_days                                                      2022-06-15  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github work.xxx.com/task xxx.com/mail ...
# 04F4iKnBDqb6                                          work.xxx.com/task
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-06-16  \
# device_num_transform
# 01GOhHDp463z                                                        NaN
# 04F4iKnBDqb6          xxx.com/github xxx.com/github xxx.com/github x...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-06-17  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github work.xxx.com/task xxx.com/githu...
# 04F4iKnBDqb6                              xxx.com/github xxx.com/github
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                              2022-06-18      2022-06-19  \
# device_num_transform
# 01GOhHDp463z                                NaN  xxx.com/github
# 04F4iKnBDqb6          xxx.com/oa xxx.com/github             NaN
# 04MrZwVR5Dh4                                NaN             NaN
# 05DiseR8wyyh                                NaN             NaN
# 05SghMEzzxQQ                                NaN             NaN
#
# op_days                                         2022-06-20  \
# device_num_transform
# 01GOhHDp463z          xxx.com/oa xxx.com/github xxx.com/oa
# 04F4iKnBDqb6                                           NaN
# 04MrZwVR5Dh4                                           NaN
# 05DiseR8wyyh                                           NaN
# 05SghMEzzxQQ                                           NaN
#
# op_days                              2022-06-21  \
# device_num_transform
# 01GOhHDp463z                       xxx.com/mail
# 04F4iKnBDqb6          xxx.com/github xxx.com/oa
# 04MrZwVR5Dh4                                NaN
# 05DiseR8wyyh                                NaN
# 05SghMEzzxQQ                                NaN
#
# op_days                                  2022-06-22  \
# device_num_transform
# 01GOhHDp463z            xxx.com/mail xxx.com/github
# 04F4iKnBDqb6          xxx.com/github xxx.com/github
# 04MrZwVR5Dh4                                    NaN
# 05DiseR8wyyh                                    NaN
# 05SghMEzzxQQ                                    NaN
#
# op_days                                                      2022-06-23  \
# device_num_transform
# 01GOhHDp463z          xxx.com/oa xxx.com/github xxx.com/github xxx.c...
# 04F4iKnBDqb6                                             xxx.com/github
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-06-24  \
# device_num_transform
# 01GOhHDp463z          xxx.com/oa xxx.com/github xxx.com/github xxx.c...
# 04F4iKnBDqb6                                             xxx.com/github
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days               2022-06-25 2022-06-26  \
# device_num_transform
# 01GOhHDp463z          xxx.com/oa        NaN
# 04F4iKnBDqb6                 NaN        NaN
# 04MrZwVR5Dh4                 NaN        NaN
# 05DiseR8wyyh                 NaN        NaN
# 05SghMEzzxQQ                 NaN        NaN
#
# op_days                                                      2022-06-27  \
# device_num_transform
# 01GOhHDp463z          wpsdoc.xxx.com/kdocs wpsdoc.xxx.com/download w...
# 04F4iKnBDqb6                                             xxx.com/github
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-06-28  \
# device_num_transform
# 01GOhHDp463z          xxx.com/loginAuth xxx.com/mail xxx.com/github ...
# 04F4iKnBDqb6                                       wpsdoc.xxx.com/kdocs
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-06-29  \
# device_num_transform
# 01GOhHDp463z                                                        NaN
# 04F4iKnBDqb6          xxx.com/github xxx.com/loginAuth xxx.com/mail ...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN
#
# op_days                                                      2022-06-30
# device_num_transform
# 01GOhHDp463z                                             xxx.com/github
# 04F4iKnBDqb6          xxx.com/mail xxx.com/github xxx.com/oa xxx.com...
# 04MrZwVR5Dh4                                                        NaN
# 05DiseR8wyyh                                                        NaN
# 05SghMEzzxQQ                                                        NaN

# %%
df_cols.fillna('', inplace=True)
df_cols.head()
# Out:
# op_days                                                      2022-01-07  \
# device_num_transform
# 01GOhHDp463z          xxx.com/mail xxx.com/loginAuth xxx.com/github ...
# 04F4iKnBDqb6          xxx.com/mail wpsdoc.xxx.com/kdocs work.xxx.com...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days              2022-01-08 2022-01-09      2022-01-10  \
# device_num_transform
# 01GOhHDp463z                                xxx.com/github
# 04F4iKnBDqb6
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                     2022-01-11  \
# device_num_transform
# 01GOhHDp463z                            xxx.com/github
# 04F4iKnBDqb6          xxx.com/loginAuth xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-01-12  \
# device_num_transform
# 01GOhHDp463z                                               xxx.com/mail
# 04F4iKnBDqb6          work.xxx.com/task xxx.com/github xxx.com/login...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-01-13  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/loginAuth xxx.com/githu...
# 04F4iKnBDqb6                        xxx.com/loginAuth work.xxx.com/task
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-01-14  \
# device_num_transform
# 01GOhHDp463z                                                 xxx.com/oa
# 04F4iKnBDqb6          xxx.com/github xxx.com/github xxx.com/github x...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                   2022-01-15                     2022-01-16  \
# device_num_transform
# 01GOhHDp463z                          xxx.com/github xxx.com/github
# 04F4iKnBDqb6          xxx.com/github           wpsdoc.xxx.com/kdocs
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                           2022-01-17  \
# device_num_transform
# 01GOhHDp463z                       xxx.com/github xxx.com/oa
# 04F4iKnBDqb6          xxx.com/loginAuth wpsdoc.xxx.com/kdocs
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                        2022-01-18  \
# device_num_transform
# 01GOhHDp463z            xxx.com/mail wpsdoc.xxx.com/kdocs
# 04F4iKnBDqb6          wpsdoc.xxx.com/kdocs xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-01-19  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/mail work.xxx.com/task ...
# 04F4iKnBDqb6          wpsdoc.xxx.com/kdocs wpsdoc.xxx.com/kdocs xxx....
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-01-20  \
# device_num_transform
# 01GOhHDp463z              xxx.com/mail work.xxx.com/task xxx.com/github
# 04F4iKnBDqb6          xxx.com/github xxx.com/github xxx.com/loginAut...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                    2022-01-21  \
# device_num_transform
# 01GOhHDp463z                                           xxx.com/github
# 04F4iKnBDqb6          xxx.com/loginAuth xxx.com/github xxx.com/github
# 04MrZwVR5Dh4                                     xxx.com/getLoginType
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days              2022-01-22      2022-01-23  \
# device_num_transform
# 01GOhHDp463z                     xxx.com/github
# 04F4iKnBDqb6
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-01-24  \
# device_num_transform
# 01GOhHDp463z                           work.xxx.com/task xxx.com/github
# 04F4iKnBDqb6          wpsdoc.xxx.com/kdocs xxx.com/github xxx.com/oa...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                   2022-01-25 2022-01-26  \
# device_num_transform
# 01GOhHDp463z          xxx.com/mail work.xxx.com/task
# 04F4iKnBDqb6             xxx.com/github xxx.com/mail
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-01-27  \
# device_num_transform
# 01GOhHDp463z          work.xxx.com/task xxx.com/github work.xxx.com/...
# 04F4iKnBDqb6          xxx.com/mail xxx.com/github xxx.com/github xxx...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                             2022-01-28  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/mail xxx.com/mail
# 04F4iKnBDqb6                                    xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-01-29  \
# device_num_transform
# 01GOhHDp463z          xxx.com/loginAuth xxx.com/mail xxx.com/loginAu...
# 04F4iKnBDqb6          xxx.com/github wpsdoc.xxx.com/kdocs wpsdoc.xxx...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-01-30  \
# device_num_transform
# 01GOhHDp463z                   xxx.com/github xxx.com/mail xxx.com/mail
# 04F4iKnBDqb6          xxx.com/github wpsdoc.xxx.com/kdocs wpsdoc.xxx...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days              2022-01-31    2022-02-01 2022-02-02 2022-02-03  \
# device_num_transform
# 01GOhHDp463z                     xxx.com/mail
# 04F4iKnBDqb6
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days              2022-02-04 2022-02-05      2022-02-06  \
# device_num_transform
# 01GOhHDp463z                                xxx.com/github
# 04F4iKnBDqb6
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                         2022-02-07  \
# device_num_transform
# 01GOhHDp463z
# 04F4iKnBDqb6          wpsdoc.xxx.com/kdocs
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-02-08  \
# device_num_transform
# 01GOhHDp463z                 xxx.com/mail xxx.com/github xxx.com/github
# 04F4iKnBDqb6          xxx.com/mail xxx.com/loginAuth work.xxx.com/ta...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-02-09  \
# device_num_transform
# 01GOhHDp463z          wpsdoc.xxx.com/kdocs wpsdoc.xxx.com/download w...
# 04F4iKnBDqb6                           xxx.com/github work.xxx.com/task
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-02-10  \
# device_num_transform
# 01GOhHDp463z          xxx.com/mail xxx.com/github xxx.com/github xxx...
# 04F4iKnBDqb6          xxx.com/github work.xxx.com/task xxx.com/mail ...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-02-11  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github wpsdoc.xxx.com/kdocs xxx.com/gi...
# 04F4iKnBDqb6
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days              2022-02-12 2022-02-13  \
# device_num_transform
# 01GOhHDp463z
# 04F4iKnBDqb6
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-02-14  \
# device_num_transform
# 01GOhHDp463z                                             xxx.com/github
# 04F4iKnBDqb6          xxx.com/github xxx.com/github xxx.com/mail xxx...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-02-15  \
# device_num_transform
# 01GOhHDp463z
# 04F4iKnBDqb6          work.xxx.com/task xxx.com/github wpsdoc.xxx.co...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                        2022-02-16  \
# device_num_transform
# 01GOhHDp463z                                 xxx.com/mail
# 04F4iKnBDqb6          xxx.com/github wpsdoc.xxx.com/kdocs
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-02-17  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github wpsdoc.xxx.com/kdocs wpsdoc.xxx...
# 04F4iKnBDqb6                                             xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                      2022-02-18 2022-02-19            2022-02-20  \
# device_num_transform
# 01GOhHDp463z          work.xxx.com/task             wpsdoc.xxx.com/kdocs
# 04F4iKnBDqb6
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-02-21  \
# device_num_transform
# 01GOhHDp463z          work.xxx.com/task xxx.com/github wpsdoc.xxx.co...
# 04F4iKnBDqb6          xxx.com/github xxx.com/mail wpsdoc.xxx.com/kdo...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                   2022-02-22  \
# device_num_transform
# 01GOhHDp463z          xxx.com/mail work.xxx.com/task
# 04F4iKnBDqb6               xxx.com/github xxx.com/oa
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-02-23  \
# device_num_transform
# 01GOhHDp463z              work.xxx.com/task xxx.com/github xxx.com/mail
# 04F4iKnBDqb6          xxx.com/github xxx.com/mail xxx.com/github xxx...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                    2022-02-24  \
# device_num_transform
# 01GOhHDp463z                            xxx.com/github xxx.com/github
# 04F4iKnBDqb6          xxx.com/github xxx.com/loginAuth xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days              2022-02-25 2022-02-26 2022-02-27  \
# device_num_transform
# 01GOhHDp463z
# 04F4iKnBDqb6
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-02-28  \
# device_num_transform
# 01GOhHDp463z          wpsdoc.xxx.com/kdocs wpsdoc.xxx.com/download w...
# 04F4iKnBDqb6          xxx.com/oa xxx.com/github work.xxx.com/task wo...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-03-01  \
# device_num_transform
# 01GOhHDp463z                                             xxx.com/github
# 04F4iKnBDqb6          xxx.com/github xxx.com/mail xxx.com/mail work....
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-03-02  \
# device_num_transform
# 01GOhHDp463z                                          work.xxx.com/task
# 04F4iKnBDqb6          xxx.com/mail xxx.com/loginAuth work.xxx.com/ta...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-03-03  \
# device_num_transform
# 01GOhHDp463z                           xxx.com/loginAuth xxx.com/github
# 04F4iKnBDqb6          xxx.com/oa xxx.com/oa xxx.com/github xxx.com/g...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-03-04  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/oa xxx.com/loginAuth xx...
# 04F4iKnBDqb6                                  xxx.com/mail xxx.com/mail
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                   2022-03-05 2022-03-06      2022-03-07  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github             xxx.com/github
# 04F4iKnBDqb6
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                        2022-03-08  \
# device_num_transform
# 01GOhHDp463z
# 04F4iKnBDqb6          wpsdoc.xxx.com/kdocs xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                             2022-03-09  \
# device_num_transform
# 01GOhHDp463z                  xxx.com/loginAuth xxx.com/github
# 04F4iKnBDqb6          xxx.com/github xxx.com/mail xxx.com/mail
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-03-10  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/mail xxx.com/github xxx...
# 04F4iKnBDqb6            xxx.com/github xxx.com/loginAuth xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-03-11  \
# device_num_transform
# 01GOhHDp463z                                          work.xxx.com/task
# 04F4iKnBDqb6          wpsdoc.xxx.com/kdocs wpsdoc.xxx.com/download w...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days              2022-03-12 2022-03-13                   2022-03-14  \
# device_num_transform
# 01GOhHDp463z                                             xxx.com/github
# 04F4iKnBDqb6                                xxx.com/mail xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-03-15  \
# device_num_transform
# 01GOhHDp463z
# 04F4iKnBDqb6          xxx.com/mail xxx.com/github xxx.com/github xxx...
# 04MrZwVR5Dh4
# 05DiseR8wyyh                                       xxx.com/getLoginType
# 05SghMEzzxQQ
#
# op_days                                                      2022-03-16  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/mail xxx.com/loginAuth ...
# 04F4iKnBDqb6          work.xxx.com/task work.xxx.com/task xxx.com/oa...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-03-17  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github work.xxx.com/task work.xxx.com/...
# 04F4iKnBDqb6          xxx.com/github wpsdoc.xxx.com/kdocs xxx.com/gi...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-03-18  \
# device_num_transform
# 01GOhHDp463z          xxx.com/loginAuth xxx.com/mail xxx.com/oa work...
# 04F4iKnBDqb6                        xxx.com/loginAuth work.xxx.com/task
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                      2022-03-19 2022-03-20  \
# device_num_transform
# 01GOhHDp463z          work.xxx.com/task
# 04F4iKnBDqb6
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-03-21  \
# device_num_transform
# 01GOhHDp463z          work.xxx.com/task work.xxx.com/task xxx.com/gi...
# 04F4iKnBDqb6                                             xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-03-22  \
# device_num_transform
# 01GOhHDp463z                           xxx.com/loginAuth xxx.com/github
# 04F4iKnBDqb6          wpsdoc.xxx.com/kdocs xxx.com/mail wpsdoc.xxx.c...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-03-23  \
# device_num_transform
# 01GOhHDp463z                 xxx.com/github xxx.com/mail xxx.com/github
# 04F4iKnBDqb6          xxx.com/github xxx.com/github xxx.com/mail xxx...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-03-24  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github work.xxx.com/task work.xxx.com/...
# 04F4iKnBDqb6          xxx.com/mail xxx.com/mail xxx.com/github xxx.c...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                  2022-03-25 2022-03-26  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/github
# 04F4iKnBDqb6                         xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                   2022-03-27  \
# device_num_transform
# 01GOhHDp463z
# 04F4iKnBDqb6          xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-03-28  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/github work.xxx.com/tas...
# 04F4iKnBDqb6                           work.xxx.com/task xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                        2022-03-29  \
# device_num_transform
# 01GOhHDp463z                               xxx.com/github
# 04F4iKnBDqb6          xxx.com/github wpsdoc.xxx.com/kdocs
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-03-30  \
# device_num_transform
# 01GOhHDp463z                             xxx.com/mail work.xxx.com/task
# 04F4iKnBDqb6          xxx.com/loginAuth xxx.com/github xxx.com/githu...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                   2022-03-31  \
# device_num_transform
# 01GOhHDp463z
# 04F4iKnBDqb6          xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-04-01  \
# device_num_transform
# 01GOhHDp463z                                             xxx.com/github
# 04F4iKnBDqb6          wpsdoc.xxx.com/kdocs wpsdoc.xxx.com/download w...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                  2022-04-02  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github work.xxx.com/task xxx.com/mail
# 04F4iKnBDqb6               xxx.com/mail xxx.com/mail xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days               2022-04-03 2022-04-04 2022-04-05  \
# device_num_transform
# 01GOhHDp463z
# 04F4iKnBDqb6          xxx.com/oa
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-04-06  \
# device_num_transform
# 01GOhHDp463z                  wpsdoc.xxx.com/kdocs wpsdoc.xxx.com/kdocs
# 04F4iKnBDqb6          wpsdoc.xxx.com/kdocs xxx.com/github work.xxx.c...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-04-07  \
# device_num_transform
# 01GOhHDp463z                           work.xxx.com/task xxx.com/github
# 04F4iKnBDqb6          xxx.com/oa xxx.com/loginAuth xxx.com/github xx...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-04-08  \
# device_num_transform
# 01GOhHDp463z          xxx.com/mail wpsdoc.xxx.com/kdocs wpsdoc.xxx.c...
# 04F4iKnBDqb6           wpsdoc.xxx.com/kdocs xxx.com/github xxx.com/mail
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days              2022-04-09 2022-04-10  \
# device_num_transform
# 01GOhHDp463z
# 04F4iKnBDqb6
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                             2022-04-11  \
# device_num_transform
# 01GOhHDp463z          xxx.com/oa xxx.com/github xxx.com/github
# 04F4iKnBDqb6                                    xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-04-12  \
# device_num_transform
# 01GOhHDp463z          wpsdoc.xxx.com/kdocs wpsdoc.xxx.com/download w...
# 04F4iKnBDqb6                               work.xxx.com/task xxx.com/oa
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-04-13  \
# device_num_transform
# 01GOhHDp463z          work.xxx.com/task xxx.com/mail xxx.com/github ...
# 04F4iKnBDqb6                                             xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                 2022-04-14  \
# device_num_transform
# 01GOhHDp463z                           xxx.com/mail xxx.com/github
# 04F4iKnBDqb6          xxx.com/github xxx.com/github xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-04-15  \
# device_num_transform
# 01GOhHDp463z          wpsdoc.xxx.com/kdocs wpsdoc.xxx.com/download w...
# 04F4iKnBDqb6                        xxx.com/loginAuth work.xxx.com/task
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days              2022-04-16      2022-04-17  \
# device_num_transform
# 01GOhHDp463z
# 04F4iKnBDqb6                     xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-04-18  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github work.xxx.com/task xxx.com/githu...
# 04F4iKnBDqb6          xxx.com/loginAuth wpsdoc.xxx.com/kdocs xxx.com...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-04-19  \
# device_num_transform
# 01GOhHDp463z                                                 xxx.com/oa
# 04F4iKnBDqb6          wpsdoc.xxx.com/kdocs xxx.com/github xxx.com/ma...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-04-20  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/github xxx.com/github x...
# 04F4iKnBDqb6                                       wpsdoc.xxx.com/kdocs
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-04-21  \
# device_num_transform
# 01GOhHDp463z                                             xxx.com/github
# 04F4iKnBDqb6          wpsdoc.xxx.com/kdocs wpsdoc.xxx.com/download w...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-04-22  \
# device_num_transform
# 01GOhHDp463z          xxx.com/mail xxx.com/github xxx.com/github xxx...
# 04F4iKnBDqb6                              xxx.com/github xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days              2022-04-23                                2022-04-24  \
# device_num_transform
# 01GOhHDp463z                     xxx.com/github xxx.com/github xxx.com/oa
# 04F4iKnBDqb6                                               xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ                                        xxx.com/getVerifyCode
#
# op_days                                               2022-04-25  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/github xxx.com/mail
# 04F4iKnBDqb6
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                  2022-04-26  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/github
# 04F4iKnBDqb6          xxx.com/github xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-04-27  \
# device_num_transform
# 01GOhHDp463z          wpsdoc.xxx.com/kdocs wpsdoc.xxx.com/download w...
# 04F4iKnBDqb6                                xxx.com/mail xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-04-28  \
# device_num_transform
# 01GOhHDp463z                                             xxx.com/github
# 04F4iKnBDqb6          xxx.com/mail work.xxx.com/task xxx.com/mail xx...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-04-29  \
# device_num_transform
# 01GOhHDp463z          xxx.com/oa xxx.com/github work.xxx.com/task xx...
# 04F4iKnBDqb6
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days              2022-04-30  2022-05-01 2022-05-02            2022-05-03  \
# device_num_transform
# 01GOhHDp463z                     xxx.com/oa             wpsdoc.xxx.com/kdocs
# 04F4iKnBDqb6
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days              2022-05-04      2022-05-05  \
# device_num_transform
# 01GOhHDp463z                     xxx.com/github
# 04F4iKnBDqb6
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-05-06  \
# device_num_transform
# 01GOhHDp463z                                               xxx.com/mail
# 04F4iKnBDqb6          xxx.com/mail xxx.com/github xxx.com/github xxx...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                2022-05-07 2022-05-08  \
# device_num_transform
# 01GOhHDp463z                                    work.xxx.com/task
# 04F4iKnBDqb6          xxx.com/github work.xxx.com/task xxx.com/oa
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                  2022-05-09  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/github
# 04F4iKnBDqb6                         xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                  2022-05-10  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/github
# 04F4iKnBDqb6          xxx.com/github xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-05-11  \
# device_num_transform
# 01GOhHDp463z          xxx.com/mail xxx.com/github xxx.com/github xxx...
# 04F4iKnBDqb6          wpsdoc.xxx.com/kdocs xxx.com/github work.xxx.c...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                    2022-05-12  \
# device_num_transform
# 01GOhHDp463z          work.xxx.com/task xxx.com/github xxx.com/github
# 04F4iKnBDqb6          xxx.com/loginAuth xxx.com/github xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-05-13  \
# device_num_transform
# 01GOhHDp463z                                             xxx.com/github
# 04F4iKnBDqb6          work.xxx.com/task wpsdoc.xxx.com/kdocs wpsdoc....
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days              2022-05-14 2022-05-15  \
# device_num_transform
# 01GOhHDp463z
# 04F4iKnBDqb6
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-05-16  \
# device_num_transform
# 01GOhHDp463z          xxx.com/mail xxx.com/github xxx.com/oa xxx.com...
# 04F4iKnBDqb6                                             xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                    2022-05-17  \
# device_num_transform
# 01GOhHDp463z                 xxx.com/oa xxx.com/github xxx.com/github
# 04F4iKnBDqb6          xxx.com/loginAuth xxx.com/github xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# ...
# 04F4iKnBDqb6               xxx.com/github xxx.com/github xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days              2022-05-21 2022-05-22  \
# device_num_transform
# 01GOhHDp463z
# 04F4iKnBDqb6
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-05-23  \
# device_num_transform
# 01GOhHDp463z          xxx.com/mail xxx.com/mail xxx.com/github work....
# 04F4iKnBDqb6
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-05-24  \
# device_num_transform
# 01GOhHDp463z                                xxx.com/github xxx.com/mail
# 04F4iKnBDqb6          xxx.com/github work.xxx.com/task xxx.com/githu...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-05-25  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/github xxx.com/github w...
# 04F4iKnBDqb6                                xxx.com/github xxx.com/mail
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-05-26  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/github xxx.com/loginAut...
# 04F4iKnBDqb6                              xxx.com/github xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                     2022-05-27 2022-05-28 2022-05-29  \
# device_num_transform
# 01GOhHDp463z                 xxx.com/mail xxx.com/mail
# 04F4iKnBDqb6          work.xxx.com/task xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-05-30  \
# device_num_transform
# 01GOhHDp463z          xxx.com/mail xxx.com/github work.xxx.com/task ...
# 04F4iKnBDqb6
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-05-31  \
# device_num_transform
# 01GOhHDp463z                                  xxx.com/github xxx.com/oa
# 04F4iKnBDqb6          xxx.com/github xxx.com/github xxx.com/github x...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                   2022-06-01  \
# device_num_transform
# 01GOhHDp463z          xxx.com/oa xxx.com/loginAuth work.xxx.com/task
# 04F4iKnBDqb6                               xxx.com/github xxx.com/oa
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                               2022-06-02  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/mail xxx.com/github
# 04F4iKnBDqb6                    xxx.com/github work.xxx.com/task
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                   2022-06-03      2022-06-04 2022-06-05  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github  xxx.com/github
# 04F4iKnBDqb6
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                    2022-06-06  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github work.xxx.com/task xxx.com/github
# 04F4iKnBDqb6                                           xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-06-07  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github xxx.com/github work.xxx.com/tas...
# 04F4iKnBDqb6               xxx.com/github xxx.com/github xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-06-08  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github wpsdoc.xxx.com/kdocs xxx.com/lo...
# 04F4iKnBDqb6              xxx.com/mail xxx.com/loginAuth xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                     2022-06-09  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github work.xxx.com/task
# 04F4iKnBDqb6             xxx.com/github xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-06-10  \
# device_num_transform
# 01GOhHDp463z          work.xxx.com/task wpsdoc.xxx.com/kdocs wpsdoc....
# 04F4iKnBDqb6
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days              2022-06-11 2022-06-12                   2022-06-13  \
# device_num_transform
# 01GOhHDp463z                                xxx.com/mail xxx.com/github
# 04F4iKnBDqb6
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                               2022-06-14  \
# device_num_transform
# 01GOhHDp463z                       xxx.com/github xxx.com/github
# 04F4iKnBDqb6          xxx.com/github xxx.com/github xxx.com/mail
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-06-15  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github work.xxx.com/task xxx.com/mail ...
# 04F4iKnBDqb6                                          work.xxx.com/task
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-06-16  \
# device_num_transform
# 01GOhHDp463z
# 04F4iKnBDqb6          xxx.com/github xxx.com/github xxx.com/github x...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-06-17  \
# device_num_transform
# 01GOhHDp463z          xxx.com/github work.xxx.com/task xxx.com/githu...
# 04F4iKnBDqb6                              xxx.com/github xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                              2022-06-18      2022-06-19  \
# device_num_transform
# 01GOhHDp463z                                     xxx.com/github
# 04F4iKnBDqb6          xxx.com/oa xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                         2022-06-20  \
# device_num_transform
# 01GOhHDp463z          xxx.com/oa xxx.com/github xxx.com/oa
# 04F4iKnBDqb6
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                              2022-06-21  \
# device_num_transform
# 01GOhHDp463z                       xxx.com/mail
# 04F4iKnBDqb6          xxx.com/github xxx.com/oa
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                  2022-06-22  \
# device_num_transform
# 01GOhHDp463z            xxx.com/mail xxx.com/github
# 04F4iKnBDqb6          xxx.com/github xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-06-23  \
# device_num_transform
# 01GOhHDp463z          xxx.com/oa xxx.com/github xxx.com/github xxx.c...
# 04F4iKnBDqb6                                             xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-06-24  \
# device_num_transform
# 01GOhHDp463z          xxx.com/oa xxx.com/github xxx.com/github xxx.c...
# 04F4iKnBDqb6                                             xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days               2022-06-25 2022-06-26  \
# device_num_transform
# 01GOhHDp463z          xxx.com/oa
# 04F4iKnBDqb6
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-06-27  \
# device_num_transform
# 01GOhHDp463z          wpsdoc.xxx.com/kdocs wpsdoc.xxx.com/download w...
# 04F4iKnBDqb6                                             xxx.com/github
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-06-28  \
# device_num_transform
# 01GOhHDp463z          xxx.com/loginAuth xxx.com/mail xxx.com/github ...
# 04F4iKnBDqb6                                       wpsdoc.xxx.com/kdocs
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-06-29  \
# device_num_transform
# 01GOhHDp463z
# 04F4iKnBDqb6          xxx.com/github xxx.com/loginAuth xxx.com/mail ...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ
#
# op_days                                                      2022-06-30
# device_num_transform
# 01GOhHDp463z                                             xxx.com/github
# 04F4iKnBDqb6          xxx.com/mail xxx.com/github xxx.com/oa xxx.com...
# 04MrZwVR5Dh4
# 05DiseR8wyyh
# 05SghMEzzxQQ

# %%
df_res = df_cols.apply(lambda x: ' '.join(list(filter(None, list(x)))), axis=1)
df_res
# Out:
# device_num_transform
# 01GOhHDp463z    xxx.com/mail xxx.com/loginAuth xxx.com/github ...
# 04F4iKnBDqb6    xxx.com/mail wpsdoc.xxx.com/kdocs work.xxx.com...
# 04MrZwVR5Dh4                                 xxx.com/getLoginType
# 05DiseR8wyyh                                 xxx.com/getLoginType
# 05SghMEzzxQQ                                xxx.com/getVerifyCode
#                                       ...
# zOb9NlDd0LNL                                xxx.com/getVerifyCode
# zZaMUpAM22FA                                 xxx.com/getLoginType
# zavzUQni8jCv                                    xxx.com/loginAuth
# znuxvoiO6WKQ                                 xxx.com/getLoginType
# zv5gASBc2N4X                                xxx.com/getVerifyCode
# Length: 1162, dtype: object

# %%
df_num = df_res.apply(lambda x: len(x.split()))
df_num
# Out:
# device_num_transform
# 01GOhHDp463z    410
# 04F4iKnBDqb6    393
# 04MrZwVR5Dh4      1
# 05DiseR8wyyh      1
# 05SghMEzzxQQ      1
#                ...
# zOb9NlDd0LNL      1
# zZaMUpAM22FA      1
# zavzUQni8jCv      1
# znuxvoiO6WKQ      1
# zv5gASBc2N4X      1
# Length: 1162, dtype: int64

# %%
df_res = df_res[df_num > 3]
df_res.head()
# Out:
# device_num_transform
# 01GOhHDp463z    xxx.com/mail xxx.com/loginAuth xxx.com/github ...
# 04F4iKnBDqb6    xxx.com/mail wpsdoc.xxx.com/kdocs work.xxx.com...
# 0L5KlIYwu0Yy    xxx.com/github wpsdoc.xxx.com/kdocs xxx.com/ma...
# 0bdar6YzF7TR    xxx.com/checkingin hr.xxx.com/ hr.xxx.com/ xxx...
# 0dV6LzVsv7pW    xxx.com/github xxx.com/oa wpsdoc.xxx.com/kdocs...
# dtype: object

# %%
df_res.to_csv(os.path.join(path_new_data, 'corpus.csv'), index=False, header=False, sep='\t')

# %%
def train_embedding(path_corpus, path_save_models, path_save_txt, col):
    sentences = word2vec.Text8Corpus(path_corpus)  # 原始语料路径,已分词
    # 训练代码
    model = word2vec.Word2Vec(sentences, sg=1, vector_size=5, window=12, min_count=1,
                              hs=0,  workers=10, epochs=10)
    # save
    path_embedding_model = os.path.join(path_save_models, 'models_{}.model'.format(str(col)))
    path_embedding_vocab = os.path.join(path_save_txt, 'models_{}_embedding.txt'.format(str(col)))

    model.save(path_embedding_model)
    model.wv.save_word2vec_format(path_embedding_vocab)
    print('词向量训练完成：{}'.format(str(col)))

# %%
train_embedding(
    path_corpus = os.path.join(path_new_data, 'corpus.csv'),
    path_save_models = os.path.join(path_new_data, 'corpus_models'),
    path_save_txt = os.path.join(path_new_data, 'corpus_txt'),
    col = 'device_num_transform',
               )
# Out:
# 词向量训练完成：device_num_transform

# %%
df_tmp = pd.read_csv('/Users/liliangshan/workspace/python/01_datasets/ccf_system_access_risk_identification/new_data/corpus_txt/models_device_num_transform_embedding.txt', skiprows=1, header=None, sep=' ' )
df_tmp
# Out:
#                           0         1         2         3         4         5
# 0            xxx.com/github  0.372258 -0.109154  0.838936 -0.696688 -0.470712
# 1   wpsdoc.xxx.com/download  0.032606 -0.594723  0.087753 -0.636999 -0.691368
# 2              xxx.com/mail -0.164870 -0.815885  0.099441 -0.390733 -0.795901
# 3         work.xxx.com/task -0.050692 -0.610392  0.229830 -0.714795 -0.653477
# 4         business.xxx.com/  1.130417 -0.261384 -0.789448 -1.736327 -1.130289
# 5      wpsdoc.xxx.com/kdocs  0.023941 -0.726561  0.008695 -0.478485 -0.753250
# 6         xxx.com/loginAuth -0.070380 -0.705889  0.146878 -0.437643 -0.728691
# 7                xxx.com/oa -0.162362 -0.831574 -0.039809 -0.394129 -0.879894
# 8        xxx.com/checkingin -1.042300  0.347731 -0.085625  0.438875 -2.706073
# 9        xxx.com/accounting  1.619950 -0.605472  0.112955  1.702297 -1.913541
# 10              hr.xxx.com/ -1.779259  0.986257  1.226322  0.532909 -2.967238

# %%
# 构建符合本项目的词向量
embeddings = np.random.rand(len(word2id), int(config['train_test_settings']['embedding_dim']))
f = open(path_row_embedding, 'r', encoding='UTF-8')
for i, line in enumerate(f):
    if i == 0:  # 若第一行是标题，则跳过
        continue
    lin = line.strip().split(" ")  # 预训练词向量
    if lin[0] in word2id:
        idx = word2id[lin[0]]
        emb = [float(x) for x in lin[1: int(config['train_test_settings']['embedding_dim']) + 1]]
        embeddings[idx] = np.asarray(emb, dtype="float32")
f.close()

# %%
df_res.head(10)
# Out:
# device_num_transform
# 01GOhHDp463z    xxx.com/mail xxx.com/loginAuth xxx.com/github ...
# 04F4iKnBDqb6    xxx.com/mail wpsdoc.xxx.com/kdocs work.xxx.com...
# 04MrZwVR5Dh4                                 xxx.com/getLoginType
# 05DiseR8wyyh                                 xxx.com/getLoginType
# 05SghMEzzxQQ                                xxx.com/getVerifyCode
# 09qlLew78XXp                                 xxx.com/getLoginType
# 0AG7bOroVGrh                                xxx.com/getVerifyCode
# 0B1EZlyCIjEA                                xxx.com/getVerifyCode
# 0BJZnGywzJAc                                 xxx.com/getLoginType
# 0DSr7NTlrmpE                                 xxx.com/getLoginType
# dtype: object

# %%
df_num[df_num>3]
# Out:
# device_num_transform
# 01GOhHDp463z    410
# 04F4iKnBDqb6    393
# 0L5KlIYwu0Yy    423
# 0bdar6YzF7TR    321
# 0dV6LzVsv7pW    477
# 0jQzrW0ob3tw    378
# 0vwTFOBrbvIs    383
# 19sK60AbnGgR    422
# 1BmyW1drMraT    374
# 1NnRdFzp9NWJ    368
# 1SRtvCb9DNFr    412
# 1baNbqxMWcCu    409
# 1gUBfR9p6HLE    363
# 1lTglzPf2SLB    423
# 21DcH4wj4tEf    338
# 2AECzhJLRR4Y    385
# 2EmjEhrepKLJ    436
# 2PQLbdJAk4QW    306
# 2ZOGB1eOX3vU    419
# 2pOKemyYTkvI    369
# 2u1rhQmiknmk    386
# 36AnzTaMQafK    386
# 39OE3BHMPdqV    345
# 3ANg3oEpqSxD    355
# 3nvH2PHqvZrr    311
# 3rYjJlAh0Q1x    327
# 3wDqyLqvVCn1    433
# 42y4i2PwNyBY    361
# 44BDMyay4hg1    394
# 4BWxjoSreaOm    468
# 4ERrLGUd7rMh    361
# 4G2Bw0Csw5lz    413
# 4Jv2QioonsJM    318
# 4Qy11wvgpGFs    418
# 4SXmah16O6AH    403
# 5DmlITfRNR36    445
# 5Qli6KaoYmgU    356
# 5SgCho991yJr    388
# 5nWnCuken0p8    384
# 5yApVeSk7drn    375
# 651TrktciC9i    409
# 6MwEE0egsCb7    300
# 6NRAoXZogVDX    403
# 6T3i25megG6k    364
# 6YuqJIvp6wuX    409
# 6m7Wp9p29RXI    377
# 6ypVTOMezZPI    339
# 6zUqVT1ygOEZ    443
# 72IsjEv4ThEB    334
# 798WtsqdmzON    379
# 7KZWJS5kfdwO    448
# 7XGXdzsk7SDA    386
# 7YM3aaHmgUsf    407
# 7mYejnjm4EoU    378
# 7oIzIFUzvExP    324
# 7rHhoZ2Rv1Hf    424
# 7rqsgOo0hLOV    364
# 7tn2kU7UkBFQ    405
# 84XXhUeI2Eno    421
# 8Bklz7k6AMBE    453
# 8X5MTrzXSIqA    310
# 8XwwfyYXx2eH    447
# 8bCWDahC7Gaq    338
# 8ftsXFm5I1Ej    364
# 8hjqBqrNDPkE    452
# 8mChagTPYOoL    455
# 94Gccq5Jq1KK    375
# APVLKac2thV2    335
# AYpqOsD47K9p    452
# Beriq7on1mmB    350
# C04Llg4lKl4C    348
# CYUCfieM2Iss    421
# CgLOtWGNWc3N    399
# Cv0WxgH0yCRF    288
# D5zHmS1xOlJX    384
# DIBl5zjCQg9U    340
# E5Mjdi1Ka59s    302
# EYNn0Kmp0a5S    452
# FgFXwvk2F1Wm    358
# G9ZQ1AybsUPR    310
# GCgxrFb69up7    405
# GGqviJf0d2Rb    469
# GH5w6zTcZL0R    366
# Gk0JoiqhROiD    409
# GnkVqPSy5nnl    339
# H8NAVsdws95G    409
# HL3vrsyu1H3Z    446
# HLAdiXh668iK    428
# HO7ucXnISE5V    332
# HT5IjXqw8GLD    347
# IIE74Ejh0Duy    425
# IQRRBooV0IOH    430
# IUM0CBTaOBp6    374
# JxQtAgYh0ISE    437
# K8Ith9mjHsKo    449
# K8k4JBhzqIdf    364
# KqX2PEWxq3Mh    387
# KxJoETnt0nfy    370
# LNPnn3Njeuu2    379
# LqEZg78nuB9U    461
# LyJXjnSk8YnP    402
# MQt1K0TcQ2iJ    379
# NW1NTKXx75Ek    394
# O0z4bdaN1tBX    392
# O3hWNlj3qpqW    397
# O54DfqjlCrhL    477
# PImvhsPp0AFS    364
# PV9ahGuqwn4t    255
# PlAdPUvplSW0    414
# PmF1OyXA5StT    409
# Rfv57YyO3vny    475
# RlZlLWSvh292    394
# Rz2yXzQm69qw    363
# S05VjSkg47I4    356
# T2H1mGc6fYWL    328
# T4rS7HpsD6nh    411
# T6CUqEYnR8fU    372
# T7mGjWmswm9Z    402
# T9sVlBvn2jO4    453
# TzmgdvYq3Kx0    456
# U3vZVEEyMm17    442
# VBIZVc1AnS3x    384
# W1Cstajd8x1s    399
# WdXbb6MizIQV    427
# Wrv3vNAxhxhu    368
# X9RHOzThlnFS    317
# XT6rv8cyHt6J    318
# XpMyOxNIKI6a    432
# Y0gyKLbnWTxZ    346
# Y0ic4I4cr0UU    308
# Y28jqypG4aOB    349
# Y3VHKrl2kSIM    370
# Yrc7Vy9WNS7M    403
# aIbV3Qij3kop    363
# b9ADJJLeCoyD    409
# c0wXA3XzgtNV    405
# c2ktd8xZIUsB    374
# co2NRdph7Z3Z    410
# d0Tcifk9omYQ    301
# d9oq5vCk6JMi    394
# drldzlpAVw5Q    426
# e0JNvdFePaFK    437
# e79QrtWgS3Oz    349
# eCi9IsVr1WEJ    366
# fWy9wTZxT6JY    361
# gkPlBwXt1TUi    373
# h8uS3IlwxjSQ    344
# i9hrGcub2Xen    381
# iHjuALht4Rkj    401
# iKPTa3su50y7    386
# ikOCpO4j3KU9    387
# jUG1ecmbP6rI    359
# kMRm5KEb0ovh    426
# kSscjiRSz1aD    377
# kUa61ygA6gI3    462
# kxL9IiM0TNqm    328
# lHZQcsid67md    433
# lPFcCAdg9EgB    320
# nQh4tAxz6bsv    420
# oZWobCMy9y7d    337
# pLxAO9Wq3F1j    412
# qCV5fVA95BlQ    357
# qMOJXl9j3qIS    382
# qenPgmcX8rEz    326
# qp7HVkuILPkG    411
# r33JCsELNTFZ    426
# rXOriovd7MVW    385
# rqRxAjAL1RYC    418
# rtYJstV68BNy    435
# s9vItuaVQkNn    356
# sL7bfqAu38XZ    447
# sdN7y26qL30M    421
# swh1mqEhXZFi    382
# t3ts32NPjtG9    439
# t8xfzCnTTmYd    418
# tGe3La5sME5n    339
# u02CbZhxZaSX    424
# uRYWimJ18UEk    422
# uUDYfPs3t4tI    358
# vHOP4Plkk3yh    435
# vtgYAYUq2QhK    331
# wG43OLpj9PUN    345
# wqHGEaIrW5Gm    410
# x1EcTfUyrJbE    451
# xGr7O0Pe3i5M    378
# z6eSfxO2SFSG    355
# z77UjKOsSdRT    338
# dtype: int64

# %%
    df_res = df_user_create.apply(lambda x: ' '.join(list(filter(None, list(x)))), axis=1)
    df_num = df_res.apply(lambda x: len(x.split()))

# %%
df = df.dropna(columns=[cols])
df_cols = df.groupby(['op_days','device_num_transform'])[col].agg(lambda x: " ".join(list(x)))
df_cols = df_cols.unstack()
df_cols =

# %%
def get_corpus(df, col, path_save, freq=0.95):
    """
    生成用于训练词向量的语料
    :param df:
    :param col:
    :param path_save:
    :param freq:
    :return:
    """
    df = df.dropna(columns=[cols])
    df_cols = df.groupby(['op_days','device_num_transform'])[col].agg(lambda x: " ".join(list(x)))
    df_cols = df_cols.unstack()
    df_cols =

# %%
def get_corpus(config, col, freq=0.95):
    """
    生成用于训练词向量的语料
    :param freq:
    :param config:
    :param col:
    :return:
    """
    path_col = os.path.join(config['path_pipeline_settings']['path_pipeline_col_click'],
                            '{}_corpus_{}.csv'.format(col, str(int(freq * 100))))
    path_save = os.path.join(config['path_pipeline_settings']['path_col_corpus'],
                             '{}_corpus.txt'.format(col))
    if os.path.exists(path_save):
        logger.debug('03 训练语料已存在： {}_corpus_{}.csv'.format(col, str(int(freq * 100))))
        return
    df_col = pd.read_csv(path_col, na_values=r'\N', dtype={col: str}, usecols=['time', 'user_id', col])
    df_col = df_col.dropna()
    df_user_create = df_col.groupby(['user_id', 'time'])[col].agg(lambda x: ' '.join(list(x)))
    df_user_create = df_user_create.unstack()
    df_user_create = df_user_create[list(range(1, 92))]
    df_user_create.fillna('', inplace=True)

    df_res = df_user_create.apply(lambda x: ' '.join(list(filter(None, list(x)))), axis=1)
    df_num = df_res.apply(lambda x: len(x.split()))
    #df_res = df_res[df_num > 7]

    df_res.to_csv(path_save, index=False, header=False, sep='\t')

    logger.debug('03 训练语料已生成： {}_corpus_{}.csv'.format(col, str(int(freq * 100))))
# Out:
#           id         user_name department ip_transform device_num_transform  \
# 44477  44477      xiongkai3397         rd    6H1iPLgBB         GCgxrFb69up7
# 45489  45489  zhengguiying7117         rd    0mjaEf4SB         8ftsXFm5I1Ej
# 45706  45706       yuanjun5870         hr    1Vk2kEa4X         W1Cstajd8x1s
# 45901  45901  zhoutingting3694         rd    4Wj6uxLx3         H8NAVsdws95G
# 43827  43827       yanglin6562      sales    eK12oQmm8         GnkVqPSy5nnl
#
#       browser_version  browser os_type        os_version         op_datetime  \
# 44477       chrome_93   chrome     win             win10 2022-01-07 02:44:29
# 45489       safari_13   safari   macos  macos_big_sur_11 2022-01-07 02:54:32
# 45706      firefox_78  firefox     win              win7 2022-01-07 03:00:56
# 45901         edge_93     edge     win             win10 2022-01-07 04:29:34
# 43827            ie_9       ie     win             win10 2022-01-07 05:17:44
#
#       ip_type  http_status_code op_city log_system_transform  \
# 44477      内网               200      深圳         nHrKgKdJ1Mzt
# 45489      内网               200      成都         nHrKgKdJ1Mzt
# 45706      内网               200      深圳         a5G25puBl9xj
# 45901      内网               200      杭州         nHrKgKdJ1Mzt
# 43827      内网               200      重庆         sW0whYIx8LFM
#
#                      url op_month  is_risk       url_sit url_page     op_days  \
# 44477     xxx.com/github  2022-01      1.0       xxx.com   github  2022-01-07
# 45489     xxx.com/github  2022-01      1.0       xxx.com   github  2022-01-07
# 45706        hr.xxx.com/  2022-01      1.0    hr.xxx.com           2022-01-07
# 45901     xxx.com/github  2022-01      1.0       xxx.com   github  2022-01-07
# 43827  work.xxx.com/task  2022-01      1.0  work.xxx.com     task  2022-01-07
#
#        op_diff_second1  op_diff_second1_log  op_diff_second1_log_log  \
# 44477              NaN                  NaN                      NaN
# 45489              NaN                  NaN                      NaN
# 45706              NaN                  NaN                      NaN
# 45901              NaN                  NaN                      NaN
# 43827              NaN                  NaN                      NaN
#
#        op_times_groups  system_op_diff_second1  system_op_diff_second1_log  \
# 44477                0                     NaN                         NaN
# 45489                0                   603.0                    6.401917
# 45706                0                   384.0                    5.950643
# 45901                0                  5318.0                    8.578853
# 43827                0                  2890.0                    7.969012
#
#        system_op_diff_second1_log_log  system_op_times_groups
# 44477                             NaN                       0
# 45489                        1.856598                       1
# 45706                        1.783499                       1
# 45901                        2.149300                       2
# 43827                        2.075560                       3

# %%
df
