# %% [markdown]
# ## 导包

# %%
# 公榜分数0.92860690761
import pandas as pd
import numpy as np
import lightgbm as lgb
import time
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_auc_score as auc
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_absolute_percentage_error as mape
from sklearn.model_selection import StratifiedKFold, KFold
from matplotlib.pyplot import plot, show

# %%
import os
import pandas as pd 
import numpy as np
import scorpyo as sp

import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

import time

from sklearn.model_selection import KFold
from scipy.stats import spearmanr
from lightgbm import LGBMClassifier

# %%
path_project = r'/Users/liliangshan/workspace/python/01_datasets/ccf_system_access_risk_identification'

# path dir
path_row_data = os.path.join(path_project, 'row_data')
path_new_data = os.path.join(path_project, 'new_data')
path_results  = os.path.join(path_project, 'results')

# path row_data
path_train = os.path.join(path_row_data, 'train.csv')
path_test  = os.path.join(path_row_data, 'evaluation_public.csv')
path_sample_submission = os.path.join(path_row_data, 'submit_example.csv')


## results
path_output_report = os.path.join(path_results, '01_原始数据探察.xlsx')

y_label = "is_risk"

# %% [markdown]
# ## 数据读取

# %%
df_row_train = sp.read_data(path_train)
df_row_val  = sp.read_data(path_test)

# %%
df_row_train.head()
# Out:
#    id        user_name department ip_transform device_num_transform  \
# 0   0  guojianping9672         rd    GVhZtW4i1         rqRxAjAL1RYC
# 1   1      yangtao1740      sales    l3MuTMPoQ         iKPTa3su50y7
# 2   2     wangying9098         rd    4uHWcskWv         1baNbqxMWcCu
# 3   3   liguixiang3860         rd    mQh3NwtY7         C04Llg4lKl4C
# 4   4       guanyu9205      sales    C2QtgDKAZ         kSscjiRSz1aD
#
#   browser_version  browser os_type os_version          op_datetime ip_type  \
# 0      firefox_78  firefox     win      win10  2022-01-18 19:10:41      内网
# 1       chrome_93   chrome     win      win11  2022-04-01 17:04:00      内网
# 2           ie_11       ie     win      win10  2022-03-01 15:53:49      内网
# 3         edge_93     edge     win      win10  2022-02-07 19:46:25      内网
# 4         edge_93     edge     win      win10  2022-04-12 10:05:19      内网
#
#    http_status_code op_city log_system_transform                   url  \
# 0               200      成都         2umVQwhiiwNJ          xxx.com/mail
# 1               200      深圳         RwHe8Q1R7AlB     business.xxx.com/
# 2               200      成都         dwS3cdn15GK4  wpsdoc.xxx.com/kdocs
# 3               200      北京         nHrKgKdJ1Mzt        xxx.com/github
# 4               200      成都         RwHe8Q1R7AlB     business.xxx.com/
#
#   op_month  is_risk
# 0  2022-01        0
# 1  2022-04        0
# 2  2022-03        0
# 3  2022-02        0
# 4  2022-04        0

# %%
# _ = sp.excel_label(df_row_train, y=y_label, excel_path=path_output_report, show=True)

# %%
# sp.excel_detect(df_row_train, sheet_name='02.训练集-数据描述性统计',excel_path=path_output_report)

# %%
# sp.excel_detect(df_row_val, sheet_name='03.测试集-数据描述性统计',excel_path=path_output_report)

# %% [markdown]
# ## 特征工程

# %% [markdown]
# 特征衍生

# %%
df = pd.concat([df_row_train, df_row_val])
# 认证日期时间
df['op_datetime'] = pd.to_datetime(df['op_datetime'])
# 几点钟
df['hour'] = df['op_datetime'].dt.hour
# 周几
df['dayofweek'] = df['op_datetime'].dt.dayofweek
# 一个月的第几天
df['day'] = df['op_datetime'].dt.day
# 一年的第几月
df['month'] = df['op_datetime'].dt.month


# 用户名-认证时间
df = df.sort_values(by=['user_name', 'op_datetime']).reset_index(drop=True)
# datetime转int时间戳
df['ts'] = df['op_datetime'].values.astype(np.int64) // 10 ** 9
# 按客户进行统计这次认证和上次认证的时间差
df['ts1'] = df.groupby('user_name')['ts'].shift(1)
# 按客户进行统计这次认证和上上次认证的时间差
df['ts2'] = df.groupby('user_name')['ts'].shift(2)
# 按客户进行统计这次认证和上上上次认证的时间差
df['ts3'] = df.groupby('user_name')['ts'].shift(3)
df['ts_diff1'] = df['ts1'] - df['ts']
df['ts_diff2'] = df['ts2'] - df['ts']
df['ts_diff3'] = df['ts3'] - df['ts']

df['hour_sin'] = np.sin(df['hour']/24*2*np.pi)
df['hour_cos'] = np.cos(df['hour']/24*2*np.pi)

# %%
cat_f = ['user_name', 'department', 'ip_transform', 'device_num_transform', 'browser_version', 'browser',
          'os_type', 'os_version', 'ip_type', 'op_city', 'log_system_transform', 'url',]
for f in cat_f:
#     le = LabelEncoder()
#     df[f] = le.fit_transform(df[f])
    df[f+'_ts_diff_mean'] = df.groupby([f])['ts_diff1'].transform('mean')
    df[f+'_ts_diff_std'] = df.groupby([f])['ts_diff1'].transform('std')
    df[f+'_ts_diff2_mean'] = df.groupby([f])['ts_diff2'].transform('mean')
    df[f+'_ts_diff2_std'] = df.groupby([f])['ts_diff2'].transform('std')
    df[f+'_ts_diff3_mean'] = df.groupby([f])['ts_diff3'].transform('mean')
    df[f+'_ts_diff3_std'] = df.groupby([f])['ts_diff3'].transform('std')

df_train = df[df[y_label].notna()].reset_index(drop=True)
df_test = df[df[y_label].isna()].reset_index(drop=True)

# %%
bins_adj = sp.woebin(df_train, y_label, var_skip=['id'])

train_woe = sp.woebin_ply(df_train, bins_adj)
val_woe  = sp.woebin_ply(df_test, bins_adj)
# Out:
# There are 1 date/time type columns are removed from input dataset.
#  (ColumnNames: op_month)
# >>> There are 4 variables have too many unique non-numberic values, which might cause the binning process slow. Please double check the following variables:
# ip_transform, user_name, op_datetime, device_num_transform
# >>> Continue the binning process?
# 1: yes
# 2: no
# 3: remove these variables
# Selection: 3
# There are 9 variables have only one binning intervals，please check the binning result.
#  (ColumnNames: os_type_ts_diff2_mean, os_type_ts_diff_std, ip_type_ts_diff_mean, ip_type_ts_diff2_mean, ip_type_ts_diff3_std, ip_type_ts_diff_std, ip_type_ts_diff3_mean, ip_type, ip_type_ts_diff2_std)
# [INFO] converting into woe values ...
# Woe transformating on 47660 rows and 95 columns in 00:00:10
# [INFO] converting into woe values ...

# %%
def is_numeric(series):
    """
    功能: 
    1. 检查series中数据是否为数值型数据
    
    输入:
    series: Series, 列数据。
    
    输出:
    bool, false series为非数值型， true series为数值型
    
    维护记录:
    1. edited by toad
    2. altered by 黎良山 2022/01/11
    """

    return series.dtype.kind in 'ifc'

# %%
feats = []
for col in train_woe.columns:
    if is_numeric(train_woe[col]) and col != y_label:
        feats.append(col)

# %%
train_woe = train_woe[[i for i in train_woe.columns if i[-3:]=='woe']+[y_label]]

# %%
len(bins_adj), len(train_woe.columns)
# Out:
# (95, 96)

# %%
iv_list, iv_drop_var, iv_data = sp.feature_selection_iv(train_woe, bins_adj, y_label, max_threshold=10.0)
print(iv_drop_var)
# Out:
# ['os_type_ts_diff2_mean_woe', 'browser_version_ts_diff3_mean_woe', 'browser_ts_diff_std_woe', 'browser_ts_diff3_mean_woe', 'ts2_woe', 'ts1_woe', 'os_version_ts_diff2_mean_woe', 'os_version_ts_diff3_std_woe', 'os_type_ts_diff_std_woe', 'browser_version_woe', 'os_type_ts_diff3_std_woe', 'department_ts_diff3_std_woe', 'user_name_ts_diff3_std_woe', 'os_type_ts_diff_mean_woe', 'os_version_woe', 'ip_type_ts_diff_mean_woe', 'user_name_ts_diff2_std_woe', 'os_type_woe', 'user_name_ts_diff3_mean_woe', 'browser_ts_diff_mean_woe', 'browser_version_ts_diff3_std_woe', 'department_woe', 'os_type_ts_diff3_mean_woe', 'browser_version_ts_diff_mean_woe', 'department_ts_diff_std_woe', 'ip_type_ts_diff2_mean_woe', 'browser_ts_diff3_std_woe', 'os_version_ts_diff2_std_woe', 'ip_type_ts_diff3_std_woe', 'user_name_ts_diff2_mean_woe', 'browser_woe', 'user_name_ts_diff_mean_woe', 'os_version_ts_diff_std_woe', 'browser_ts_diff2_mean_woe', 'department_ts_diff_mean_woe', 'ip_type_ts_diff_std_woe', 'ip_type_ts_diff3_mean_woe', 'user_name_ts_diff_std_woe', 'department_ts_diff3_mean_woe', 'os_type_ts_diff2_std_woe', 'ip_type_woe', 'browser_version_ts_diff_std_woe', 'ts_woe', 'browser_version_ts_diff2_mean_woe', 'department_ts_diff2_mean_woe', 'os_version_ts_diff3_mean_woe', 'browser_ts_diff2_std_woe', 'ts3_woe', 'day_woe', 'month_woe', 'department_ts_diff2_std_woe', 'browser_version_ts_diff2_std_woe', 'ip_type_ts_diff2_std_woe', 'os_version_ts_diff_mean_woe']

# %%
corr_matrix, corr_drop_var, corr_data = sp.feature_selection_corr(iv_data, y_label)
print(corr_drop_var)
# Out:
# ['url_ts_diff2_mean_woe' 'url_ts_diff3_mean_woe' 'url_ts_diff2_std_woe'
#  'device_num_transform_ts_diff3_mean_woe' 'url_ts_diff_mean_woe'
#  'device_num_transform_ts_diff_mean_woe'
#  'device_num_transform_ts_diff2_mean_woe' 'op_city_ts_diff_std_woe'
#  'device_num_transform_ts_diff_std_woe'
#  'log_system_transform_ts_diff2_std_woe' 'op_city_ts_diff2_std_woe'
#  'device_num_transform_ts_diff2_std_woe'
#  'log_system_transform_ts_diff3_std_woe'
#  'log_system_transform_ts_diff2_mean_woe' 'op_city_ts_diff3_mean_woe'
#  'device_num_transform_ts_diff3_std_woe'
#  'log_system_transform_ts_diff_std_woe'
#  'log_system_transform_ts_diff3_mean_woe' 'op_city_ts_diff2_mean_woe'
#  'ip_transform_ts_diff2_mean_woe' 'url_ts_diff_std_woe'
#  'log_system_transform_ts_diff_mean_woe' 'op_city_ts_diff3_std_woe'
#  'ip_transform_ts_diff3_mean_woe']

# %%
vif_list, vif_drop_var, res_data = sp.feature_selection_vif(corr_data, y_label)
print(vif_drop_var)
# Out:
# []

# %%
result, drop_list, res_frame = sp.stepwise(res_data, y_label, remove_negitive_coef=False)
# Out:
# 变量ip_transform_ts_diff_mean_woe被加入
# 变量hour_cos_woe被加入
# 变量hour_sin_woe被加入
# 变量url_woe被加入
# 变量dayofweek_woe被加入
# 变量ts_diff1_woe被加入
# 变量ts_diff3_woe被加入
# 变量hour_woe被加入
# 变量url_ts_diff3_std_woe被加入
# 变量log_system_transform_woe被加入
# 变量ts_diff2_woe被加入
# 变量op_city_woe被加入
# 变量op_city_ts_diff_mean_woe被删除
# 逐步回归结果
#                 指标1                 取值1                    指标2         取值2
# 0  Dep. Variable:    y                     No. Observations:    47660.0000
# 1  Model:            LogisticRegression    Df Residuals:        47647.0000
# 2  Method:           MLE                   Df Model:               12.0000
# 3  Date:             Wed; 12 Oct 2022      Pseudo R-squ.:           0.3276
# 4  Time:             13:55:57              Log-Likelihood:     -14169.0000
# 5  converged:        True                  LL-Null:            -21071.0000
# 6  Covariance Type:  nonrobust             LLR p-value:             0.0000
#                  feat                coef   std err     z      P>|z|   [0.025  \
# 0   intercept                      -1.7164    0.016  -105.011   0.000  -1.748
# 1   ts_diff1_woe                    0.5409    0.031    17.735   0.000   0.481
# 2   url_ts_diff3_std_woe           -1.0641    0.101   -10.498   0.000  -1.263
# 3   hour_sin_woe                    1.8187    0.055    32.773   0.000   1.710
# 4   hour_woe                       -0.6169    0.048   -12.829   0.000  -0.711
# 5   hour_cos_woe                    1.6827    0.035    47.886   0.000   1.614
# 6   url_woe                         1.1449    0.055    20.971   0.000   1.038
# 7   ts_diff3_woe                    0.6976    0.044    15.774   0.000   0.611
# 8   ts_diff2_woe                    0.1777    0.037     4.834   0.000   0.106
# 9   op_city_woe                    -0.1436    0.099    -1.456   0.145  -0.337
# 10  dayofweek_woe                   1.1303    0.035    31.910   0.000   1.061
# 11  log_system_transform_woe       -0.4960    0.074    -6.746   0.000  -0.640
# 12  ip_transform_ts_diff_mean_woe   1.2298    0.022    57.040   0.000   1.188
#
#     0.975]
# 0   -1.684
# 1    0.601
# 2   -0.865
# 3    1.927
# 4   -0.523
# 5    1.752
# 6    1.252
# 7    0.784
# 8    0.250
# 9    0.050
# 10   1.200
# 11  -0.352
# 12   1.272

# %%
feats = iv_data.columns.drop(y_label)

# %%
feats
# Out:
# Index(['url_ts_diff3_std_woe', 'hour_woe', 'ip_transform_ts_diff3_mean_woe',
#        'ts_diff3_woe', 'url_ts_diff_mean_woe',
#        'log_system_transform_ts_diff3_std_woe', 'ip_transform_ts_diff_std_woe',
#        'url_woe', 'op_city_ts_diff_std_woe', 'op_city_ts_diff2_mean_woe',
#        'hour_cos_woe', 'hour_sin_woe',
#        'log_system_transform_ts_diff2_mean_woe',
#        'ip_transform_ts_diff3_std_woe',
#        'device_num_transform_ts_diff2_std_woe',
#        'log_system_transform_ts_diff2_std_woe', 'http_status_code_woe',
#        'url_ts_diff_std_woe', 'device_num_transform_ts_diff3_mean_woe',
#        'device_num_transform_ts_diff3_std_woe', 'op_city_ts_diff3_mean_woe',
#        'url_ts_diff2_mean_woe', 'ts_diff2_woe', 'log_system_transform_woe',
#        'op_city_ts_diff_mean_woe', 'ip_transform_ts_diff2_mean_woe',
#        'ts_diff1_woe', 'url_ts_diff2_std_woe', 'url_ts_diff3_mean_woe',
#        'ip_transform_ts_diff2_std_woe', 'op_city_ts_diff2_std_woe',
#        'dayofweek_woe', 'op_city_woe', 'ip_transform_ts_diff_mean_woe',
#        'log_system_transform_ts_diff_mean_woe',
#        'device_num_transform_ts_diff2_mean_woe', 'op_city_ts_diff3_std_woe',
#        'device_num_transform_ts_diff_std_woe',
#        'log_system_transform_ts_diff_std_woe',
#        'log_system_transform_ts_diff3_mean_woe',
#        'device_num_transform_ts_diff_mean_woe'],
#       dtype='object')

# %%
train_woe.head()
# Out:
#    url_ts_diff3_std_woe  browser_version_ts_diff3_mean_woe  hour_woe  \
# 0                 0.150                              0.014    -0.410
# 1                 0.150                              0.014     0.940
# 2                -0.239                              0.014    -0.213
# 3                 0.150                              0.014    -0.213
# 4                 0.150                              0.014    -0.213
#
#    browser_ts_diff3_mean_woe  os_version_ts_diff2_mean_woe  \
# 0                     -0.014                         0.011
# 1                     -0.014                         0.011
# 2                     -0.014                         0.011
# 3                     -0.014                         0.011
# 4                     -0.014                         0.011
#
#    os_version_ts_diff3_std_woe  os_type_ts_diff_std_woe  browser_version_woe  \
# 0                        0.011                      0.0               -0.021
# 1                        0.011                      0.0               -0.021
# 2                        0.011                      0.0               -0.021
# 3                        0.011                      0.0               -0.021
# 4                        0.011                      0.0               -0.021
#
#    os_type_ts_diff3_std_woe  ip_transform_ts_diff3_mean_woe  ...  \
# 0                     0.009                          -0.257  ...
# 1                     0.009                          -0.257  ...
# 2                     0.009                          -0.257  ...
# 3                     0.009                          -0.257  ...
# 4                     0.009                          -0.257  ...
#
#    device_num_transform_ts_diff2_mean_woe  op_city_ts_diff3_std_woe  \
# 0                                  -0.102                    -0.107
# 1                                  -0.102                    -0.107
# 2                                  -0.102                    -0.107
# 3                                  -0.102                    -0.107
# 4                                  -0.102                    -0.107
#
#    device_num_transform_ts_diff_std_woe  browser_version_ts_diff2_std_woe  \
# 0                                -0.129                            -0.021
# 1                                -0.129                            -0.021
# 2                                -0.129                            -0.021
# 3                                -0.129                            -0.021
# 4                                -0.129                            -0.021
#
#    log_system_transform_ts_diff_std_woe  \
# 0                                 0.106
# 1                                 0.106
# 2                                -0.248
# 3                                 0.106
# 4                                 0.106
#
#    log_system_transform_ts_diff3_mean_woe  ip_type_ts_diff2_std_woe  \
# 0                                  -0.267                    -0.011
# 1                                  -0.267                    -0.011
# 2                                  -0.267                    -0.011
# 3                                  -0.267                    -0.011
# 4                                  -0.267                    -0.011
#
#    os_version_ts_diff_mean_woe  device_num_transform_ts_diff_mean_woe  is_risk
# 0                        0.009                                 -0.091      0.0
# 1                        0.009                                 -0.091      0.0
# 2                        0.009                                 -0.091      0.0
# 3                        0.009                                 -0.091      0.0
# 4                        0.009                                 -0.091      0.0
#
# [5 rows x 96 columns]

# %%
df_train = train_woe
df_test = val_woe

# %% [markdown]
# ## modeling

# %%
params = {
    'learning_rate': 0.05,
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'num_leaves': 31,
    'verbose': -1,
    'seed': 2222,
    'n_jobs': -1,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.9,
    'bagging_freq': 4,
    # 'min_child_weight': 10,
}

# %%
fold_num = 5
seeds = [2222]
oof = np.zeros(len(df_train))
importance = 0
pred_y = pd.DataFrame()
score = []
for seed in seeds:
    kf = StratifiedKFold(n_splits=fold_num, shuffle=True, random_state=seed)
    # kf = KFold(n_splits=fold_num, shuffle=True, random_state=seed)
    for fold, (train_idx, val_idx) in enumerate(kf.split(df_train[feats], df_train[y_label])):
        print('-----------', fold)
        train = lgb.Dataset(df_train.loc[train_idx, feats],
                            df_train.loc[train_idx, y_label])
        val = lgb.Dataset(df_train.loc[val_idx, feats],
                          df_train.loc[val_idx, y_label])
        model = lgb.train(params, train, valid_sets=[val], 
                          num_boost_round=20000, early_stopping_rounds=100)

        oof[val_idx] += model.predict(df_train.loc[val_idx, feats]) / len(seeds)
        pred_y['fold_%d_seed_%d' % (fold, seed)] = model.predict(df_test[feats])
        importance += model.feature_importance(importance_type='gain') / fold_num
        score.append(auc(df_train.loc[val_idx, y_label], model.predict(df_train.loc[val_idx, feats])))
feats_importance = pd.DataFrame()
feats_importance['name'] = feats
feats_importance['importance'] = importance
display(feats_importance.sort_values('importance', ascending=False)[:30])

df_train['oof'] = oof
display(np.mean(score), np.std(score))

score = np.mean(score)
df_test[y_label] = pred_y.mean(axis=1).values
df_test = df_test.sort_values('id').reset_index(drop=True)

sub = pd.read_csv(path_sample_submission)
sub[y_label] = df_test[y_label].values
sub.to_csv(os.path.join(path_results,time.strftime('lgb_%Y%m%d%H%M_')+'%.5f.csv'%score), index=False)
# Out:
# ----------- 0
# [1]	valid_0's auc: 0.86632
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's auc: 0.899652
# [3]	valid_0's auc: 0.916146
# [4]	valid_0's auc: 0.919372
# [5]	valid_0's auc: 0.919432
# [6]	valid_0's auc: 0.919775
# [7]	valid_0's auc: 0.920142
# [8]	valid_0's auc: 0.920661
# [9]	valid_0's auc: 0.921064
# [10]	valid_0's auc: 0.921581
# [11]	valid_0's auc: 0.921821
# [12]	valid_0's auc: 0.921751
# [13]	valid_0's auc: 0.921864
# [14]	valid_0's auc: 0.921853
# [15]	valid_0's auc: 0.921858
# [16]	valid_0's auc: 0.922775
# [17]	valid_0's auc: 0.922738
# [18]	valid_0's auc: 0.922698
# [19]	valid_0's auc: 0.922514
# [20]	valid_0's auc: 0.923007
# [21]	valid_0's auc: 0.923099
# [146]	valid_0's auc: 0.920518
# [147]	valid_0's auc: 0.920486
# [148]	valid_0's auc: 0.920454
# [149]	valid_0's auc: 0.920438
# [150]	valid_0's auc: 0.920471
# [151]	valid_0's auc: 0.920455
# [152]	valid_0's auc: 0.920478
# [153]	valid_0's auc: 0.920511
# [154]	valid_0's auc: 0.92047
# [155]	valid_0's auc: 0.92044
# [156]	valid_0's auc: 0.920426
# [157]	valid_0's auc: 0.920337
# [158]	valid_0's auc: 0.920355
# [159]	valid_0's auc: 0.920292
# [160]	valid_0's auc: 0.920251
# [161]	valid_0's auc: 0.920236
# [162]	valid_0's auc: 0.920216
# [163]	valid_0's auc: 0.920215
# [164]	valid_0's auc: 0.920206
# [165]	valid_0's auc: 0.920217
# [166]	valid_0's auc: 0.920261
# [167]	valid_0's auc: 0.920208
# [168]	valid_0's auc: 0.920269
# [169]	valid_0's auc: 0.920285
# [170]	valid_0's auc: 0.920282
# [171]	valid_0's auc: 0.920298
# [172]	valid_0's auc: 0.920261
# [173]	valid_0's auc: 0.920198
# [174]	valid_0's auc: 0.920171
# [175]	valid_0's auc: 0.920071
# [176]	valid_0's auc: 0.920064
# [177]	valid_0's auc: 0.920021
# [178]	valid_0's auc: 0.92001
# [179]	valid_0's auc: 0.920046
# [180]	valid_0's auc: 0.920076
# [181]	valid_0's auc: 0.920054
# [182]	valid_0's auc: 0.920049
# [183]	valid_0's auc: 0.920155
# [184]	valid_0's auc: 0.920157
# Early stopping, best iteration is:
# [84]	valid_0's auc: 0.921822
#                                       name    importance
# 16                    http_status_code_woe  33623.194413
# 6             ip_transform_ts_diff_std_woe  27763.837487
# 10                            hour_cos_woe  26484.416275
# 11                            hour_sin_woe  25045.866873
# 13           ip_transform_ts_diff3_std_woe  15029.206821
# 31                           dayofweek_woe   8541.605663
# 3                             ts_diff3_woe   7823.466113
# 1                                 hour_woe   6153.725188
# 26                            ts_diff1_woe   5860.410943
# 4                     url_ts_diff_mean_woe   3827.599616
# 29           ip_transform_ts_diff2_std_woe   3297.332638
# 22                            ts_diff2_woe   1712.657286
# 18  device_num_transform_ts_diff3_mean_woe    664.135953
# 14   device_num_transform_ts_diff2_std_woe    563.267247
# 40   device_num_transform_ts_diff_mean_woe    554.412696
# 0                     url_ts_diff3_std_woe    450.914232
# 21                   url_ts_diff2_mean_woe    444.936422
# 35  device_num_transform_ts_diff2_mean_woe    400.319731
# 7                                  url_woe    393.522826
# 5    log_system_transform_ts_diff3_std_woe    329.775859
# 37    device_num_transform_ts_diff_std_woe    274.733206
# 19   device_num_transform_ts_diff3_std_woe    217.812042
# 12  log_system_transform_ts_diff2_mean_woe    179.921054
# 25          ip_transform_ts_diff2_mean_woe    162.617429
# 8                  op_city_ts_diff_std_woe    148.753748
# 32                             op_city_woe    104.972110
# 24                op_city_ts_diff_mean_woe    101.708150
# 38    log_system_transform_ts_diff_std_woe     90.425615
# 2           ip_transform_ts_diff3_mean_woe     76.925396
# 33           ip_transform_ts_diff_mean_woe     67.897024
# 0.922752518587804
# 0.0015893689353349578
