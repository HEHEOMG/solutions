# %%
import os
import re
import numpy as np
import pandas as pd
import datetime

import matplotlib.pyplot as plt
import seaborn as sns

import scorpyo as sp

from null_importance import get_null_importance


pd.set_option('max_rows', 500, 'max_columns', 200)

# %%
path_project = r'/Users/liliangshan/workspace/python/01_datasets/ccf_system_access_risk_identification'

# path dir
path_row_data = os.path.join(path_project, 'row_data')
path_new_data = os.path.join(path_project, 'new_data')
path_results  = os.path.join(path_project, 'results')
path_results_jupyter  = os.path.join(path_results, 'jupyter')

# path row_data
path_train = os.path.join(path_row_data, 'train.csv')
path_test  = os.path.join(path_row_data, 'evaluation_public.csv')
path_sample_submission = os.path.join(path_row_data, 'submit_example.csv')


path_new_train = os.path.join(path_new_data, 'train_lightgbm_20221014.csv')
path_new_test  = os.path.join(path_new_data, 'test_lightgbm_20221014.csv')

## results
path_output_report = os.path.join(path_results, '01_原始数据探察_20221014.xlsx')

y_label = "is_risk"

# %%
df_row_train = sp.read_data(path_train)
df_row_val  = sp.read_data(path_test)

df_row_train['url_sit'] = df_row_train['url'].map(lambda x: x.split('/')[0])
df_row_train['url_page'] = df_row_train['url'].map(lambda x: x.split('/')[1])

df_row_val['url_sit'] = df_row_val['url'].map(lambda x: x.split('/')[0])
df_row_val['url_page'] = df_row_val['url'].map(lambda x: x.split('/')[1])



df_train_info = df_row_train.copy().sort_values(by='op_datetime')

# %%
df_row_train.head()
# Out:
#    id        user_name department ip_transform device_num_transform  \
# 0   0  guojianping9672         rd    GVhZtW4i1         rqRxAjAL1RYC
# 1   1      yangtao1740      sales    l3MuTMPoQ         iKPTa3su50y7
# 2   2     wangying9098         rd    4uHWcskWv         1baNbqxMWcCu
# 3   3   liguixiang3860         rd    mQh3NwtY7         C04Llg4lKl4C
# 4   4       guanyu9205      sales    C2QtgDKAZ         kSscjiRSz1aD
#
#   browser_version  browser os_type os_version          op_datetime ip_type  \
# 0      firefox_78  firefox     win      win10  2022-01-18 19:10:41      内网
# 1       chrome_93   chrome     win      win11  2022-04-01 17:04:00      内网
# 2           ie_11       ie     win      win10  2022-03-01 15:53:49      内网
# 3         edge_93     edge     win      win10  2022-02-07 19:46:25      内网
# 4         edge_93     edge     win      win10  2022-04-12 10:05:19      内网
#
#    http_status_code op_city log_system_transform                   url  \
# 0               200      成都         2umVQwhiiwNJ          xxx.com/mail
# 1               200      深圳         RwHe8Q1R7AlB     business.xxx.com/
# 2               200      成都         dwS3cdn15GK4  wpsdoc.xxx.com/kdocs
# 3               200      北京         nHrKgKdJ1Mzt        xxx.com/github
# 4               200      成都         RwHe8Q1R7AlB     business.xxx.com/
#
#   op_month  is_risk           url_sit url_page
# 0  2022-01        0           xxx.com     mail
# 1  2022-04        0  business.xxx.com
# 2  2022-03        0    wpsdoc.xxx.com    kdocs
# 3  2022-02        0           xxx.com   github
# 4  2022-04        0  business.xxx.com

# %%
sp.excel_detect(df_row_train, sheet_name='02.训练集-数据描述性统计')
# Out:
# sheet02.训练集-数据描述性统计在01_数据探查.xlsx中已经存在，我们将对原文件进行覆盖
#            feat_name_row    type   size  missing  unique  zero_ratio  \
# 0                     id   int64  47660     0.00   47660       0.000
# 1              user_name  object  47660     0.08     187       0.000
# 2             department  object  47660     0.08       5       0.000
# 3           ip_transform  object  47660     0.00    2105       0.000
# 4   device_num_transform  object  47660     0.00     844       0.000
# 5        browser_version  object  47660     0.00       8       0.000
# 6                browser  object  47660     0.00       5       0.000
# 7                os_type  object  47660     0.00       2       0.000
# 8             os_version  object  47660     0.00       4       0.000
# 9            op_datetime  object  47660     0.00   47343       0.000
# 10               ip_type  object  47660     0.08       1       0.000
# 11      http_status_code   int64  47660     0.00       5       0.000
# 12               op_city  object  47660     0.00      14       0.000
# 13  log_system_transform  object  47660     0.08       9       0.000
# 14                   url  object  47660     0.00      13       0.000
# 15              op_month  object  47660     0.00       4       0.000
# 16               is_risk   int64  47660     0.00       2       0.839
# 17               url_sit  object  47660     0.00       5       0.000
# 18              url_page  object  47660     0.00      12       0.000
#
#     negative_ratio       top1_all_value  top1_all_ratio  \
# 0              0.0                    0           0.000
# 1              NaN        xuxiuying8050           0.007
# 2              NaN                   rd           0.654
# 3              NaN            w2CfuqTz3           0.007
# 4              NaN         O54DfqjlCrhL           0.007
# 5              NaN              edge_93           0.372
# 6              NaN               chrome           0.431
# 7              NaN                  win           0.905
# 8              NaN                win10           0.758
# 9              NaN  2022-04-02 17:02:24           0.000
# 10             NaN                   内网           0.920
# 11             0.0                  200           0.948
# 12             NaN                   深圳           0.334
# 13             NaN         nHrKgKdJ1Mzt           0.322
# 14             NaN       xxx.com/github           0.322
# 15             NaN              2022-03           0.293
# 16             0.0                    0           0.839
# 17             NaN              xxx.com           0.603
# 18             NaN               github           0.322
#
#                  mean_or_top1                     std_or_top2  \
# 0                     23829.5                       13758.401
# 1         xuxiuying8050:0.65%             hongchang3029:0.63%
# 2                   rd:65.36%                    sales:17.26%
# 3             w2CfuqTz3:0.68%                 u9diCFdYZ:0.66%
# 4          O54DfqjlCrhL:0.70%              kUa61ygA6gI3:0.68%
# 5              edge_93:37.16%                chrome_90:33.38%
# 6               chrome:43.15%                     edge:37.16%
# 7                  win:90.52%                     macos:9.48%
# 8                win10:75.84%                     win7:10.81%
# 9   2022-04-02 17:02:24:0.01%       2022-02-16 11:36:12:0.01%
# 10                  内网:92.01%                            None
# 11                    211.336                          48.817
# 12                  深圳:33.38%                       成都:24.54%
# 13        nHrKgKdJ1Mzt:32.17%             dwS3cdn15GK4:22.89%
# 14      xxx.com/github:32.17%  wpsdoc.xxx.com/download:15.43%
# 15             2022-03:29.28%                  2022-04:26.86%
# 16                      0.161                           0.368
# 17             xxx.com:60.29%           wpsdoc.xxx.com:22.89%
# 18              github:32.17%                 download:15.43%
#
#                   min_or_top3                 1%_or_top4  \
# 0                         0.0                     476.59
# 1            tanliu3173:0.62%          liuhong6350:0.62%
# 2                 other:4.07%           accounting:3.56%
# 3             pPgzIf3S4:0.65%            7YnPN3fqd:0.65%
# 4          Rfv57YyO3vny:0.67%         5DmlITfRNR36:0.66%
# 5             safari_13:9.48%            chrome_77:5.32%
# 6                safari:9.48%                   ie:5.39%
# 7                        None                       None
# 8      macos_big_sur_11:9.48%                win11:3.87%
# 9   2022-04-28 09:33:53:0.01%  2022-03-04 17:13:36:0.01%
# 10                       None                       None
# 11                      200.0                      200.0
# 12                  杭州:18.47%                  北京:17.67%
# 13         2umVQwhiiwNJ:9.74%         sW0whYIx8LFM:8.51%
# 14         xxx.com/mail:9.74%    work.xxx.com/task:8.51%
# 15             2022-01:22.92%             2022-02:20.94%
# 16                        0.0                        0.0
# 17         work.xxx.com:8.51%     business.xxx.com:7.85%
# 18                 mail:9.74%                 task:8.51%
#
#                   10%_or_top5             50%_or_bottom5  \
# 0                      4765.9                    23829.5
# 1             lufan2545:0.62%       zhouxiumei4433:0.38%
# 2                    hr:1.75%                  rd:65.36%
# 3             DhTMwbtS5:0.64%            948U9MQcB:0.00%
# 4          TzmgdvYq3Kx0:0.66%         aUECyyFo55Zy:0.00%
# 5            firefox_78:4.82%            chrome_77:5.32%
# 6               firefox:4.82%              chrome:43.15%
# 7                        None                       None
# 8                        None                       None
# 9   2022-03-23 14:47:36:0.00%  2022-04-29 09:58:59:0.00%
# 10                       None                       None
# 11                      200.0                      200.0
# 12                   广州:0.99%                   郑州:0.42%
# 13         RwHe8Q1R7AlB:7.85%         RwHe8Q1R7AlB:7.85%
# 14    business.xxx.com/:7.85%   xxx.com/checkingin:1.99%
# 15                       None                       None
# 16                        0.0                        0.0
# 17           hr.xxx.com:0.46%             xxx.com:60.29%
# 18                     :8.32%                   oa:6.58%
#
#                75%_or_bottom4             90%_or_bottom3  \
# 0                    35744.25                    42893.1
# 1          chenjian4844:0.37%         wanggang1192:0.36%
# 2                sales:17.26%                other:4.07%
# 3             h75YAkAAL:0.00%            m7512MutA:0.00%
# 4          cREgOG9x3d9X:0.00%         NGfeE42d1yHY:0.00%
# 5            firefox_78:4.82%            chrome_93:4.44%
# 6                 edge:37.16%               safari:9.48%
# 7                        None                       None
# 8                win10:75.84%                win7:10.81%
# 9   2022-04-20 19:02:48:0.00%  2022-01-19 15:11:24:0.00%
# 10                       None                       None
# 11                      200.0                      200.0
# 12                   国外:0.36%                   未知:0.32%
# 13         fwM6KZKjrzjm:6.58%         9RAS6RNfETj5:1.99%
# 14   xxx.com/accounting:1.81%          hr.xxx.com/:0.46%
# 15             2022-03:29.28%             2022-04:26.86%
# 16                        0.0                        1.0
# 17      wpsdoc.xxx.com:22.89%         work.xxx.com:8.51%
# 18           checkingin:1.99%           accounting:1.81%
#
#                 99%_or_bottom2               max_or_bottom1
# 0                     47182.41                      47659.0
# 1         ranxiuzhen6780:0.33%              xujie9775:0.30%
# 2             accounting:3.56%                     hr:1.75%
# 3              ADL8GwW32:0.00%              g3dWezpzT:0.00%
# 4           T4hueKNccs7X:0.00%           A0TLDctT8OUR:0.00%
# 5                  ie_11:3.37%                   ie_9:2.02%
# 6                     ie:5.39%                firefox:4.82%
# 7                   win:90.52%                  macos:9.48%
# 8       macos_big_sur_11:9.48%                  win11:3.87%
# 9    2022-01-19 10:53:46:0.00%    2022-04-08 19:30:10:0.00%
# 10                        None                    内网:92.01%
# 11                       404.0                        502.0
# 12                    天津:0.30%                     苏州:0.30%
# 13          2UNHLdxlhIzv:1.81%           a5G25puBl9xj:0.46%
# 14  xxx.com/getLoginType:0.44%  xxx.com/getVerifyCode:0.44%
# 15              2022-01:22.92%               2022-02:20.94%
# 16                         1.0                          1.0
# 17      business.xxx.com:7.85%             hr.xxx.com:0.46%
# 18          getLoginType:0.44%          getVerifyCode:0.44%

# %% [markdown]
# ## 定义一次/一天/一月
# 1. op\_times\_groups 一次
# 2. op\_days 一天
# 3. op\_month 一月

# %%
df = pd.concat([df_row_train, df_row_val]).reset_index(drop=True)
df = df.sort_values(by='op_datetime')
# 认证日期时间
df['op_datetime'] = pd.to_datetime(df['op_datetime'])


# 将数据分为每一天
df['op_days'] = df['op_datetime'].map(lambda x: x.strftime('%Y-%m-%d'))

# 按客户进行统计这次认证和上次认证的时间差
df['op_second'] = df['op_datetime']
df['op_second1'] = df.groupby('device_num_transform')['op_second'].shift(1)

df['op_diff_second1'] = (df['op_second'] - df['op_second1']).map(lambda x: x.total_seconds())
df['op_diff_second1_tmp'] = df['op_diff_second1']>10
# 客户第几次登录
df['op_times_groups'] = df.groupby('device_num_transform')['op_diff_second1_tmp'].apply(lambda x: x.cumsum())

df = df.drop(columns=['op_second','op_second1','op_diff_second1_tmp'])

# %% [markdown]
# ## 网络嗅探相应特征生成
#
# 1.考虑特征范围为，客户+时间+ 按时间cumsum/cumunique

# %%
time_feats = ['op_times_groups', 'op_days', 'op_month']

cate_feats = ['department', 'ip_transform', 'browser_version', 'browser', 'os_type','os_version',
              'ip_type','http_status_code', 'op_city', 'log_system_transform', 'url_page','url_sit']

# 客户+时间+按时间cumsum/cumunique
# 累计量统计
df['helper'] = 1
# 是否为异常状态码
df['http_status_code_helper'] = df['http_status_code'].map(lambda x: 1 if x in [400, 500, 502, 404] else 0) 
# 给样本编号
df['sampler_index_helper'] = df['helper'].cumsum()

for i in time_feats:
    # cumsum
    df['device_num_transform_{}_cumsum'.format(i)] = df.groupby(['device_num_transform', i])['helper'].cumsum()
    # cumunique
    for j in cate_feats:
        index_set = set(df.groupby(['device_num_transform', i, j], as_index=False).first()['sampler_index_helper'].values)
        df['tmp_helper'] = df['sampler_index_helper'].map(lambda x: 1 if x in index_set else 0)
        df['device_num_transform_{}_{}_cumunique'.format(i, j)] = df.groupby(['device_num_transform', i])['tmp_helper'].cumsum()

        
remove_cols = [x for x in df.columns if x[-6:]=='helper']

df = df.drop(columns=remove_cols)

# %% [markdown]
# ## 暴力破解
# 1. 单个mac/ip/用户认证失败次数

# %%
time_feats = ['op_times_groups', 'op_days', 'op_month']

object_feats = ['ip_transform', 'user_name', 'device_num_transform']

# 累计量统计
df['helper'] = 1
# 是否为异常状态码
df['http_status_code_helper'] = df['http_status_code'].map(lambda x: 1 if x in [400, 500, 502, 404] else 0) 
# 给样本编号
df['sampler_index_helper'] = df['helper'].cumsum()

for i in time_feats:
    # 系统层面异常次数
    df['http_status_code_{}_cumsum'.format(i)] = df.groupby([i])['http_status_code_helper'].cumsum()
    for j in object_feats:
        # object层面异常次数
        df['{}_{}_http_status_code_error_code_cumsum'.format(j,i)] = df.groupby([i,j])['http_status_code_helper'].cumsum()
        
        # object层面异常个数
        index_set = set(df[df['http_status_code'].isin([400, 500, 502, 404])].groupby([i, j,  'http_status_code'], as_index=False).first()['sampler_index_helper'].values)
        df['tmp_helper'] = df['sampler_index_helper'].map(lambda x: 1 if x in index_set else 0)
        df['{}_{}_http_status_code_error_code_cumunique'.format(j,i)] = df.groupby([i,j])['tmp_helper'].cumsum()

remove_cols = [x for x in df.columns if x[-6:]=='helper']

df = df.drop(columns=remove_cols)

# %% [markdown]
# ## 账号异常行为
# 1. 账号+ip的登录次数
# 2. 账号的异常登录时间
# 3. 账号+ip的异常登录时间

# %%
# 几点钟
df['hour'] = df['op_datetime'].dt.hour
df['hour_sin'] = np.sin(df['hour']/24*2*np.pi)
df['hour_cos'] = np.cos(df['hour']/24*2*np.pi)

# 周几
df['dayofweek'] = df['op_datetime'].dt.dayofweek
df['dayofweek_sin'] = np.sin(df['dayofweek']/7*2*np.pi)
df['dayofweek_cos'] = np.cos(df['dayofweek']/7*2*np.pi)

# 一个月的第几天
df['day'] = df['op_datetime'].dt.day
df['day_sin'] = np.sin(df['day']/31*2*np.pi)
df['day_cos'] = np.cos(df['day']/31*2*np.pi)

# %%
# time_feats = ['op_times_groups', 'op_days', 'op_month']

# object_feats = ['ip_transform', 'user_name', 'device_num_transform']

# cate_feats = ['department', 'browser_version', 'browser', 'os_type','os_version',
#               'ip_type','http_status_code', 'op_city', 'log_system_transform', 'url_page','url_sit']

# for i in time_feats:
#     for j in object_feats:
#         for z in range(3, 10, 2):
#             tmp = df.groupby([i,j],as_index=False)['op_diff_second1'].rolling(z)

#             df['{}_{}_{}_op_diff_second1_mean'.format(i,j,z)] = tmp.mean()['op_diff_second1']
#             df['{}_{}_{}_op_diff_second1_sum'.format(i,j,z)] = tmp.sum()['op_diff_second1']
#             df['{}_{}_{}_op_diff_second1_std'.format(i,j,z)] = tmp.std()['op_diff_second1']
#             df['{}_{}_{}_op_diff_second1_var'.format(i,j,z)] = tmp.var()['op_diff_second1']
#         for k in cate_feats:
#             for z in range(3, 10, 2):
#                 tmp_t = df.groupby([i,j,k],as_index=False)['op_diff_second1'].rolling(z)
#                 df['{}_{}_{}_{}_op_diff_second1_mean'.format(i,j,k, z)] = tmp_t.mean()['op_diff_second1']
#                 df['{}_{}_{}_{}_op_diff_second1_sum'.format(i,j,k, z)] = tmp_t.sum()['op_diff_second1']
#                 df['{}_{}_{}_{}_op_diff_second1_std'.format(i,j,k, z)] = tmp_t.std()['op_diff_second1']
#                 df['{}_{}_{}_{}_op_diff_second1_var'.format(i,j,k, z)] = tmp_t.var()['op_diff_second1']

# %%
# time_feats = ['op_times_groups', 'op_days', 'op_month']

# object_feats = ['ip_transform', 'user_name', 'device_num_transform']

# cate_feats = ['department', 'browser_version', 'browser', 'os_type','os_version',
#               'ip_type','http_status_code', 'op_city', 'log_system_transform', 'url_page','url_sit']

# for i in time_feats:
#     for j in object_feats:
#         for z in range(3, 10, 2):
#             df['{}_{}_{}_op_diff_second1_mean'.format(i,j,z)] = df.groupby([i,j],as_index=False)['op_diff_second1'].rolling(z).mean()['op_diff_second1']
#             df['{}_{}_{}_op_diff_second1_sum'.format(i,j,z)] = df.groupby([i,j],as_index=False)['op_diff_second1'].rolling(z).sum()['op_diff_second1']
#             df['{}_{}_{}_op_diff_second1_std'.format(i,j,z)] = df.groupby([i,j],as_index=False)['op_diff_second1'].rolling(z).std()['op_diff_second1']
#             df['{}_{}_{}_op_diff_second1_var'.format(i,j,z)] = df.groupby([i,j],as_index=False)['op_diff_second1'].rolling(z).var()['op_diff_second1']
# #         for k in cate_feats:
# #             for z in range(3, 10, 2):
# #                 df['{}_{}_{}_{}_op_diff_second1_mean'.format(i,j,k, z)] = df.groupby([i,j,k],as_index=False)['op_diff_second1'].rolling(z).mean()['op_diff_second1']
# #                 df['{}_{}_{}_{}_op_diff_second1_sum'.format(i,j,k, z)] = df.groupby([i,j,k],as_index=False)['op_diff_second1'].rolling(z).sum()['op_diff_second1']
# #                 df['{}_{}_{}_{}_op_diff_second1_std'.format(i,j,k, z)] = df.groupby([i,j,k],as_index=False)['op_diff_second1'].rolling(z).std()['op_diff_second1']
# #                 df['{}_{}_{}_{}_op_diff_second1_var'.format(i,j,k, z)] = df.groupby([i,j,k],as_index=False)['op_diff_second1'].rolling(z).var()['op_diff_second1']

# %%
# cat_f = ['user_name','department','ip_transform','device_num_transform','browser_version','browser',
#  'os_type','os_version','ip_type','op_city','log_system_transform','url','url_sit','url_page']


# # 删除时间及类别型变量过多的特征
# remove_col = ['op_datetime', 'op_month', 'user_name', 'ip_transform', 'device_num_transform', 'op_days', 'ts', 'ts1', 'ts2','ts3']


# for f in cat_f:
#     df[f+'_ts_diff_mean'] = df.groupby([f])['ts_diff1'].transform('mean')
#     df[f+'_ts_diff_std'] = df.groupby([f])['ts_diff1'].transform('std')
#     df[f+'_ts_diff2_mean'] = df.groupby([f])['ts_diff2'].transform('mean')
#     df[f+'_ts_diff2_std'] = df.groupby([f])['ts_diff2'].transform('std')
#     df[f+'_ts_diff3_mean'] = df.groupby([f])['ts_diff3'].transform('mean')
#     df[f+'_ts_diff3_std'] = df.groupby([f])['ts_diff3'].transform('std')

#     df['device_num_transform_op_days_' + f+'_ts_diff_mean'] = df.groupby(['device_num_transform','op_days',f])['ts_diff1'].transform('mean')
#     df['device_num_transform_op_days_' + f+'_ts_diff_std'] = df.groupby(['device_num_transform','op_days',f])['ts_diff1'].transform('std')
#     df['device_num_transform_op_days_' + f+'_ts_diff2_mean'] = df.groupby(['device_num_transform','op_days',f])['ts_diff2'].transform('mean')
#     df['device_num_transform_op_days_' + f+'_ts_diff2_std'] = df.groupby(['device_num_transform','op_days',f])['ts_diff2'].transform('std')
#     df['device_num_transform_op_days_' + f+'_ts_diff3_mean'] = df.groupby(['device_num_transform','op_days',f])['ts_diff3'].transform('mean')
#     df['device_num_transform_op_days_' + f+'_ts_diff3_std'] = df.groupby(['device_num_transform','op_days',f])['ts_diff3'].transform('std')
    
#     df['device_num_transform_op_month_' + f+'_ts_diff_mean'] = df.groupby(['device_num_transform','op_month',f])['ts_diff1'].transform('mean')
#     df['device_num_transform_op_month_' + f+'_ts_diff_std'] = df.groupby(['device_num_transform','op_month',f])['ts_diff1'].transform('std')
#     df['device_num_transform_op_month_' + f+'_ts_diff2_mean'] = df.groupby(['device_num_transform','op_month',f])['ts_diff2'].transform('mean')
#     df['device_num_transform_op_month_' + f+'_ts_diff2_std'] = df.groupby(['device_num_transform','op_month',f])['ts_diff2'].transform('std')
#     df['device_num_transform_op_month_' + f+'_ts_diff3_mean'] = df.groupby(['device_num_transform','op_month',f])['ts_diff3'].transform('mean')
#     df['device_num_transform_op_month_' + f+'_ts_diff3_std'] = df.groupby(['device_num_transform','op_month',f])['ts_diff3'].transform('std')

# %% [markdown]
# ## 账号下载量异常
# 1. 平均object的下载次数
# 2. 平均查询时间

# %%
# 累计量统计
df['helper'] = 1

time_feats = ['op_times_groups', 'op_days', 'op_month']

object_feats = ['ip_transform', 'user_name', 'device_num_transform']

for i in time_feats:
    for j in object_feats:
        for f in df['url_page'].unique():
            df['{}_{}_{}_cumsum'.format(j, i, f)] = df[df['url_page']==f].groupby([i,j])['helper'].cumsum()
            for z in df['http_status_code'].unique():
                df['{}_{}_{}_{}_cumsum'.format(j, i, f, z)] = df[(df['url_page']==f)&(df['http_status_code']==z)].groupby([i,j])['helper'].cumsum()
        
remove_cols = [x for x in df.columns if x[-6:]=='helper']

df = df.drop(columns=remove_cols)

# %% [markdown]
# ## 特征筛选

# %%
# 删除时间及类别型变量过多的特征
remove_col = ['op_datetime', 'op_month', 'user_name', 'ip_transform', 'device_num_transform', 'op_days', 'ts', 'ts1', 'ts2','ts3']

remove_col = [x for x in df.columns if x in remove_col]
df = df.drop(columns=remove_col)
df.head()
# Out:
#           id department browser_version  browser os_type        os_version  \
# 44477  44477         rd       chrome_93   chrome     win             win10
# 45489  45489         rd       safari_13   safari   macos  macos_big_sur_11
# 45706  45706         hr      firefox_78  firefox     win              win7
# 45901  45901         rd         edge_93     edge     win             win10
# 43827  43827      sales            ie_9       ie     win             win10
#
#       ip_type  http_status_code op_city log_system_transform  \
# 44477      内网               200      深圳         nHrKgKdJ1Mzt
# 45489      内网               200      成都         nHrKgKdJ1Mzt
# 45706      内网               200      深圳         a5G25puBl9xj
# 45901      内网               200      杭州         nHrKgKdJ1Mzt
# 43827      内网               200      重庆         sW0whYIx8LFM
#
#                      url  is_risk       url_sit url_page  op_diff_second1  \
# 44477     xxx.com/github      1.0       xxx.com   github              NaN
# 45489     xxx.com/github      1.0       xxx.com   github              NaN
# 45706        hr.xxx.com/      1.0    hr.xxx.com                       NaN
# 45901     xxx.com/github      1.0       xxx.com   github              NaN
# 43827  work.xxx.com/task      1.0  work.xxx.com     task              NaN
#
#        op_times_groups  device_num_transform_op_times_groups_cumsum  \
# 44477                0                                            1
# 45489                0                                            1
# 45706                0                                            1
# 45901                0                                            1
# 43827                0                                            1
#
#        device_num_transform_op_times_groups_department_cumunique  \
# 44477                                                  1
# 45489                                                  1
# 45706                                                  1
# 45901                                                  1
# 43827                                                  1
#
#        device_num_transform_op_times_groups_ip_transform_cumunique  \
# 44477                                                  1
# 45489                                                  1
# 45706                                                  1
# 45901                                                  1
# 43827                                                  1
#
#        device_num_transform_op_times_groups_browser_version_cumunique  \
# 44477                                                  1
# 45489                                                  1
# 45706                                                  1
# 45901                                                  1
# 43827                                                  1
#
#        device_num_transform_op_times_groups_browser_cumunique  \
# 44477                                                  1
# 45489                                                  1
# 45706                                                  1
# 45901                                                  1
# 43827                                                  1
#
#        device_num_transform_op_times_groups_os_type_cumunique  \
# 44477                                                  1
# 45489                                                  1
# 45706                                                  1
# 45901                                                  1
# 43827                                                  1
#
#        device_num_transform_op_times_groups_os_version_cumunique  \
# 44477                                                  1
# 45489                                                  1
# 45706                                                  1
# 45901                                                  1
# 43827                                                  1
#
#        device_num_transform_op_times_groups_ip_type_cumunique  \
# 44477                                                  1
# 45489                                                  1
# 45706                                                  1
# 45901                                                  1
# 43827                                                  1
#
#        device_num_transform_op_times_groups_http_status_code_cumunique  \
# 44477                                                  1
# 45489                                                  1
# 45706                                                  1
# 45901                                                  1
# 43827                                                  1
#
#        device_num_transform_op_times_groups_op_city_cumunique  \
# 44477                                                  1
# 45489                                                  1
# 45706                                                  1
# 45901                                                  1
# 43827                                                  1
#
#        device_num_transform_op_times_groups_log_system_transform_cumunique  \
# 44477                                                  1
# 45489                                                  1
# 45706                                                  1
# 45901                                                  1
# 43827                                                  1
#
#        device_num_transform_op_times_groups_url_page_cumunique  \
# 44477                                                  1
# 45489                                                  1
# 45706                                                  1
# 45901                                                  1
# 43827                                                  1
#
#        device_num_transform_op_times_groups_url_sit_cumunique  \
# 44477                                                  1
# 45489                                                  1
# 45706                                                  1
# 45901                                                  1
# 43827                                                  1
#
#        device_num_transform_op_days_cumsum  \
# 44477                                    1
# 45489                                    1
# 45706                                    1
# 45901                                    1
# 43827                                    1
#
#        device_num_transform_op_days_department_cumunique  \
# 44477                                                  1
# 45489                                                  1
# 45706                                                  1
# 45901                                                  1
# 43827                                                  1
#
#        device_num_transform_op_days_ip_transform_cumunique  \
# 44477                                                  1
# 45489                                                  1
# 45706                                                  1
# 45901                                                  1
# 43827                                                  1
#
#        device_num_transform_op_days_browser_version_cumunique  \
# 44477                                                  1
# 45489                                                  1
# 45706                                                  1
# 45901                                                  1
# 43827                                                  1
#
#        device_num_transform_op_days_browser_cumunique  \
# 44477                                               1
# 45489                                               1
# 45706                                               1
# 45901                                               1
# 43827                                               1
#
#        device_num_transform_op_days_os_type_cumunique  \
# 44477                                               1
# 45489                                               1
# 45706                                               1
# 45901                                               1
# 43827                                               1
#
#        device_num_transform_op_days_os_version_cumunique  \
# 44477                                                  1
# 45489                                                  1
# 45706                                                  1
# 45901                                                  1
# 43827                                                  1
#
#        device_num_transform_op_days_ip_type_cumunique  \
# 44477                                               1
# 45489                                               1
# 45706                                               1
# 45901                                               1
# 43827                                               1
#
#        device_num_transform_op_days_http_status_code_cumunique  \
# 44477                                                  1
# 45489                                                  1
# 45706                                                  1
# 45901                                                  1
# 43827                                                  1
#
#        device_num_transform_op_days_op_city_cumunique  \
# 44477                                               1
# 45489                                               1
# 45706                                               1
# 45901                                               1
# 43827                                               1
#
#        device_num_transform_op_days_log_system_transform_cumunique  \
# 44477                                                  1
# 45489                                                  1
# 45706                                                  1
# 45901                                                  1
# 43827                                                  1
#
#        device_num_transform_op_days_url_page_cumunique  \
# 44477                                                1
# 45489                                                1
# 45706                                                1
# 45901                                                1
# 43827                                                1
#
#        device_num_transform_op_days_url_sit_cumunique  \
# 44477                                               1
# 45489                                               1
# 45706                                               1
# 45901                                               1
# 43827                                               1
#
#        device_num_transform_op_month_cumsum  \
# 44477                                     1
# 45489                                     1
# 45706                                     1
# 45901                                     1
# 43827                                     1
#
#        device_num_transform_op_month_department_cumunique  \
# 44477                                                  1
# 45489                                                  1
# 45706                                                  1
# 45901                                                  1
# 43827                                                  1
#
#        device_num_transform_op_month_ip_transform_cumunique  \
# 44477                                                  1
# 45489                                                  1
# 45706                                                  1
# 45901                                                  1
# 43827                                                  1
#
#        device_num_transform_op_month_browser_version_cumunique  \
# 44477                                                  1
# 45489                                                  1
# 45706                                                  1
# 45901                                                  1
# 43827                                                  1
#
#        device_num_transform_op_month_browser_cumunique  \
# 44477                                                1
# 45489                                                1
# 45706                                                1
# 45901                                                1
# 43827                                                1
#
#        device_num_transform_op_month_os_type_cumunique  \
# 44477                                                1
# 45489                                                1
# 45706                                                1
# 45901                                                1
# 43827                                                1
#
#        device_num_transform_op_month_os_version_cumunique  \
# 44477                                                  1
# 45489                                                  1
# 45706                                                  1
# 45901                                                  1
# 43827                                                  1
#
#        device_num_transform_op_month_ip_type_cumunique  \
# 44477                                                1
# 45489                                                1
# 45706                                                1
# 45901                                                1
# 43827                                                1
#
#        device_num_transform_op_month_http_status_code_cumunique  \
# 44477                                                  1
# 45489                                                  1
# 45706                                                  1
# 45901                                                  1
# 43827                                                  1
#
#        device_num_transform_op_month_op_city_cumunique  \
# 44477                                                1
# 45489                                                1
# 45706                                                1
# 45901                                                1
# 43827                                                1
#
#        device_num_transform_op_month_log_system_transform_cumunique  \
# 44477                                                  1
# 45489                                                  1
# 45706                                                  1
# 45901                                                  1
# 43827                                                  1
#
#        device_num_transform_op_month_url_page_cumunique  \
# 44477                                                 1
# 45489                                                 1
# 45706                                                 1
# 45901                                                 1
# 43827                                                 1
#
#        device_num_transform_op_month_url_sit_cumunique  \
# 44477                                                1
# 45489                                                1
# 45706                                                1
# 45901                                                1
# 43827                                                1
#
#        http_status_code_op_times_groups_cumsum  \
# 44477                                        0
# 45489                                        0
# 45706                                        0
# 45901                                        0
# 43827                                        0
#
#        ip_transform_op_times_groups_http_status_code_error_code_cumsum  \
# 44477                                                  0
# 45489                                                  0
# 45706                                                  0
# 45901                                                  0
# 43827                                                  0
#
#        ip_transform_op_times_groups_http_status_code_error_code_cumunique  \
# 44477                                                  0
# 45489                                                  0
# 45706                                                  0
# 45901                                                  0
# 43827                                                  0
#
#        user_name_op_times_groups_http_status_code_error_code_cumsum  \
# 44477                                                  0
# 45489                                                  0
# 45706                                                  0
# 45901                                                  0
# 43827                                                  0
#
#        user_name_op_times_groups_http_status_code_error_code_cumunique  \
# 44477                                                  0
# 45489                                                  0
# 45706                                                  0
# 45901                                                  0
# 43827                                                  0
#
#        device_num_transform_op_times_groups_http_status_code_error_code_cumsum  \
# 44477                                                  0
# 45489                                                  0
# 45706                                                  0
# 45901                                                  0
# 43827                                                  0
#
#        device_num_transform_op_times_groups_http_status_code_error_code_cumunique  \
# 44477                                                  0
# 45489                                                  0
# 45706                                                  0
# 45901                                                  0
# 43827                                                  0
#
#        http_status_code_op_days_cumsum  \
# 44477                                0
# 45489                                0
# 45706                                0
# 45901                                0
# 43827                                0
#
#        ip_transform_op_days_http_status_code_error_code_cumsum  \
# 44477                                                  0
# 45489                                                  0
# 45706                                                  0
# 45901                                                  0
# 43827                                                  0
#
#        ip_transform_op_days_http_status_code_error_code_cumunique  \
# 44477                                                  0
# 45489                                                  0
# 45706                                                  0
# 45901                                                  0
# 43827                                                  0
#
#        user_name_op_days_http_status_code_error_code_cumsum  \
# 44477                                                  0
# 45489                                                  0
# 45706                                                  0
# 45901                                                  0
# 43827                                                  0
#
#        user_name_op_days_http_status_code_error_code_cumunique  \
# 44477                                                  0
# 45489                                                  0
# 45706                                                  0
# 45901                                                  0
# 43827                                                  0
#
#        device_num_transform_op_days_http_status_code_error_code_cumsum  \
# 44477                                                  0
# 45489                                                  0
# 45706                                                  0
# 45901                                                  0
# 43827                                                  0
#
#        device_num_transform_op_days_http_status_code_error_code_cumunique  \
# 44477                                                  0
# 45489                                                  0
# 45706                                                  0
# 45901                                                  0
# 43827                                                  0
#
#        http_status_code_op_month_cumsum  \
# 44477                                 0
# 45489                                 0
# 45706                                 0
# 45901                                 0
# 43827                                 0
#
#        ip_transform_op_month_http_status_code_error_code_cumsum  \
# 44477                                                  0
# 45489                                                  0
# 45706                                                  0
# 45901                                                  0
# 43827                                                  0
#
#        ip_transform_op_month_http_status_code_error_code_cumunique  \
# 44477                                                  0
# 45489                                                  0
# 45706                                                  0
# 45901                                                  0
# 43827                                                  0
#
#        user_name_op_month_http_status_code_error_code_cumsum  \
# 44477                                                  0
# 45489                                                  0
# 45706                                                  0
# 45901                                                  0
# 43827                                                  0
#
#        user_name_op_month_http_status_code_error_code_cumunique  \
# 44477                                                  0
# 45489                                                  0
# 45706                                                  0
# 45901                                                  0
# 43827                                                  0
#
#        device_num_transform_op_month_http_status_code_error_code_cumsum  \
# 44477                                                  0
# 45489                                                  0
# 45706                                                  0
# 45901                                                  0
# 43827                                                  0
#
#        device_num_transform_op_month_http_status_code_error_code_cumunique  \
# 44477                                                  0
# 45489                                                  0
# 45706                                                  0
# 45901                                                  0
# 43827                                                  0
#
#        hour  hour_sin  hour_cos  dayofweek  dayofweek_sin  dayofweek_cos  day  \
# 44477     2  0.500000  0.866025          4      -0.433884      -0.900969    7
# 45489     2  0.500000  0.866025          4      -0.433884      -0.900969    7
# 45706     3  0.707107  0.707107          4      -0.433884      -0.900969    7
# 45901     4  0.866025  0.500000          4      -0.433884      -0.900969    7
# 43827     5  0.965926  0.258819          4      -0.433884      -0.900969    7
#
#         day_sin   day_cos  ip_transform_op_times_groups_github_cumsum  \
# 44477  0.988468  0.151428                                         1.0
# 45489  0.988468  0.151428                                         1.0
# 45706  0.988468  0.151428                                         NaN
# 45901  0.988468  0.151428                                         1.0
# 43827  0.988468  0.151428                                         NaN
#
#        ip_transform_op_times_groups_github_200_cumsum  \
# 44477                                             1.0
# 45489                                             1.0
# 45706                                             NaN
# 45901                                             1.0
# 43827                                             NaN
#
#        ip_transform_op_times_groups_github_400_cumsum  \
# 44477                                             NaN
# 45489                                             NaN
# 45706                                             NaN
# 45901                                             NaN
# 43827                                             NaN
#
#        ip_transform_op_times_groups_github_500_cumsum  \
# 44477                                             NaN
# 45489                                             NaN
# 45706                                             NaN
# 45901                                             NaN
# 43827                                             NaN
#
#        ip_transform_op_times_groups_github_502_cumsum  \
# 44477                                             NaN
# 45489                                             NaN
# 45706                                             NaN
# 45901                                             NaN
# 43827                                             NaN
#
#        ip_transform_op_times_groups_github_404_cumsum  \
# 44477                                             NaN
# 45489                                             NaN
# 45706                                             NaN
# 45901                                             NaN
# 43827                                             NaN
#
#        ip_transform_op_times_groups__cumsum  \
# 44477                                   NaN
# 45489                                   NaN
# 45706                                   1.0
# 45901                                   NaN
# 43827                                   NaN
#
#        ip_transform_op_times_groups__200_cumsum  \
# 44477                                       NaN
# 45489                                       NaN
# 45706                                       1.0
# 45901                                       NaN
# 43827                                       NaN
#
#        ip_transform_op_times_groups__400_cumsum  \
# 44477                                       NaN
# 45489                                       NaN
# 45706                                       NaN
# 45901                                       NaN
# 43827                                       NaN
#
#        ip_transform_op_times_groups__500_cumsum  \
# 44477                                       NaN
# 45489                                       NaN
# 45706                                       NaN
# 45901                                       NaN
# 43827                                       NaN
#
#        ip_transform_op_times_groups__502_cumsum  \
# 44477                                       NaN
# 45489                                       NaN
# 45706                                       NaN
# 45901                                       NaN
# 43827                                       NaN
#
#        ip_transform_op_times_groups__404_cumsum  \
# 44477                                       NaN
# 45489                                       NaN
# 45706                                       NaN
# 45901                                       NaN
# 43827                                       NaN
#
#        ip_transform_op_times_groups_task_cumsum  \
# 44477                                       NaN
# 45489                                       NaN
# 45706                                       NaN
# 45901                                       NaN
# 43827                                       1.0
#
#        ip_transform_op_times_groups_task_200_cumsum  \
# 44477                                           NaN
# 45489                                           NaN
# 45706                                           NaN
# 45901                                           NaN
# 43827                                           1.0
#
#        ip_transform_op_times_groups_task_400_cumsum  ...  \
# 44477                                           NaN  ...
# 45489                                           NaN  ...
# 45706                                           NaN  ...
# 45901                                           NaN  ...
# 43827                                           NaN  ...
#
#        user_name_op_days_kdocs_400_cumsum  user_name_op_days_kdocs_500_cumsum  \
# 44477                                 NaN                                 NaN
# 45489                                 NaN                                 NaN
# 45706                                 NaN                                 NaN
# 45901                                 NaN                                 NaN
# 43827                                 NaN                                 NaN
#
#        user_name_op_days_kdocs_502_cumsum  user_name_op_days_kdocs_404_cumsum  \
# 44477                                 NaN                                 NaN
# 45489                                 NaN                                 NaN
# 45706                                 NaN                                 NaN
# 45901                                 NaN                                 NaN
# 43827                                 NaN                                 NaN
#
#        user_name_op_days_checkingin_cumsum  \
# 44477                                  NaN
# 45489                                  NaN
# 45706                                  NaN
# 45901                                  NaN
# 43827                                  NaN
#
#        user_name_op_days_checkingin_200_cumsum  \
# 44477                                      NaN
# 45489                                      NaN
# 45706                                      NaN
# 45901                                      NaN
# 43827                                      NaN
#
#        user_name_op_days_checkingin_400_cumsum  \
# 44477                                      NaN
# 45489                                      NaN
# 45706                                      NaN
# 45901                                      NaN
# 43827                                      NaN
#
#        user_name_op_days_checkingin_500_cumsum  \
# 44477                                      NaN
# 45489                                      NaN
# 45706                                      NaN
# 45901                                      NaN
# 43827                                      NaN
#
#        user_name_op_days_checkingin_502_cumsum  \
# 44477                                      NaN
# 45489                                      NaN
# 45706                                      NaN
# 45901                                      NaN
# 43827                                      NaN
#
#        user_name_op_days_checkingin_404_cumsum  \
# 44477                                      NaN
# 45489                                      NaN
# 45706                                      NaN
# 45901                                      NaN
# 43827                                      NaN
#
#        user_name_op_days_getLoginType_cumsum  \
# 44477                                    NaN
# 45489                                    NaN
# 45706                                    NaN
# 45901                                    NaN
# 43827                                    NaN
#
#        user_name_op_days_getLoginType_200_cumsum  \
# 44477                                        NaN
# 45489                                        NaN
# 45706                                        NaN
# 45901                                        NaN
# 43827                                        NaN
#
#        user_name_op_days_getLoginType_400_cumsum  \
# 44477                                        NaN
# 45489                                        NaN
# 45706                                        NaN
# 45901                                        NaN
# 43827                                        NaN
#
#        user_name_op_days_getLoginType_500_cumsum  \
# 44477                                        NaN
# 45489                                        NaN
# 45706                                        NaN
# 45901                                        NaN
# 43827                                        NaN
#
#        user_name_op_days_getLoginType_502_cumsum  \
# 44477                                        NaN
# 45489                                        NaN
# 45706                                        NaN
# 45901                                        NaN
# 43827                                        NaN
#
#        user_name_op_days_getLoginType_404_cumsum  \
# 44477                                        NaN
# 45489                                        NaN
# 45706                                        NaN
# 45901                                        NaN
# 43827                                        NaN
#
#        user_name_op_days_download_cumsum  \
# 44477                                NaN
# 45489                                NaN
# 45706                                NaN
# 45901                                NaN
# 43827                                NaN
#
#        user_name_op_days_download_200_cumsum  \
# 44477                                    NaN
# 45489                                    NaN
# 45706                                    NaN
# 45901                                    NaN
# 43827                                    NaN
#
#        user_name_op_days_download_400_cumsum  \
# 44477                                    NaN
# 45489                                    NaN
# 45706                                    NaN
# 45901                                    NaN
# 43827                                    NaN
#
#        user_name_op_days_download_500_cumsum  \
# 44477                                    NaN
# 45489                                    NaN
# 45706                                    NaN
# 45901                                    NaN
# 43827                                    NaN
#
#        user_name_op_days_download_502_cumsum  \
# 44477                                    NaN
# 45489                                    NaN
# 45706                                    NaN
# 45901                                    NaN
# 43827                                    NaN
#
#        user_name_op_days_download_404_cumsum  \
# 44477                                    NaN
# 45489                                    NaN
# 45706                                    NaN
# 45901                                    NaN
# 43827                                    NaN
#
#        user_name_op_days_accounting_cumsum  \
# 44477                                  NaN
# 45489                                  NaN
# 45706                                  NaN
# 45901                                  NaN
# 43827                                  NaN
#
#        user_name_op_days_accounting_200_cumsum  \
# 44477                                      NaN
# 45489                                      NaN
# 45706                                      NaN
# 45901                                      NaN
# 43827                                      NaN
#
#        user_name_op_days_accounting_400_cumsum  \
# 44477                                      NaN
# 45489                                      NaN
# 45706                                      NaN
# 45901                                      NaN
# 43827                                      NaN
#
#        user_name_op_days_accounting_500_cumsum  \
# 44477                                      NaN
# 45489                                      NaN
# 45706                                      NaN
# 45901                                      NaN
# 43827                                      NaN
#
#        user_name_op_days_accounting_502_cumsum  \
# 44477                                      NaN
# 45489                                      NaN
# 45706                                      NaN
# 45901                                      NaN
# 43827                                      NaN
#
#        user_name_op_days_accounting_404_cumsum  \
# 44477                                      NaN
# 45489                                      NaN
# 45706                                      NaN
# 45901                                      NaN
# 43827                                      NaN
#
#        device_num_transform_op_days_github_cumsum  \
# 44477                                         1.0
# 45489                                         1.0
# 45706                                         NaN
# 45901                                         1.0
# 43827                                         NaN
#
#        device_num_transform_op_days_github_200_cumsum  \
# 44477                                             1.0
# 45489                                             1.0
# 45706                                             NaN
# 45901                                             1.0
# 43827                                             NaN
#
#        device_num_transform_op_days_github_400_cumsum  \
# 44477                                             NaN
# 45489                                             NaN
# 45706                                             NaN
# 45901                                             NaN
# 43827                                             NaN
#
#        device_num_transform_op_days_github_500_cumsum  \
# 44477                                             NaN
# 45489                                             NaN
# 45706                                             NaN
# 45901                                             NaN
# 43827                                             NaN
#
#        device_num_transform_op_days_github_502_cumsum  \
# 44477                                             NaN
# 45489                                             NaN
# 45706                                             NaN
# 45901                                             NaN
# 43827                                             NaN
#
#        device_num_transform_op_days_github_404_cumsum  \
# 44477                                             NaN
# 45489                                             NaN
# 45706                                             NaN
# 45901                                             NaN
# 43827                                             NaN
#
#        device_num_transform_op_days__cumsum  \
# 44477                                   NaN
# 45489                                   NaN
# 45706                                   1.0
# 45901                                   NaN
# 43827                                   NaN
#
#        device_num_transform_op_days__200_cumsum  \
# 44477                                       NaN
# 45489                                       NaN
# 45706                                       1.0
# 45901                                       NaN
# 43827                                       NaN
#
#        device_num_transform_op_days__400_cumsum  \
# 44477                                       NaN
# 45489                                       NaN
# 45706                                       NaN
# 45901                                       NaN
# 43827                                       NaN
#
#        device_num_transform_op_days__500_cumsum  \
# 44477                                       NaN
# 45489                                       NaN
# 45706                                       NaN
# 45901                                       NaN
# 43827                                       NaN
#
#        device_num_transform_op_days__502_cumsum  \
# 44477                                       NaN
# 45489                                       NaN
# 45706                                       NaN
# 45901                                       NaN
# 43827                                       NaN
#
#        device_num_transform_op_days__404_cumsum  \
# 44477                                       NaN
# 45489                                       NaN
# 45706                                       NaN
# 45901                                       NaN
# 43827                                       NaN
#
#        device_num_transform_op_days_task_cumsum  \
# 44477                                       NaN
# 45489                                       NaN
# 45706                                       NaN
# 45901                                       NaN
# 43827                                       1.0
#
#        device_num_transform_op_days_task_200_cumsum  \
# 44477                                           NaN
# 45489                                           NaN
# 45706                                           NaN
# 45901                                           NaN
# 43827                                           1.0
#
#        device_num_transform_op_days_task_400_cumsum  \
# 44477                                           NaN
# 45489                                           NaN
# 45706                                           NaN
# 45901                                           NaN
# 43827                                           NaN
#
#        device_num_transform_op_days_task_500_cumsum  \
# 44477                                           NaN
# 45489                                           NaN
# 45706                                           NaN
# 45901                                           NaN
# 43827                                           NaN
#
#        device_num_transform_op_days_task_502_cumsum  \
# 44477                                           NaN
# 45489                                           NaN
# 45706                                           NaN
# 45901                                           NaN
# 43827                                           NaN
#
#        device_num_transform_op_days_task_404_cumsum  \
# 44477                                           NaN
# 45489                                           NaN
# 45706                                           NaN
# 45901                                           NaN
# 43827                                           NaN
#
#        device_num_transform_op_days_mail_cumsum  \
# 44477                                       NaN
# 45489                                       NaN
# 45706                                       NaN
# 45901                                       NaN
# 43827                                       NaN
#
#        device_num_transform_op_days_mail_200_cumsum  \
# 44477                                           NaN
# 45489                                           NaN
# 45706                                           NaN
# 45901                                           NaN
# 43827                                           NaN
#
#        device_num_transform_op_days_mail_400_cumsum  \
# 44477                                           NaN
# 45489                                           NaN
# 45706                                           NaN
# 45901                                           NaN
# 43827                                           NaN
#
#        device_num_transform_op_days_mail_500_cumsum  \
# 44477                                           NaN
# 45489                                           NaN
# 45706                                           NaN
# 45901                                           NaN
# 43827                                           NaN
#
#        device_num_transform_op_days_mail_502_cumsum  \
# 44477                                           NaN
# 45489                                           NaN
# 45706                                           NaN
# 45901                                           NaN
# 43827                                           NaN
#
#        device_num_transform_op_days_mail_404_cumsum  \
# 44477                                           NaN
# 45489                                           NaN
# 45706                                           NaN
# 45901                                           NaN
# 43827                                           NaN
#
#        device_num_transform_op_days_oa_cumsum  \
# 44477                                     NaN
# 45489                                     NaN
# 45706                                     NaN
# 45901                                     NaN
# 43827                                     NaN
#
#        device_num_transform_op_days_oa_200_cumsum  \
# 44477                                         NaN
# 45489                                         NaN
# 45706                                         NaN
# 45901                                         NaN
# 43827                                         NaN
#
#        device_num_transform_op_days_oa_400_cumsum  \
# 44477                                         NaN
# 45489                                         NaN
# 45706                                         NaN
# 45901                                         NaN
# 43827                                         NaN
#
#        device_num_transform_op_days_oa_500_cumsum  \
# 44477                                         NaN
# 45489                                         NaN
# 45706                                         NaN
# 45901                                         NaN
# 43827                                         NaN
#
#        device_num_transform_op_days_oa_502_cumsum  \
# 44477                                         NaN
# 45489                                         NaN
# 45706                                         NaN
# 45901                                         NaN
# 43827                                         NaN
#
#        device_num_transform_op_days_oa_404_cumsum  \
# 44477                                         NaN
# 45489                                         NaN
# 45706                                         NaN
# 45901                                         NaN
# 43827                                         NaN
#
#        device_num_transform_op_days_getVerifyCode_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_getVerifyCode_200_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_getVerifyCode_400_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_getVerifyCode_500_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_getVerifyCode_502_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_getVerifyCode_404_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_loginAuth_cumsum  \
# 44477                                            NaN
# 45489                                            NaN
# 45706                                            NaN
# 45901                                            NaN
# 43827                                            NaN
#
#        device_num_transform_op_days_loginAuth_200_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_loginAuth_400_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_loginAuth_500_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_loginAuth_502_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_loginAuth_404_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_kdocs_cumsum  \
# 44477                                        NaN
# 45489                                        NaN
# 45706                                        NaN
# 45901                                        NaN
# 43827                                        NaN
#
#        device_num_transform_op_days_kdocs_200_cumsum  \
# 44477                                            NaN
# 45489                                            NaN
# 45706                                            NaN
# 45901                                            NaN
# 43827                                            NaN
#
#        device_num_transform_op_days_kdocs_400_cumsum  \
# 44477                                            NaN
# 45489                                            NaN
# 45706                                            NaN
# 45901                                            NaN
# 43827                                            NaN
#
#        device_num_transform_op_days_kdocs_500_cumsum  \
# 44477                                            NaN
# 45489                                            NaN
# 45706                                            NaN
# 45901                                            NaN
# 43827                                            NaN
#
#        device_num_transform_op_days_kdocs_502_cumsum  \
# 44477                                            NaN
# 45489                                            NaN
# 45706                                            NaN
# 45901                                            NaN
# 43827                                            NaN
#
#        device_num_transform_op_days_kdocs_404_cumsum  \
# 44477                                            NaN
# 45489                                            NaN
# 45706                                            NaN
# 45901                                            NaN
# 43827                                            NaN
#
#        device_num_transform_op_days_checkingin_cumsum  \
# 44477                                             NaN
# 45489                                             NaN
# 45706                                             NaN
# 45901                                             NaN
# 43827                                             NaN
#
#        device_num_transform_op_days_checkingin_200_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_checkingin_400_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_checkingin_500_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_checkingin_502_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_checkingin_404_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_getLoginType_cumsum  \
# 44477                                               NaN
# 45489                                               NaN
# 45706                                               NaN
# 45901                                               NaN
# 43827                                               NaN
#
#        device_num_transform_op_days_getLoginType_200_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_getLoginType_400_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_getLoginType_500_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_getLoginType_502_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_getLoginType_404_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_download_cumsum  \
# 44477                                           NaN
# 45489                                           NaN
# 45706                                           NaN
# 45901                                           NaN
# 43827                                           NaN
#
#        device_num_transform_op_days_download_200_cumsum  \
# 44477                                               NaN
# 45489                                               NaN
# 45706                                               NaN
# 45901                                               NaN
# 43827                                               NaN
#
#        device_num_transform_op_days_download_400_cumsum  \
# 44477                                               NaN
# 45489                                               NaN
# 45706                                               NaN
# 45901                                               NaN
# 43827                                               NaN
#
#        device_num_transform_op_days_download_500_cumsum  \
# 44477                                               NaN
# 45489                                               NaN
# 45706                                               NaN
# 45901                                               NaN
# 43827                                               NaN
#
#        device_num_transform_op_days_download_502_cumsum  \
# 44477                                               NaN
# 45489                                               NaN
# 45706                                               NaN
# 45901                                               NaN
# 43827                                               NaN
#
#        device_num_transform_op_days_download_404_cumsum  \
# 44477                                               NaN
# 45489                                               NaN
# 45706                                               NaN
# 45901                                               NaN
# 43827                                               NaN
#
#        device_num_transform_op_days_accounting_cumsum  \
# 44477                                             NaN
# 45489                                             NaN
# 45706                                             NaN
# 45901                                             NaN
# 43827                                             NaN
#
#        device_num_transform_op_days_accounting_200_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_accounting_400_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_accounting_500_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_accounting_502_cumsum  \
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
#        device_num_transform_op_days_accounting_404_cumsum
# 44477                                                NaN
# 45489                                                NaN
# 45706                                                NaN
# 45901                                                NaN
# 43827                                                NaN
#
# [5 rows x 517 columns]

# %% [markdown]
# ### 评分卡特征筛选

# %%
df_row_train = df[df[y_label].notna()].reset_index(drop=True)
df_row_val = df[df[y_label].isna()].reset_index(drop=True)

df_train, df_test, convert_cols = sp.transform_data_detail(df_row_train, df_row_val, y_label, excel_path=path_output_report)
df_train.head()
# Out:
# sheet05.可能为数值类型的object类型数据统计在/Users/liliangshan/workspace/python/01_datasets/ccf_system_access_risk_identification/results/01_原始数据探察_20221014.xlsx中已经存在，我们将对原文件进行覆盖
# sheet06.数据预处理在/Users/liliangshan/workspace/python/01_datasets/ccf_system_access_risk_identification/results/01_原始数据探察_20221014.xlsx中已经存在，我们将对原文件进行覆盖
#       id department browser_version  browser        os_version op_city  \
# 0  44477         rd       chrome_93   chrome             win10      深圳
# 1  45489         rd       safari_13   safari  macos_big_sur_11      成都
# 2  45706         hr      firefox_78  firefox              win7      深圳
# 3  45901         rd         edge_93     edge             win10      杭州
# 4  43827      sales            ie_9       ie             win10      重庆
#
#   log_system_transform                url  is_risk       url_sit url_page  \
# 0         nHrKgKdJ1Mzt     xxx.com/github      1.0       xxx.com   github
# 1         nHrKgKdJ1Mzt     xxx.com/github      1.0       xxx.com   github
# 2         a5G25puBl9xj        hr.xxx.com/      1.0    hr.xxx.com
# 3         nHrKgKdJ1Mzt     xxx.com/github      1.0       xxx.com   github
# 4         sW0whYIx8LFM  work.xxx.com/task      1.0  work.xxx.com     task
#
#    op_diff_second1  op_times_groups  \
# 0              NaN                0
# 1              NaN                0
# 2              NaN                0
# 3              NaN                0
# 4              NaN                0
#
#    device_num_transform_op_times_groups_cumsum  \
# 0                                            1
# 1                                            1
# 2                                            1
# 3                                            1
# 4                                            1
#
#    device_num_transform_op_times_groups_url_page_cumunique  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    device_num_transform_op_days_cumsum  \
# 0                                    1
# 1                                    1
# 2                                    1
# 3                                    1
# 4                                    1
#
#    device_num_transform_op_days_log_system_transform_cumunique  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    device_num_transform_op_days_url_page_cumunique  \
# 0                                                1
# 1                                                1
# 2                                                1
# 3                                                1
# 4                                                1
#
#    device_num_transform_op_days_url_sit_cumunique  \
# 0                                               1
# 1                                               1
# 2                                               1
# 3                                               1
# 4                                               1
#
#    device_num_transform_op_month_cumsum  \
# 0                                     1
# 1                                     1
# 2                                     1
# 3                                     1
# 4                                     1
#
#    device_num_transform_op_month_ip_transform_cumunique  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    device_num_transform_op_month_http_status_code_cumunique  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    device_num_transform_op_month_op_city_cumunique  \
# 0                                                1
# 1                                                1
# 2                                                1
# 3                                                1
# 4                                                1
#
#    device_num_transform_op_month_log_system_transform_cumunique  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    device_num_transform_op_month_url_page_cumunique  \
# 0                                                 1
# 1                                                 1
# 2                                                 1
# 3                                                 1
# 4                                                 1
#
#    device_num_transform_op_month_url_sit_cumunique  \
# 0                                                1
# 1                                                1
# 2                                                1
# 3                                                1
# 4                                                1
#
#    http_status_code_op_times_groups_cumsum  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
#
#    user_name_op_times_groups_http_status_code_error_code_cumsum  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    user_name_op_times_groups_http_status_code_error_code_cumunique  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    http_status_code_op_days_cumsum  \
# 0                                0
# 1                                0
# 2                                0
# 3                                0
# 4                                0
#
#    user_name_op_days_http_status_code_error_code_cumsum  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    user_name_op_days_http_status_code_error_code_cumunique  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    http_status_code_op_month_cumsum  \
# 0                                 0
# 1                                 0
# 2                                 0
# 3                                 0
# 4                                 0
#
#    ip_transform_op_month_http_status_code_error_code_cumsum  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    ip_transform_op_month_http_status_code_error_code_cumunique  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    user_name_op_month_http_status_code_error_code_cumsum  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    user_name_op_month_http_status_code_error_code_cumunique  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    device_num_transform_op_month_http_status_code_error_code_cumsum  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    device_num_transform_op_month_http_status_code_error_code_cumunique  hour  \
# 0                                                  0                       2
# 1                                                  0                       2
# 2                                                  0                       3
# 3                                                  0                       4
# 4                                                  0                       5
#
#    hour_sin  hour_cos  dayofweek  dayofweek_sin  dayofweek_cos  day   day_sin  \
# 0  0.500000  0.866025          4      -0.433884      -0.900969    7  0.988468
# 1  0.500000  0.866025          4      -0.433884      -0.900969    7  0.988468
# 2  0.707107  0.707107          4      -0.433884      -0.900969    7  0.988468
# 3  0.866025  0.500000          4      -0.433884      -0.900969    7  0.988468
# 4  0.965926  0.258819          4      -0.433884      -0.900969    7  0.988468
#
#     day_cos  ip_transform_op_times_groups_github_cumsum  \
# 0  0.151428                                         1.0
# 1  0.151428                                         1.0
# 2  0.151428                                         NaN
# 3  0.151428                                         1.0
# 4  0.151428                                         NaN
#
#    ip_transform_op_times_groups_github_200_cumsum  \
# 0                                             1.0
# 1                                             1.0
# 2                                             NaN
# 3                                             1.0
# 4                                             NaN
#
#    ip_transform_op_times_groups_download_cumsum  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    ip_transform_op_times_groups_download_200_cumsum  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    user_name_op_times_groups_github_cumsum  \
# 0                                      1.0
# 1                                      1.0
# 2                                      NaN
# 3                                      1.0
# 4                                      NaN
#
#    user_name_op_times_groups_github_200_cumsum  \
# 0                                          1.0
# 1                                          1.0
# 2                                          NaN
# 3                                          1.0
# 4                                          NaN
#
#    user_name_op_times_groups_download_cumsum  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    user_name_op_times_groups_download_200_cumsum  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    device_num_transform_op_times_groups_github_cumsum  \
# 0                                                1.0
# 1                                                1.0
# 2                                                NaN
# 3                                                1.0
# 4                                                NaN
#
#    device_num_transform_op_times_groups_github_200_cumsum  \
# 0                                                1.0
# 1                                                1.0
# 2                                                NaN
# 3                                                1.0
# 4                                                NaN
#
#    device_num_transform_op_times_groups_download_cumsum  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    device_num_transform_op_times_groups_download_200_cumsum  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ip_transform_op_days_github_cumsum  ip_transform_op_days_github_200_cumsum  \
# 0                                 1.0                                     1.0
# 1                                 1.0                                     1.0
# 2                                 NaN                                     NaN
# 3                                 1.0                                     1.0
# 4                                 NaN                                     NaN
#
#    ip_transform_op_days_download_cumsum  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    ip_transform_op_days_download_200_cumsum  user_name_op_days_github_cumsum  \
# 0                                       NaN                              1.0
# 1                                       NaN                              1.0
# 2                                       NaN                              NaN
# 3                                       NaN                              1.0
# 4                                       NaN                              NaN
#
#    user_name_op_days_github_200_cumsum  user_name_op_days_download_cumsum  \
# 0                                  1.0                                NaN
# 1                                  1.0                                NaN
# 2                                  NaN                                NaN
# 3                                  1.0                                NaN
# 4                                  NaN                                NaN
#
#    user_name_op_days_download_200_cumsum  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    device_num_transform_op_days_github_cumsum  \
# 0                                         1.0
# 1                                         1.0
# 2                                         NaN
# 3                                         1.0
# 4                                         NaN
#
#    device_num_transform_op_days_github_200_cumsum  \
# 0                                             1.0
# 1                                             1.0
# 2                                             NaN
# 3                                             1.0
# 4                                             NaN
#
#    device_num_transform_op_days_download_cumsum  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    device_num_transform_op_days_download_200_cumsum
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN

# %%
train_woe, val_woe, bins_adj = sp.binning_data_detail(train=df_train,
                        test=df_test, y=y_label, excel_path=path_output_report, var_skip=['id'],)
# Out:
# There are blank strings in 1 columns, which are replaced with NaN.
#  (ColumnNames: url_page)
# There are 8 variables have only one binning intervals，please check the binning result.
#  (ColumnNames: ip_transform_op_times_groups_github_cumsum, user_name_op_times_groups_github_cumsum, user_name_op_days_http_status_code_error_code_cumsum, user_name_op_times_groups_github_200_cumsum, device_num_transform_op_times_groups_github_cumsum, ip_transform_op_times_groups_github_200_cumsum, device_num_transform_op_times_groups_github_200_cumsum, user_name_op_times_groups_http_status_code_error_code_cumsum)
# sheet07.初始分箱结果在/Users/liliangshan/workspace/python/01_datasets/ccf_system_access_risk_identification/results/01_原始数据探察_20221014.xlsx中已经存在，我们将对原文件进行覆盖
# 特征ip_transform_op_times_groups_github_cumsum，除特殊值分箱外，分箱箱数少于2箱，无法调整, 建议删除
# 特征user_name_op_times_groups_github_cumsum，除特殊值分箱外，分箱箱数少于2箱，无法调整, 建议删除
# 特征user_name_op_days_http_status_code_error_code_cumsum，除特殊值分箱外，分箱箱数少于2箱，无法调整, 建议删除
# 特征user_name_op_times_groups_github_200_cumsum，除特殊值分箱外，分箱箱数少于2箱，无法调整, 建议删除
# 特征device_num_transform_op_times_groups_github_cumsum，除特殊值分箱外，分箱箱数少于2箱，无法调整, 建议删除
# 特征ip_transform_op_times_groups_github_200_cumsum，除特殊值分箱外，分箱箱数少于2箱，无法调整, 建议删除
# 特征device_num_transform_op_times_groups_github_200_cumsum，除特殊值分箱外，分箱箱数少于2箱，无法调整, 建议删除
# 特征user_name_op_times_groups_http_status_code_error_code_cumsum，除特殊值分箱外，分箱箱数少于2箱，无法调整, 建议删除
# sheet08.分箱调整明细在/Users/liliangshan/workspace/python/01_datasets/ccf_system_access_risk_identification/results/01_原始数据探察_20221014.xlsx中已经存在，我们将对原文件进行覆盖
# [INFO] converting into woe values ...
# There are blank strings in 1 columns, which are replaced with NaN.
#  (ColumnNames: url_page)
# [INFO] converting into woe values ...
# There are blank strings in 1 columns, which are replaced with NaN.
#  (ColumnNames: url_page)
# sheet09.调整后分箱结果在/Users/liliangshan/workspace/python/01_datasets/ccf_system_access_risk_identification/results/01_原始数据探察_20221014.xlsx中已经存在，我们将对原文件进行覆盖

# %%
res_data, res_val, bins_selection = sp.select_feat_detail(train_woe, val_woe,df_test, y_label, bins_adj,exclude=['id'],
                                                iv_max_threshold=1.5,
                                                remove_negitive_coef=False,
                                                corr_threshold=0.7,
                                                #chi_threshold=0.00001,
                                                excel_path=path_output_report)
# Out:
# 变量dayofweek_sin 的分箱结果未通过卡方检验
# 变量dayofweek 的分箱结果未通过卡方检验
# 变量device_num_transform_op_month_log_system_transform_cumunique 的分箱结果未通过卡方检验
# 变量op_city 的分箱结果未通过卡方检验
# 变量url_sit 的分箱结果未通过卡方检验
# 变量device_num_transform_op_times_groups_download_cumsum_woe被加入
# 变量http_status_code_op_days_cumsum_woe被加入
# 变量hour_cos_woe被加入
# 变量op_diff_second1_woe被加入
# 变量ip_transform_op_days_github_200_cumsum_woe被加入
# 变量hour_woe被加入
# 变量device_num_transform_op_days_log_system_transform_cumunique_woe被加入
# 变量url_woe被加入
# 变量http_status_code_op_times_groups_cumsum_woe被加入
# 变量log_system_transform_woe被加入
# 变量device_num_transform_op_month_http_status_code_error_code_cumunique_woe被加入
# 变量device_num_transform_op_times_groups_download_200_cumsum_woe被加入
# 变量device_num_transform_op_days_cumsum_woe被加入
# 变量device_num_transform_op_month_url_sit_cumunique_woe被删除
# 逐步回归结果
#                 指标1                 取值1                    指标2         取值2
# 0  Dep. Variable:    y                     No. Observations:    47660.0000
# 1  Model:            LogisticRegression    Df Residuals:        47646.0000
# 2  Method:           MLE                   Df Model:               13.0000
# 3  Date:             Thu; 20 Oct 2022      Pseudo R-squ.:           0.4038
# 4  Time:             09:07:29              Log-Likelihood:     -12562.0000
# 5  converged:        True                  LL-Null:            -21071.0000
# 6  Covariance Type:  nonrobust             LLR p-value:             0.0000
#                                      feat                                   \
# 0   intercept                                     ...
# 1   log_system_transform_woe                      ...
# 2   device_num_transform_op_days_log_system_transf...
# 3   http_status_code_op_days_cumsum_woe           ...
# 4   url_woe                                       ...
# 5   http_status_code_op_times_groups_cumsum_woe   ...
# 6   device_num_transform_op_month_http_status_code...
# 7   hour_cos_woe                                  ...
# 8   hour_woe                                      ...
# 9   device_num_transform_op_days_cumsum_woe       ...
# 10  device_num_transform_op_times_groups_download_...
# 11  op_diff_second1_woe                           ...
# 12  device_num_transform_op_times_groups_download_...
# 13  ip_transform_op_days_github_200_cumsum_woe    ...
#
#       coef   std err     z     P>|z|   [0.025  0.975]
# 0   -1.7064    0.018  -94.076   0.000  -1.742  -1.671
# 1   -0.4709    0.073   -6.462   0.000  -0.614  -0.328
# 2    0.7546    0.091    8.274   0.000   0.576   0.933
# 3    1.4299    0.029   49.266   0.000   1.373   1.487
# 4    0.7303    0.057   12.708   0.000   0.618   0.843
# 5    0.1779    0.061    2.893   0.004   0.057   0.298
# 6    0.2104    0.053    3.986   0.000   0.107   0.314
# 7    1.2317    0.023   53.997   0.000   1.187   1.276
# 8   -0.9363    0.060  -15.575   0.000  -1.054  -0.818
# 9   -0.0303    0.053   -0.567   0.571  -0.135   0.074
# 10   0.0740    0.060    1.226   0.220  -0.044   0.192
# 11   1.2686    0.034   36.878   0.000   1.201   1.336
# 12   1.0271    0.026   39.581   0.000   0.976   1.078
# 13   0.8503    0.045   18.834   0.000   0.762   0.939
# sheet10.特征筛选在/Users/liliangshan/workspace/python/01_datasets/ccf_system_access_risk_identification/results/01_原始数据探察_20221014.xlsx中已经存在，我们将对原文件进行覆盖
# sheet11.特征表现在/Users/liliangshan/workspace/python/01_datasets/ccf_system_access_risk_identification/results/01_原始数据探察_20221014.xlsx中已经存在，我们将对原文件进行覆盖

# %% [markdown]
# ### null importance特征筛选

# %%
feats, categorical_feats = get_null_importance(df_train.drop(columns=[y_label,'id']),
                                               df_train[y_label], 
                                               thresholds=15)

# %%
# iv_list, iv_drop_var, iv_data = sp.feature_selection_iv(train_woe, bins_adj, 
#                                     y_label, max_threshold=10.0, exclude=['id'])
# print(iv_drop_var)

# %%
# corr_matrix, corr_drop_var, corr_data = sp.feature_selection_corr(df_train[], y_label, exclude=['id'])
# print(corr_drop_var)

# %% [markdown]
# ### 合并特征

# %%
object_feats = ['ip_transform', 'user_name', 'device_num_transform']

df_train = pd.concat([df_train_info[object_feats], df_train[feats], res_data], axis=1)
df_test = pd.concat([df_test[feats], res_val], axis=1)

# %% [markdown]
# ## modeling

# %%
feats = df_train.columns.drop(['id', y_label]+object_feats)
feats = feats.drop(categorical_feats)
#feats

# %%
categorical_feats
# Out:
# ['department',
#  'os_version',
#  'log_system_transform',
#  'url',
#  'url_sit',
#  'url_page']

# %%
feats = feats_importance.sort_values('importance', ascending=False)[:20]['name'].values

# %%
import time
from sklearn.metrics import roc_auc_score as auc
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold, KFold

# %%
params = {
    'learning_rate': 0.05,
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'num_leaves': 31,
    'verbose': -1,
    'seed': 2222,
    'n_jobs': -1,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.9,
    'bagging_freq': 4,
    # 'min_child_weight': 10,
}

# %%
fold_num = 5
seeds = [2022]
oof = np.zeros(len(df_train))
importance = 0
pred_y = pd.DataFrame()
score = []
for seed in seeds:
    kf = StratifiedKFold(n_splits=fold_num, shuffle=True, random_state=seed)
    # kf = KFold(n_splits=fold_num, shuffle=True, random_state=seed)
    for fold, (train_idx, val_idx) in enumerate(kf.split(df_train[feats], df_train[y_label])):
        print('-----------', fold)
        train = lgb.Dataset(df_train.loc[train_idx, feats],
                            df_train.loc[train_idx, y_label],
                           # categorical_feature=categorical_feats
                           )
        val = lgb.Dataset(df_train.loc[val_idx, feats],
                          df_train.loc[val_idx, y_label],
                          #categorical_feature=categorical_feats
                         )
        model = lgb.train(params, train, valid_sets=[val], 
                          num_boost_round=20000, early_stopping_rounds=100)

        oof[val_idx] += model.predict(df_train.loc[val_idx, feats]) / len(seeds)
        pred_y['fold_%d_seed_%d' % (fold, seed)] = model.predict(df_test[feats])
        importance += model.feature_importance(importance_type='gain') / fold_num
        score.append(auc(df_train.loc[val_idx, y_label], model.predict(df_train.loc[val_idx, feats])))
feats_importance = pd.DataFrame()
feats_importance['name'] = feats
feats_importance['importance'] = importance
display(feats_importance.sort_values('importance', ascending=False)[:30])

df_train['oof'] = oof
display(np.mean(score), np.std(score))

score = np.mean(score)
df_test[y_label] = pred_y.mean(axis=1).values
df_test = df_test.sort_values('id').reset_index(drop=True)

sub = pd.read_csv(path_sample_submission)
sub[y_label] = df_test[y_label].values
sub.to_csv(os.path.join(path_results_jupyter,time.strftime('lgb_%Y%m%d%H%M_')+'%.5f.csv'%score), index=False)
# Out:
# ----------- 0
# [1]	valid_0's auc: 0.926401
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's auc: 0.925103
# [3]	valid_0's auc: 0.924314
# [4]	valid_0's auc: 0.931948
# [5]	valid_0's auc: 0.932609
# [6]	valid_0's auc: 0.931488
# [7]	valid_0's auc: 0.932742
# [8]	valid_0's auc: 0.933144
# [9]	valid_0's auc: 0.934547
# [10]	valid_0's auc: 0.93723
# [11]	valid_0's auc: 0.937524
# [12]	valid_0's auc: 0.938156
# [13]	valid_0's auc: 0.938706
# [14]	valid_0's auc: 0.938904
# [15]	valid_0's auc: 0.939247
# [16]	valid_0's auc: 0.938988
# [17]	valid_0's auc: 0.939026
# [18]	valid_0's auc: 0.939338
# [19]	valid_0's auc: 0.939486
# [20]	valid_0's auc: 0.939488
# [21]	valid_0's auc: 0.939233
# [22]	valid_0's auc: 0.939444
# [23]	valid_0's auc: 0.939377
# [24]	valid_0's auc: 0.93953
# [25]	valid_0's auc: 0.939705
# [26]	valid_0's auc: 0.93966
# [27]	valid_0's auc: 0.939755
# [28]	valid_0's auc: 0.939778
# [29]	valid_0's auc: 0.939795
# [30]	valid_0's auc: 0.939316
# [31]	valid_0's auc: 0.939032
# [32]	valid_0's auc: 0.939036
# [33]	valid_0's auc: 0.93973
# [34]	valid_0's auc: 0.939873
# [35]	valid_0's auc: 0.93997
# [36]	valid_0's auc: 0.940159
# [37]	valid_0's auc: 0.940519
# [38]	valid_0's auc: 0.940684
# [39]	valid_0's auc: 0.940861
# [40]	valid_0's auc: 0.940887
# [41]	valid_0's auc: 0.940845
# [42]	valid_0's auc: 0.940883
# [43]	valid_0's auc: 0.940671
# [44]	valid_0's auc: 0.940728
# [45]	valid_0's auc: 0.940679
# [46]	valid_0's auc: 0.940789
# [47]	valid_0's auc: 0.940755
# [48]	valid_0's auc: 0.940841
# 5                 http_status_code_op_days_cumsum_woe  17803.247076
# 4                                                hour  17206.570181
# 2   device_num_transform_op_month_log_system_trans...  14259.893868
# 7   ip_transform_op_month_http_status_code_error_c...   8421.500192
# 8   device_num_transform_op_month_ip_transform_cum...   6962.760233
# 9                                           dayofweek   6415.377804
# 10                                            day_cos   4852.065298
# 11  device_num_transform_op_month_http_status_code...   4509.583942
# 6           user_name_op_times_groups_download_cumsum   4264.005034
# 12                    user_name_op_days_github_cumsum   3610.272916
# 13                 ip_transform_op_days_github_cumsum   3595.285675
# 19                                       hour_cos_woe   2237.271475
# 15                                                day   1993.341943
# 17    device_num_transform_op_month_op_city_cumunique   1643.963055
# 16                                op_diff_second1_woe   1550.400361
# 18                device_num_transform_op_days_cumsum   1006.749829
# 14  device_num_transform_op_times_groups_download_...      4.530534
# 0.9396741777758418
# 0.0016486948897566967

# %%
feats_importance.sort_values('importance', ascending=False)[:50]
# Out:
#                                                  name    importance
# 1        ip_transform_op_times_groups_download_cumsum  42165.178598
# 0                                            hour_cos  38059.912356
# 3                                     op_diff_second1  21543.045400
# 5                 http_status_code_op_days_cumsum_woe  17803.247076
# 4                                                hour  17206.570181
# 2   device_num_transform_op_month_log_system_trans...  14259.893868
# 7   ip_transform_op_month_http_status_code_error_c...   8421.500192
# 8   device_num_transform_op_month_ip_transform_cum...   6962.760233
# 9                                           dayofweek   6415.377804
# 10                                            day_cos   4852.065298
# 11  device_num_transform_op_month_http_status_code...   4509.583942
# 6           user_name_op_times_groups_download_cumsum   4264.005034
# 12                    user_name_op_days_github_cumsum   3610.272916
# 13                 ip_transform_op_days_github_cumsum   3595.285675
# 19                                       hour_cos_woe   2237.271475
# 15                                                day   1993.341943
# 17    device_num_transform_op_month_op_city_cumunique   1643.963055
# 16                                op_diff_second1_woe   1550.400361
# 18                device_num_transform_op_days_cumsum   1006.749829
# 14  device_num_transform_op_times_groups_download_...      4.530534

# %%
feats_importance.sort_values('importance', ascending=False)[:50].name.values
# Out:
# array(['ip_transform_op_times_groups_download_cumsum', 'hour_cos',
#        'op_diff_second1', 'http_status_code_op_days_cumsum_woe', 'hour',
#        'device_num_transform_op_month_log_system_transform_cumunique',
#        'ip_transform_op_month_http_status_code_error_code_cumsum',
#        'device_num_transform_op_month_ip_transform_cumunique',
#        'dayofweek', 'day_cos',
#        'device_num_transform_op_month_http_status_code_cumunique',
#        'user_name_op_times_groups_download_cumsum',
#        'user_name_op_days_github_cumsum',
#        'ip_transform_op_days_github_cumsum', 'hour_cos_woe', 'day',
#        'device_num_transform_op_month_op_city_cumunique',
#        'op_diff_second1_woe', 'device_num_transform_op_days_cumsum',
#        'device_num_transform_op_times_groups_download_cumsum'],
#       dtype=object)

# %%
df_train_info['oof']=df_train['oof']

# %%
# object_feats = ['ip_transform', 'user_name', 'device_num_transform']

# pd.concat([df_train_info, df_train[['oof','is_risk']]], axis=1).to_csv('caluate.csv', index=False)

# %%
df_train_info[abs(df_train_info['is_risk']-df_train_info['oof'])>0.7]['device_num_transform'].value_counts()

# %%
df_train_info[df_train_info['device_num_transform']=='Rfv57YyO3vny']
