# %% [markdown]
# ## 导包

# %%
# 公榜分数0.92860690761
import pandas as pd
import numpy as np
import lightgbm as lgb
import time
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_auc_score as auc
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_absolute_percentage_error as mape
from sklearn.model_selection import StratifiedKFold, KFold
from matplotlib.pyplot import plot, show

# %%
import os
import pandas as pd 
import numpy as np
import scorpyo as sp

import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

import time

from sklearn.model_selection import KFold
from scipy.stats import spearmanr
from lightgbm import LGBMClassifier

# %%
path_project = r'/Users/liliangshan/workspace/python/01_datasets/ccf_system_access_risk_identification'

# path dir
path_row_data = os.path.join(path_project, 'row_data')
path_new_data = os.path.join(path_project, 'new_data')
path_results  = os.path.join(path_project, 'results')

# path row_data
path_train = os.path.join(path_row_data, 'train.csv')
path_test  = os.path.join(path_row_data, 'evaluation_public.csv')
path_sample_submission = os.path.join(path_row_data, 'submit_example.csv')


## results
path_output_report = os.path.join(path_results, '01_原始数据探察.xlsx')

y_label = "is_risk"

# %% [markdown]
# ## 数据读取

# %%
df_row_train = sp.read_data(path_train)
df_row_val  = sp.read_data(path_test)

# %%
df_row_train.head()
# Out:
#    id        user_name department ip_transform device_num_transform  \
# 0   0  guojianping9672         rd    GVhZtW4i1         rqRxAjAL1RYC
# 1   1      yangtao1740      sales    l3MuTMPoQ         iKPTa3su50y7
# 2   2     wangying9098         rd    4uHWcskWv         1baNbqxMWcCu
# 3   3   liguixiang3860         rd    mQh3NwtY7         C04Llg4lKl4C
# 4   4       guanyu9205      sales    C2QtgDKAZ         kSscjiRSz1aD
#
#   browser_version  browser os_type os_version          op_datetime ip_type  \
# 0      firefox_78  firefox     win      win10  2022-01-18 19:10:41      内网
# 1       chrome_93   chrome     win      win11  2022-04-01 17:04:00      内网
# 2           ie_11       ie     win      win10  2022-03-01 15:53:49      内网
# 3         edge_93     edge     win      win10  2022-02-07 19:46:25      内网
# 4         edge_93     edge     win      win10  2022-04-12 10:05:19      内网
#
#    http_status_code op_city log_system_transform                   url  \
# 0               200      成都         2umVQwhiiwNJ          xxx.com/mail
# 1               200      深圳         RwHe8Q1R7AlB     business.xxx.com/
# 2               200      成都         dwS3cdn15GK4  wpsdoc.xxx.com/kdocs
# 3               200      北京         nHrKgKdJ1Mzt        xxx.com/github
# 4               200      成都         RwHe8Q1R7AlB     business.xxx.com/
#
#   op_month  is_risk
# 0  2022-01        0
# 1  2022-04        0
# 2  2022-03        0
# 3  2022-02        0
# 4  2022-04        0

# %%
_ = sp.excel_label(df_row_train, y=y_label, excel_path=path_output_report, show=True)
# Out:
# ------------------------------------------------------------------------------------------
# 标签分布展示如下:
#
# 数据集样本有: 47660个,特征列有:16列, 标签列为: is_risk
#    label取值  label数量 label占比
# 0        0    39964  83.85%
# 1        1     7696  16.15%
#    id        user_name department ip_transform device_num_transform  \
# 0   0  guojianping9672         rd    GVhZtW4i1         rqRxAjAL1RYC
# 1   1      yangtao1740      sales    l3MuTMPoQ         iKPTa3su50y7
# 2   2     wangying9098         rd    4uHWcskWv         1baNbqxMWcCu
#
#   browser_version  browser os_type os_version          op_datetime ip_type  \
# 0      firefox_78  firefox     win      win10  2022-01-18 19:10:41      内网
# 1       chrome_93   chrome     win      win11  2022-04-01 17:04:00      内网
# 2           ie_11       ie     win      win10  2022-03-01 15:53:49      内网
#
#    http_status_code op_city log_system_transform                   url  \
# 0               200      成都         2umVQwhiiwNJ          xxx.com/mail
# 1               200      深圳         RwHe8Q1R7AlB     business.xxx.com/
# 2               200      成都         dwS3cdn15GK4  wpsdoc.xxx.com/kdocs
#
#   op_month  is_risk
# 0  2022-01        0
# 1  2022-04        0
# 2  2022-03        0
# ------------------------------------------------------------------------------------------
# sheet01.标签分布分析在/Users/liliangshan/workspace/python/01_datasets/ccf_system_access_risk_identification/results/01_原始数据探察.xlsx中已经存在，我们将对原文件进行覆盖

# %%
sp.excel_detect(df_row_train, sheet_name='02.训练集-数据描述性统计',excel_path=path_output_report)
# Out:
# sheet02.训练集-数据描述性统计在/Users/liliangshan/workspace/python/01_datasets/ccf_system_access_risk_identification/results/01_原始数据探察.xlsx中已经存在，我们将对原文件进行覆盖
#            feat_name_row    type   size  missing  unique  zero_ratio  \
# 0                     id   int64  47660     0.00   47660       0.000
# 1              user_name  object  47660     0.08     187       0.000
# 2             department  object  47660     0.08       5       0.000
# 3           ip_transform  object  47660     0.00    2105       0.000
# 4   device_num_transform  object  47660     0.00     844       0.000
# 5        browser_version  object  47660     0.00       8       0.000
# 6                browser  object  47660     0.00       5       0.000
# 7                os_type  object  47660     0.00       2       0.000
# 8             os_version  object  47660     0.00       4       0.000
# 9            op_datetime  object  47660     0.00   47343       0.000
# 10               ip_type  object  47660     0.08       1       0.000
# 11      http_status_code   int64  47660     0.00       5       0.000
# 12               op_city  object  47660     0.00      14       0.000
# 13  log_system_transform  object  47660     0.08       9       0.000
# 14                   url  object  47660     0.00      13       0.000
# 15              op_month  object  47660     0.00       4       0.000
# 16               is_risk   int64  47660     0.00       2       0.839
#
#     negative_ratio       top1_all_value  top1_all_ratio  \
# 0              0.0                    0           0.000
# 1              NaN        xuxiuying8050           0.007
# 2              NaN                   rd           0.654
# 3              NaN            w2CfuqTz3           0.007
# 4              NaN         O54DfqjlCrhL           0.007
# 5              NaN              edge_93           0.372
# 6              NaN               chrome           0.431
# 7              NaN                  win           0.905
# 8              NaN                win10           0.758
# 9              NaN  2022-04-02 17:02:24           0.000
# 10             NaN                   内网           0.920
# 11             0.0                  200           0.948
# 12             NaN                   深圳           0.334
# 13             NaN         nHrKgKdJ1Mzt           0.322
# 14             NaN       xxx.com/github           0.322
# 15             NaN              2022-03           0.293
# 16             0.0                    0           0.839
#
#                  mean_or_top1                     std_or_top2  \
# 0                     23829.5                       13758.401
# 1         xuxiuying8050:0.65%             hongchang3029:0.63%
# 2                   rd:65.36%                    sales:17.26%
# 3             w2CfuqTz3:0.68%                 u9diCFdYZ:0.66%
# 4          O54DfqjlCrhL:0.70%              kUa61ygA6gI3:0.68%
# 5              edge_93:37.16%                chrome_90:33.38%
# 6               chrome:43.15%                     edge:37.16%
# 7                  win:90.52%                     macos:9.48%
# 8                win10:75.84%                     win7:10.81%
# 9   2022-04-02 17:02:24:0.01%       2022-02-16 11:36:12:0.01%
# 10                  内网:92.01%                            None
# 11                    211.336                          48.817
# 12                  深圳:33.38%                       成都:24.54%
# 13        nHrKgKdJ1Mzt:32.17%             dwS3cdn15GK4:22.89%
# 14      xxx.com/github:32.17%  wpsdoc.xxx.com/download:15.43%
# 15             2022-03:29.28%                  2022-04:26.86%
# 16                      0.161                           0.368
#
#                   min_or_top3                 1%_or_top4  \
# 0                         0.0                     476.59
# 1            tanliu3173:0.62%          liuhong6350:0.62%
# 2                 other:4.07%           accounting:3.56%
# 3             pPgzIf3S4:0.65%            7YnPN3fqd:0.65%
# 4          Rfv57YyO3vny:0.67%         5DmlITfRNR36:0.66%
# 5             safari_13:9.48%            chrome_77:5.32%
# 6                safari:9.48%                   ie:5.39%
# 7                        None                       None
# 8      macos_big_sur_11:9.48%                win11:3.87%
# 9   2022-04-28 09:33:53:0.01%  2022-03-04 17:13:36:0.01%
# 10                       None                       None
# 11                      200.0                      200.0
# 12                  杭州:18.47%                  北京:17.67%
# 13         2umVQwhiiwNJ:9.74%         sW0whYIx8LFM:8.51%
# 14         xxx.com/mail:9.74%    work.xxx.com/task:8.51%
# 15             2022-01:22.92%             2022-02:20.94%
# 16                        0.0                        0.0
#
#                   10%_or_top5             50%_or_bottom5  \
# 0                      4765.9                    23829.5
# 1             lufan2545:0.62%       zhouxiumei4433:0.38%
# 2                    hr:1.75%                  rd:65.36%
# 3             DhTMwbtS5:0.64%            948U9MQcB:0.00%
# 4          TzmgdvYq3Kx0:0.66%         aUECyyFo55Zy:0.00%
# 5            firefox_78:4.82%            chrome_77:5.32%
# 6               firefox:4.82%              chrome:43.15%
# 7                        None                       None
# 8                        None                       None
# 9   2022-03-23 14:47:36:0.00%  2022-04-29 09:58:59:0.00%
# 10                       None                       None
# 11                      200.0                      200.0
# 12                   广州:0.99%                   郑州:0.42%
# 13         RwHe8Q1R7AlB:7.85%         RwHe8Q1R7AlB:7.85%
# 14    business.xxx.com/:7.85%   xxx.com/checkingin:1.99%
# 15                       None                       None
# 16                        0.0                        0.0
#
#                75%_or_bottom4             90%_or_bottom3  \
# 0                    35744.25                    42893.1
# 1          chenjian4844:0.37%         wanggang1192:0.36%
# 2                sales:17.26%                other:4.07%
# 3             h75YAkAAL:0.00%            m7512MutA:0.00%
# 4          cREgOG9x3d9X:0.00%         NGfeE42d1yHY:0.00%
# 5            firefox_78:4.82%            chrome_93:4.44%
# 6                 edge:37.16%               safari:9.48%
# 7                        None                       None
# 8                win10:75.84%                win7:10.81%
# 9   2022-04-20 19:02:48:0.00%  2022-01-19 15:11:24:0.00%
# 10                       None                       None
# 11                      200.0                      200.0
# 12                   国外:0.36%                   未知:0.32%
# 13         fwM6KZKjrzjm:6.58%         9RAS6RNfETj5:1.99%
# 14   xxx.com/accounting:1.81%          hr.xxx.com/:0.46%
# 15             2022-03:29.28%             2022-04:26.86%
# 16                        0.0                        1.0
#
#                 99%_or_bottom2               max_or_bottom1
# 0                     47182.41                      47659.0
# 1         ranxiuzhen6780:0.33%              xujie9775:0.30%
# 2             accounting:3.56%                     hr:1.75%
# 3              ADL8GwW32:0.00%              g3dWezpzT:0.00%
# 4           T4hueKNccs7X:0.00%           A0TLDctT8OUR:0.00%
# 5                  ie_11:3.37%                   ie_9:2.02%
# 6                     ie:5.39%                firefox:4.82%
# 7                   win:90.52%                  macos:9.48%
# 8       macos_big_sur_11:9.48%                  win11:3.87%
# 9    2022-01-19 10:53:46:0.00%    2022-04-08 19:30:10:0.00%
# 10                        None                    内网:92.01%
# 11                       404.0                        502.0
# 12                    天津:0.30%                     苏州:0.30%
# 13          2UNHLdxlhIzv:1.81%           a5G25puBl9xj:0.46%
# 14  xxx.com/getLoginType:0.44%  xxx.com/getVerifyCode:0.44%
# 15              2022-01:22.92%               2022-02:20.94%
# 16                         1.0                          1.0

# %%
sp.excel_detect(df_row_val, sheet_name='03.测试集-数据描述性统计',excel_path=path_output_report)
# Out:
# sheet03.测试集-数据描述性统计在/Users/liliangshan/workspace/python/01_datasets/ccf_system_access_risk_identification/results/01_原始数据探察.xlsx中已经存在，我们将对原文件进行覆盖
#            feat_name_row    type   size  missing  unique  zero_ratio  \
# 0                     id   int64  25710    0.000   25710         0.0
# 1              user_name  object  25710    0.079     187         0.0
# 2             department  object  25710    0.079       5         0.0
# 3           ip_transform  object  25710    0.000    1192         0.0
# 4   device_num_transform  object  25710    0.000     505         0.0
# 5        browser_version  object  25710    0.000       8         0.0
# 6                browser  object  25710    0.000       5         0.0
# 7                os_type  object  25710    0.000       2         0.0
# 8             os_version  object  25710    0.000       4         0.0
# 9            op_datetime  object  25710    0.000   25542         0.0
# 10               ip_type  object  25710    0.079       1         0.0
# 11      http_status_code   int64  25710    0.000       5         0.0
# 12               op_city  object  25710    0.000      14         0.0
# 13  log_system_transform  object  25710    0.079       9         0.0
# 14                   url  object  25710    0.000      13         0.0
# 15              op_month  object  25710    0.000       2         0.0
#
#     negative_ratio       top1_all_value  top1_all_ratio  \
# 0              0.0                    0           0.000
# 1              NaN         yuyuzhen3194           0.007
# 2              NaN                   rd           0.656
# 3              NaN            H0TKapkPL           0.008
# 4              NaN         K8Ith9mjHsKo           0.008
# 5              NaN              edge_93           0.367
# 6              NaN               chrome           0.433
# 7              NaN                  win           0.906
# 8              NaN                win10           0.765
# 9              NaN  2022-06-23 10:51:17           0.000
# 10             NaN                   内网           0.921
# 11             0.0                  200           0.945
# 12             NaN                   深圳           0.334
# 13             NaN         nHrKgKdJ1Mzt           0.312
# 14             NaN       xxx.com/github           0.312
# 15             NaN              2022-06           0.505
#
#                  mean_or_top1                     std_or_top2  \
# 0                     12854.5                        7421.982
# 1          yuyuzhen3194:0.72%              fengying9449:0.68%
# 2                   rd:65.60%                    sales:17.08%
# 3             H0TKapkPL:0.76%                 YBCE8ld50:0.70%
# 4          K8Ith9mjHsKo:0.79%              3wDqyLqvVCn1:0.72%
# 5              edge_93:36.69%                chrome_90:33.55%
# 6               chrome:43.31%                     edge:36.69%
# 7                  win:90.63%                     macos:9.37%
# 8                win10:76.51%                     win7:10.50%
# 9   2022-06-23 10:51:17:0.01%       2022-06-01 11:38:12:0.01%
# 10                  内网:92.08%                            None
# 11                    211.805                          49.329
# 12                  深圳:33.42%                       成都:25.36%
# 13        nHrKgKdJ1Mzt:31.23%             dwS3cdn15GK4:24.72%
# 14      xxx.com/github:31.23%  wpsdoc.xxx.com/download:16.87%
# 15             2022-06:50.50%                  2022-05:49.50%
#
#                   min_or_top3                 1%_or_top4  \
# 0                         0.0                     257.09
# 1           pengfan5076:0.67%           linbin8358:0.67%
# 2                 other:4.33%           accounting:3.08%
# 3             2qWPkWg5V:0.70%            8J3dZCu0A:0.69%
# 4          4BWxjoSreaOm:0.71%         uRYWimJ18UEk:0.70%
# 5             safari_13:9.37%            chrome_77:5.57%
# 6                safari:9.37%                   ie:5.52%
# 7                        None                       None
# 8      macos_big_sur_11:9.37%                win11:3.62%
# 9   2022-05-25 15:09:56:0.01%  2022-05-06 19:34:25:0.01%
# 10                       None                       None
# 11                      200.0                      200.0
# 12                  杭州:18.30%                  北京:16.88%
# 13         2umVQwhiiwNJ:9.68%         sW0whYIx8LFM:8.18%
# 14         xxx.com/mail:9.68%    work.xxx.com/task:8.18%
# 15                       None                       None
#
#                   10%_or_top5             50%_or_bottom5  \
# 0                      2570.9                    12854.5
# 1            lijing7913:0.66%            likun8302:0.33%
# 2                    hr:1.99%                  rd:65.60%
# 3             4hPUiX1CK:0.68%            88aHOvoHa:0.00%
# 4          sdN7y26qL30M:0.70%         E9qxuBiAo3Ju:0.00%
# 5            firefox_78:5.11%            chrome_77:5.57%
# 6               firefox:5.11%              chrome:43.31%
# 7                        None                       None
# 8                        None                       None
# 9   2022-06-07 09:10:38:0.01%  2022-05-24 18:01:53:0.00%
# 10                       None                       None
# 11                      200.0                      200.0
# 12                   东莞:1.00%                   郑州:0.39%
# 13         RwHe8Q1R7AlB:7.93%         RwHe8Q1R7AlB:7.93%
# 14    business.xxx.com/:7.93%   xxx.com/checkingin:2.04%
# 15                       None                       None
#
#                75%_or_bottom4             90%_or_bottom3  \
# 0                    19281.75                    23138.1
# 1         maohaiyan4824:0.33%          chengli6873:0.32%
# 2                sales:17.08%                other:4.33%
# 3             358EfARvQ:0.00%            4L9vshrCi:0.00%
# 4          AF9IY4wFm5vY:0.00%         jI1j9ekI0wfW:0.00%
# 5            firefox_78:5.11%            chrome_93:4.20%
# 6                 edge:36.69%               safari:9.37%
# 7                        None                       None
# 8                win10:76.51%                win7:10.50%
# 9   2022-05-25 10:29:21:0.00%  2022-05-07 16:09:19:0.00%
# 10                       None                       None
# 11                      200.0                      200.0
# 12                   苏州:0.33%                   国外:0.33%
# 13         fwM6KZKjrzjm:6.13%         9RAS6RNfETj5:2.04%
# 14   xxx.com/accounting:1.69%          hr.xxx.com/:0.49%
# 15                       None                       None
#
#                 99%_or_bottom2               max_or_bottom1
# 0                     25451.91                      25709.0
# 1            yanglin6562:0.32%           chenying2872:0.32%
# 2             accounting:3.08%                     hr:1.99%
# 3              9RzuSrhOL:0.00%              LWv4Mjkys:0.00%
# 4           IN0qCiPw2eHv:0.00%           MmIkTEts5OIC:0.00%
# 5                  ie_11:3.50%                   ie_9:2.02%
# 6                     ie:5.52%                firefox:5.11%
# 7                   win:90.63%                  macos:9.37%
# 8       macos_big_sur_11:9.37%                  win11:3.62%
# 9    2022-06-30 14:19:20:0.00%    2022-06-28 14:50:21:0.00%
# 10                        None                    内网:92.08%
# 11                       404.0                        502.0
# 12                    未知:0.29%                     天津:0.27%
# 13          2UNHLdxlhIzv:1.69%           a5G25puBl9xj:0.49%
# 14  xxx.com/getLoginType:0.45%  xxx.com/getVerifyCode:0.39%
# 15              2022-06:50.50%               2022-05:49.50%

# %% [markdown]
# ## 特征工程

# %% [markdown]
# 特征衍生

# %%
df = pd.concat([df_row_train, df_row_val])
# 认证日期时间
df['op_datetime'] = pd.to_datetime(df['op_datetime'])
# 几点钟
df['hour'] = df['op_datetime'].dt.hour
# 周几
df['dayofweek'] = df['op_datetime'].dt.dayofweek
# 一个月的第几天
df['day'] = df['op_datetime'].dt.day
# 一年的第几月
df['month'] = df['op_datetime'].dt.month


# 用户名-认证时间
df = df.sort_values(by=['user_name', 'op_datetime']).reset_index(drop=True)
# datetime转int时间戳
df['ts'] = df['op_datetime'].values.astype(np.int64) // 10 ** 9
# 按客户进行统计这次认证和上次认证的时间差
df['ts1'] = df.groupby('user_name')['ts'].shift(1)
# 按客户进行统计这次认证和上上次认证的时间差
df['ts2'] = df.groupby('user_name')['ts'].shift(2)
# 按客户进行统计这次认证和上上上次认证的时间差
df['ts3'] = df.groupby('user_name')['ts'].shift(3)
df['ts_diff1'] = df['ts1'] - df['ts']
df['ts_diff2'] = df['ts2'] - df['ts']
df['ts_diff3'] = df['ts3'] - df['ts']

df['hour_sin'] = np.sin(df['hour']/24*2*np.pi)
df['hour_cos'] = np.cos(df['hour']/24*2*np.pi)

# %%
cat_f = ['user_name', 'department', 'ip_transform', 'device_num_transform', 'browser_version', 'browser',
          'os_type', 'os_version', 'ip_type', 'op_city', 'log_system_transform', 'url',]
for f in cat_f:
    df[f+'_ts_diff_mean'] = df.groupby([f])['ts_diff1'].transform('mean')
    df[f+'_ts_diff_std'] = df.groupby([f])['ts_diff1'].transform('std')
    df[f+'_ts_diff2_mean'] = df.groupby([f])['ts_diff2'].transform('mean')
    df[f+'_ts_diff2_std'] = df.groupby([f])['ts_diff2'].transform('std')
    df[f+'_ts_diff3_mean'] = df.groupby([f])['ts_diff3'].transform('mean')
    df[f+'_ts_diff3_std'] = df.groupby([f])['ts_diff3'].transform('std')

df_train = df[df[y_label].notna()].reset_index(drop=True)
df_test = df[df[y_label].isna()].reset_index(drop=True)

# %% [markdown]
# 分箱

# %%
bins = sp.woebin(df_train[cat_f + [y_label]], y_label)

train_woe = sp.woebin_ply(df_train, bins)
val_woe  = sp.woebin_ply(df_test, bins)
# Out:
# >>> There are 3 variables have too many unique non-numberic values, which might cause the binning process slow. Please double check the following variables:
# user_name, ip_transform, device_num_transform
# >>> Continue the binning process?
# 1: yes
# 2: no
# 3: remove these variables
# Selection: 3
# There are 1 variables have only one binning intervals，please check the binning result.
#  (ColumnNames: ip_type)
# [INFO] converting into woe values ...
# [INFO] converting into woe values ...

# %%
bins.keys()
# Out:
# dict_keys(['browser_version', 'department', 'browser', 'log_system_transform', 'op_city', 'os_type', 'ip_type', 'os_version', 'url'])

# %%
train_woe, val_woe, bins_adj = sp.binning_data_detail(train=df_train, 
                        test=df_test, y=y_label, var_skip=['id'], excel_path=path_output_report)
# Out:
# There are 1 date/time type columns are removed from input dataset.
#  (ColumnNames: op_month)
# >>> There are 4 variables have too many unique non-numberic values, which might cause the binning process slow. Please double check the following variables:
# user_name, op_datetime, device_num_transform, ip_transform
# >>> Continue the binning process?
# 1: yes
# 2: no
# 3: remove these variables
# Selection: 3
# There are 9 variables have only one binning intervals，please check the binning result.
#  (ColumnNames: ip_type_ts_diff2_std, os_type_ts_diff_std, ip_type_ts_diff_std, ip_type, ip_type_ts_diff3_mean, ip_type_ts_diff_mean, ip_type_ts_diff2_mean, os_type_ts_diff2_mean, ip_type_ts_diff3_std)
# 特征ip_type_ts_diff2_std，除特殊值分箱外，分箱箱数少于2箱，无法调整, 建议删除
# 特征os_type_ts_diff_std，除特殊值分箱外，分箱箱数少于2箱，无法调整, 建议删除
# 特征ip_type_ts_diff_std，除特殊值分箱外，分箱箱数少于2箱，无法调整, 建议删除
# 特征ip_type，除特殊值分箱外，分箱箱数少于2箱，无法调整, 建议删除
# 特征ip_type_ts_diff3_mean，除特殊值分箱外，分箱箱数少于2箱，无法调整, 建议删除
# 特征ip_type_ts_diff_mean，除特殊值分箱外，分箱箱数少于2箱，无法调整, 建议删除
# 特征ip_type_ts_diff2_mean，除特殊值分箱外，分箱箱数少于2箱，无法调整, 建议删除
# 特征os_type_ts_diff2_mean，除特殊值分箱外，分箱箱数少于2箱，无法调整, 建议删除
# 特征ip_type_ts_diff3_std，除特殊值分箱外，分箱箱数少于2箱，无法调整, 建议删除
# 特征device_num_transform_ts_diff_mean, 单调分箱调整失败
# 特征user_name_ts_diff2_mean, 单调分箱调整失败
# 特征browser_version_ts_diff_mean, 单调分箱调整失败
# 特征user_name_ts_diff3_mean, 单调分箱调整失败
# 特征device_num_transform_ts_diff_std, 单调分箱调整失败
# 特征device_num_transform_ts_diff3_mean, 单调分箱调整失败
# 特征device_num_transform_ts_diff2_mean, 单调分箱调整失败
# [INFO] converting into woe values ...
# [INFO] converting into woe values ...

# %%
res_data, res_val, bins_selection = sp.select_feat_detail(
    train_woe, val_woe,df_test, y_label, bins_adj, exclude=['id'],excel_path=path_output_report)
# Out:
# 变量dayofweek 的分箱结果未通过卡方检验
# 变量ip_transform_ts_diff_mean 的分箱结果未通过卡方检验
# 变量op_city 的分箱结果未通过卡方检验
# 变量ip_transform_ts_diff3_mean_woe被加入
# 变量hour_cos_woe被加入
# 变量url_woe被加入
# 变量hour_woe被加入
# 变量ts_diff3_woe被加入
# 变量url_ts_diff3_std_woe被加入
# 变量log_system_transform_woe被加入
# 变量ts_diff1_woe被加入
# 变量op_city_ts_diff_mean_woe被删除
# 变量log_system_transform_woe的系数为负，被删除
# 变量url_ts_diff3_std_woe的系数为负，被删除
# 逐步回归结果
#                 指标1                 取值1                    指标2         取值2
# 0  Dep. Variable:    is_risk               No. Observations:    47660.0000
# 1  Model:            LogisticRegression    Df Residuals:        47653.0000
# 2  Method:           MLE                   Df Model:                6.0000
# 3  Date:             Tue; 11 Oct 2022      Pseudo R-squ.:           0.2495
# 4  Time:             14:54:16              Log-Likelihood:     -15815.0000
# 5  converged:        True                  LL-Null:            -21071.0000
# 6  Covariance Type:  nonrobust             LLR p-value:             0.0000
#                 feat                 coef   std err     z      P>|z|   [0.025  \
# 0  intercept                       -1.6874    0.015  -111.311   0.000  -1.717
# 1  hour_cos_woe                     1.2250    0.020    62.606   0.000   1.187
# 2  hour_woe                         1.1752    0.037    32.018   0.000   1.103
# 3  ip_transform_ts_diff3_mean_woe   1.1696    0.025    46.160   0.000   1.120
# 4  ts_diff1_woe                     0.0540    0.064     0.839   0.401  -0.072
# 5  ts_diff3_woe                     0.7117    0.044    16.182   0.000   0.626
# 6  url_woe                          0.8456    0.041    20.735   0.000   0.766
#
#    0.975]
# 0  -1.658
# 1   1.263
# 2   1.247
# 3   1.219
# 4   0.180
# 5   0.798
# 6   0.926

# %%
model = sp.get_lr_model(res_data, y_label)
# Out:
#                 指标1                 取值1                    指标2         取值2
# 0  Dep. Variable:    is_risk               No. Observations:    47660.0000
# 1  Model:            LogisticRegression    Df Residuals:        47652.0000
# 2  Method:           MLE                   Df Model:                7.0000
# 3  Date:             Tue; 11 Oct 2022      Pseudo R-squ.:           0.4978
# 4  Time:             14:55:02              Log-Likelihood:     -10583.0000
# 5  converged:        True                  LL-Null:            -21071.0000
# 6  Covariance Type:  nonrobust             LLR p-value:             0.0000
#                 feat                 coef   std err     z     P>|z|   [0.025  \
# 0  intercept                       -8.2855    0.106  -78.378   0.000  -8.493
# 1  hour_cos_woe                     0.5356    0.030   18.121   0.000   0.478
# 2  hour_woe                         0.3917    0.050    7.899   0.000   0.295
# 3  id                               0.0002    0.000   70.448   0.000   0.000
# 4  ip_transform_ts_diff3_mean_woe   0.8175    0.024   34.281   0.000   0.771
# 5  ts_diff1_woe                    -2.0668    0.098  -21.122   0.000  -2.259
# 6  ts_diff3_woe                     0.5758    0.050   11.401   0.000   0.477
# 7  url_woe                          0.0842    0.041    2.062   0.039   0.004
#
#    0.975]
# 0  -8.078
# 1   0.593
# 2   0.489
# 3   0.000
# 4   0.864
# 5  -1.875
# 6   0.675
# 7   0.164

# %%
card = sp.scorecard(bins_selection, model, res_data.columns.drop(y_label))

# %%
res_train = sp.scorecard_ply(df_train, card)
res_val   = sp.scorecard_ply(df_test, card)

# %%
res_train[y_label] = df_train[y_label]

# %%
import copy

# %%
res = sp.report_model({'train': res_train, 'test': copy.deepcopy(res_train)}, target=y_label, pred='score', plot_type=['ks', 'lift', 'roc'])
# Out:
# Since the average of pred is not in [0,1], it is treated as predicted score but not probability.
#                   Sample      KS     AUC    GINI      F1  ACCURACY PRECISION  \
# 阈值是918.0时的模型表现  0  train  0.3837  0.6871  0.3742  0.4370  85.1259%  56.2002%
#                 1   test  0.3837  0.6871  0.3742  0.4370  85.1259%  56.2002%
# 阈值是976.0时的模型表现  0  train  0.3837  0.6871  0.3742  0.4125  78.4599%  36.8583%
#                 1   test  0.3837  0.6871  0.3742  0.4125  78.4599%  36.8583%
# 阈值是1007.0时的模型表现 0  train  0.3837  0.6871  0.3742  0.2745  43.1431%  17.2860%
#                 1   test  0.3837  0.6871  0.3742  0.2745  43.1431%  17.2860%
# 阈值是1056.0时的模型表现 0  train  0.3837  0.6871  0.3742  0.3283  38.3445%  19.9173%
#                 1   test  0.3837  0.6871  0.3742  0.3283  38.3445%  19.9173%
# 阈值是1065.0时的模型表现 0  train  0.3837  0.6871  0.3742  0.3074  31.3764%  18.3626%
#                 1   test  0.3837  0.6871  0.3742  0.3074  31.3764%  18.3626%
# 阈值是1124.0时的模型表现 0  train  0.3837  0.6871  0.3742  0.2781  16.1477%  16.1477%
#                 1   test  0.3837  0.6871  0.3742  0.2781  16.1477%  16.1477%
#
#                       RECALL
# 阈值是918.0时的模型表现  0   35.7458%
#                 1   35.7458%
# 阈值是976.0时的模型表现  0   46.8295%
#                 1   46.8295%
# 阈值是1007.0时的模型表现 0   66.6060%
#                 1   66.6060%
# 阈值是1056.0时的模型表现 0   93.2952%
#                 1   93.2952%
# 阈值是1065.0时的模型表现 0   94.3087%
#                 1   94.3087%
# 阈值是1124.0时的模型表现 0  100.0000%
#                 1  100.0000%

# %%
cat_f = ['user_name', 'department', 'ip_transform', 'device_num_transform', 'browser_version', 'browser',
          'os_type', 'os_version', 'ip_type', 'op_city', 'log_system_transform', 'url',]

for f in cat_f:
    le = LabelEncoder()
    df[f] = le.fit_transform(df[f])
    df[f+'_ts_diff_mean'] = df.groupby([f])['ts_diff1'].transform('mean')
    df[f+'_ts_diff_std'] = df.groupby([f])['ts_diff1'].transform('std')

df_train = df[df[y_label].notna()].reset_index(drop=True)
df_test = df[df[y_label].isna()].reset_index(drop=True)

# %%
feats = [f for f in df_test if f not in [y_label, 'id',
                                         'op_datetime', 'op_month', 'ts', 'ts1', 'ts2']]
print(feats)
print(df_train[feats].shape, df_test[feats].shape)
# Out:
# ['user_name', 'department', 'ip_transform', 'device_num_transform', 'browser_version', 'browser', 'os_type', 'os_version', 'ip_type', 'http_status_code', 'op_city', 'log_system_transform', 'url', 'hour', 'dayofweek', 'ts_diff1', 'ts_diff2', 'hour_sin', 'hour_cos', 'user_name_ts_diff_mean', 'user_name_ts_diff_std', 'department_ts_diff_mean', 'department_ts_diff_std', 'ip_transform_ts_diff_mean', 'ip_transform_ts_diff_std', 'device_num_transform_ts_diff_mean', 'device_num_transform_ts_diff_std', 'browser_version_ts_diff_mean', 'browser_version_ts_diff_std', 'browser_ts_diff_mean', 'browser_ts_diff_std', 'os_type_ts_diff_mean', 'os_type_ts_diff_std', 'os_version_ts_diff_mean', 'os_version_ts_diff_std', 'ip_type_ts_diff_mean', 'ip_type_ts_diff_std', 'op_city_ts_diff_mean', 'op_city_ts_diff_std', 'log_system_transform_ts_diff_mean', 'log_system_transform_ts_diff_std', 'url_ts_diff_mean', 'url_ts_diff_std']
# (47660, 43) (25710, 43)

# %% [markdown]
# ## modeling

# %%
params = {
    'learning_rate': 0.05,
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'num_leaves': 64,
    'verbose': -1,
    'seed': 2222,
    'n_jobs': -1,

    'feature_fraction': 0.8,
    'bagging_fraction': 0.9,
    'bagging_freq': 4,
    # 'min_child_weight': 10,
}

# %%
fold_num = 5
seeds = [2222]
oof = np.zeros(len(df_train))
importance = 0
pred_y = pd.DataFrame()
score = []
for seed in seeds:
    kf = StratifiedKFold(n_splits=fold_num, shuffle=True, random_state=seed)
    # kf = KFold(n_splits=fold_num, shuffle=True, random_state=seed)
    for fold, (train_idx, val_idx) in enumerate(kf.split(df_train[feats], df_train[y_label])):
        print('-----------', fold)
        train = lgb.Dataset(df_train.loc[train_idx, feats],
                            df_train.loc[train_idx, y_label])
        val = lgb.Dataset(df_train.loc[val_idx, feats],
                          df_train.loc[val_idx, y_label])
        model = lgb.train(params, train, valid_sets=[val], 
                          num_boost_round=20000, early_stopping_rounds=100)

        oof[val_idx] += model.predict(df_train.loc[val_idx, feats]) / len(seeds)
        pred_y['fold_%d_seed_%d' % (fold, seed)] = model.predict(df_test[feats])
        importance += model.feature_importance(importance_type='gain') / fold_num
        score.append(auc(df_train.loc[val_idx, y_label], model.predict(df_train.loc[val_idx, feats])))
feats_importance = pd.DataFrame()
feats_importance['name'] = feats
feats_importance['importance'] = importance
display(feats_importance.sort_values('importance', ascending=False)[:30])

df_train['oof'] = oof
display(np.mean(score), np.std(score))

score = np.mean(score)
df_test[y_label] = pred_y.mean(axis=1).values
df_test = df_test.sort_values('id').reset_index(drop=True)

sub = pd.read_csv(path_sample_submission)
sub[y_label] = df_test[y_label].values
sub.to_csv(os.path.join(path_results,time.strftime('lgb_%Y%m%d%H%M_')+'%.5f.csv'%score), index=False)
# Out:
# ----------- 0
# [1]	valid_0's auc: 0.919107
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's auc: 0.920488
# [3]	valid_0's auc: 0.923447
# [4]	valid_0's auc: 0.924489
# [5]	valid_0's auc: 0.925131
# [6]	valid_0's auc: 0.926034
# [7]	valid_0's auc: 0.926454
# [8]	valid_0's auc: 0.926227
# [9]	valid_0's auc: 0.9265
# [10]	valid_0's auc: 0.926526
# [11]	valid_0's auc: 0.926049
# [12]	valid_0's auc: 0.926018
# [13]	valid_0's auc: 0.92589
# [14]	valid_0's auc: 0.925695
# [15]	valid_0's auc: 0.925828
# [16]	valid_0's auc: 0.925957
# [17]	valid_0's auc: 0.926159
# [18]	valid_0's auc: 0.926468
# [19]	valid_0's auc: 0.926557
# [20]	valid_0's auc: 0.926504
# [21]	valid_0's auc: 0.926223
# [22]	valid_0's auc: 0.926417
# [23]	valid_0's auc: 0.926485
# [24]	valid_0's auc: 0.926551
# [25]	valid_0's auc: 0.926235
# [26]	valid_0's auc: 0.926201
# [27]	valid_0's auc: 0.92637
# [28]	valid_0's auc: 0.926421
# [29]	valid_0's auc: 0.926283
# [30]	valid_0's auc: 0.926722
# [31]	valid_0's auc: 0.92664
# [32]	valid_0's auc: 0.926685
# [118]	valid_0's auc: 0.924581
# [119]	valid_0's auc: 0.924536
# [120]	valid_0's auc: 0.924432
# [121]	valid_0's auc: 0.924285
# [122]	valid_0's auc: 0.924104
# [123]	valid_0's auc: 0.923997
# [124]	valid_0's auc: 0.924025
# [125]	valid_0's auc: 0.924378
# [126]	valid_0's auc: 0.92465
# [127]	valid_0's auc: 0.924685
# [128]	valid_0's auc: 0.924767
# [129]	valid_0's auc: 0.92476
# [130]	valid_0's auc: 0.924762
# [131]	valid_0's auc: 0.92467
# [132]	valid_0's auc: 0.924655
# [133]	valid_0's auc: 0.924901
# [134]	valid_0's auc: 0.924849
# [135]	valid_0's auc: 0.924707
# [136]	valid_0's auc: 0.924671
# [137]	valid_0's auc: 0.924562
# [138]	valid_0's auc: 0.92444
# [139]	valid_0's auc: 0.924389
# [140]	valid_0's auc: 0.924363
# [141]	valid_0's auc: 0.924304
# [142]	valid_0's auc: 0.924189
# [143]	valid_0's auc: 0.924216
# [144]	valid_0's auc: 0.924257
# [145]	valid_0's auc: 0.924359
# [146]	valid_0's auc: 0.924384
# [147]	valid_0's auc: 0.924221
# [148]	valid_0's auc: 0.92428
# [149]	valid_0's auc: 0.924515
# [150]	valid_0's auc: 0.924523
# [151]	valid_0's auc: 0.924406
# [152]	valid_0's auc: 0.924387
# [153]	valid_0's auc: 0.924359
# [154]	valid_0's auc: 0.924301
# [155]	valid_0's auc: 0.92425
# [156]	valid_0's auc: 0.92423
# [157]	valid_0's auc: 0.924239
# [158]	valid_0's auc: 0.924204
# [159]	valid_0's auc: 0.924236
# [160]	valid_0's auc: 0.924151
# [161]	valid_0's auc: 0.924067
# [162]	valid_0's auc: 0.923989
# Early stopping, best iteration is:
# [62]	valid_0's auc: 0.926467
#                                  name    importance
# 18                           hour_cos  45476.938908
# 23          ip_transform_ts_diff_mean  37614.991467
# 9                    http_status_code  34327.196289
# 13                               hour  19879.068992
# 16                           ts_diff2  12266.140734
# 15                           ts_diff1   7786.468265
# 14                          dayofweek   7256.779420
# 24           ip_transform_ts_diff_std   5806.480207
# 17                           hour_sin   3283.042056
# 21            department_ts_diff_mean   2719.028167
# 2                        ip_transform   1322.763667
# 41                   url_ts_diff_mean   1221.734009
# 3                device_num_transform   1186.492302
# 0                           user_name   1030.519657
# 19             user_name_ts_diff_mean    971.773722
# 20              user_name_ts_diff_std    900.214555
# 22             department_ts_diff_std    466.113898
# 25  device_num_transform_ts_diff_mean    281.782400
# 12                                url    259.604634
# 10                            op_city    257.036490
# 11               log_system_transform    249.170134
# 26   device_num_transform_ts_diff_std    220.807736
# 4                     browser_version    219.142212
# 37               op_city_ts_diff_mean    202.783975
# 39  log_system_transform_ts_diff_mean    201.170571
# 28        browser_version_ts_diff_std    168.316308
# 27       browser_version_ts_diff_mean    145.999814
# 38                op_city_ts_diff_std    134.189788
# 1                          department    129.386378
# 40   log_system_transform_ts_diff_std    125.440713
# 0.9275059635273724
# 0.002030164968410989
